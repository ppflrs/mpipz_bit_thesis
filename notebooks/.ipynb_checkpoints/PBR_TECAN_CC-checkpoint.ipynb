# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import os
import scipy

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set(style='whitegrid')

import itertools as it

# %config InteractiveShell.ast_node_interactivity='all'
# %config InlineBackend.figure_format = 'svg'

# %%
pd.options.display.max_rows = 100

# %% [markdown]
# # Helper Function

# %%
def get_wavelen_df(df, wavelen='680'):
    """This function returns a df which can be merged
    with temp df append the measurements"""
    
    tdf = df[df['wavelen']==wavelen].copy()
    
    tdf = tdf.drop(labels='wavelen', axis=1)
    
    tdf = tdf.rename({i:i+wavelen for i in xp2.columns}, axis=1)
    
    
    return tdf

# %% [markdown]
# # Tecan_ed PBR Experiment Data + Pre-Process

# %%
# Import Tecan PBR Exp2 & 3 Data Daily Sample's Tecan measurements
pbr_data_loc = """/home/rdmtinez/Documents/B-IT MS Program/Masters Thesis/data_o/pbr"""
xp2_loc = """/exp2/tecan_scan/exp2_tecaned_daily.csv"""
xp3_loc = """/exp3/tecan_scan/exp3_tecaned_daily.csv"""

# %%
# Pre-process
xp2 = pd.read_csv(pbr_data_loc+xp2_loc)
xp3 = pd.read_csv(pbr_data_loc+xp3_loc)

# %%
xp2['date_time'] = pd.to_datetime(xp2['date_time'], format='%d.%m.%Y %H:%M:%S').dt.round('15min')
xp3['date_time'] = pd.to_datetime(xp3['date_time'], format='%d.%m.%Y %H:%M:%S').dt.round('15min')

# %%
#
xp2['wavelen'] = xp2['wavelen'].astype(str)
xp3['wavelen'] = xp3['wavelen'].astype(str)


xp2 = xp2.set_index(keys='date_time', drop=True)
xp3 = xp3.set_index(keys='date_time', drop=True)


tubes = xp2.columns[1:].values
tubes
# Out:
# array(['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8'], dtype=object)

# %%
pd.options.display.max_rows = 6
xp2
xp3
pd.options.display.max_rows = 13
# Out:
#                     wavelen      T1      T2      T3      T4      T5      T6  \
# date_time
# 2019-04-17 21:00:00     680  0.1221  0.1240  0.1158  0.1164  0.1153  0.1174
# 2019-04-18 17:30:00     680  0.1917  0.2022  0.2101  0.1966  0.2248  0.1138
# 2019-04-19 12:30:00     680  0.1526  0.1594  0.2185  0.1883  0.2166  0.1611
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2019-04-27 18:15:00     750  0.0992  0.1102  0.1445  0.1392  0.1147  0.1254
# 2019-04-28 18:45:00     750  0.1140  0.1091  0.1466  0.1495  0.1325  0.1042
# 2019-04-29 17:45:00     750  0.0946  0.0973  0.1332  0.1062  0.1185  0.1063
#
#                          T7      T8
# date_time
# 2019-04-17 21:00:00  0.1236  0.1255
# 2019-04-18 17:30:00  0.1213  0.1310
# 2019-04-19 12:30:00  0.1528  0.1874
# ...                     ...     ...
# 2019-04-27 18:15:00  0.1189  0.1409
# 2019-04-28 18:45:00  0.1096  0.1518
# 2019-04-29 17:45:00  0.0994  0.1822
#
# [39 rows x 9 columns]
#                     wavelen      T1      T2      T3      T4      T5      T6  \
# date_time
# 2019-05-11 19:00:00     680  0.1310  0.1265  0.1251  0.1259  0.1286  0.1280
# 2019-05-12 19:30:00     680  0.1503  0.1372  0.1444  0.1413  0.1372  0.1384
# 2019-05-13 19:45:00     680  0.1098  0.1060  0.1195  0.0992  0.1160  0.1094
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2019-05-22 15:15:00     750  0.1005  0.1012  0.0992  0.0917  0.0940  0.0892
# 2019-05-23 15:00:00     750  0.0971  0.1073  0.1049  0.1061  0.1038  0.0890
# 2019-05-24 16:45:00     750  0.1032  0.1123  0.0921  0.0931  0.0907  0.0948
#
#                          T7      T8
# date_time
# 2019-05-11 19:00:00  0.1327  0.1289
# 2019-05-12 19:30:00  0.1269  0.1089
# 2019-05-13 19:45:00  0.1049  0.1070
# ...                     ...     ...
# 2019-05-22 15:15:00  0.0945  0.1053
# 2019-05-23 15:00:00  0.0968  0.1028
# 2019-05-24 16:45:00  0.1093  0.0944
#
# [36 rows x 9 columns]

# %%
to_concat = []
for wav in xp2.wavelen.unique():
    to_concat.append(get_wavelen_df(xp2, wav))

tecdfx2 = pd.concat(to_concat, axis=1)


to_concat = []
for wav in xp3.wavelen.unique():
    to_concat.append(get_wavelen_df(xp3, wav))
    
tecdfx3 = pd.concat(to_concat, axis=1)

# %%
pd.options.display.max_rows = 6
pd.options.display.max_columns = 24

tecdfx2
tecdfx3
# Apply MODELS to Tecan Data --- this allows you to obtain the
    # fraction that is B and C
    # fraction that is B and C
    
    # It is with the Fractions that you can then try and correlate with the actuall cell count data

pd.options.display.max_columns = 10
pd.options.display.max_rows = 15
# Out:
#                       T1680   T2680   T3680   T4680   T5680   T6680   T7680  \
# date_time
# 2019-04-17 21:00:00  0.1221  0.1240  0.1158  0.1164  0.1153  0.1174  0.1236
# 2019-04-18 17:30:00  0.1917  0.2022  0.2101  0.1966  0.2248  0.1138  0.1213
# 2019-04-19 12:30:00  0.1526  0.1594  0.2185  0.1883  0.2166  0.1611  0.1528
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2019-04-27 18:15:00  0.0995  0.1106  0.1678  0.2116  0.1367  0.1567  0.1583
# 2019-04-28 18:45:00  0.1078  0.1037  0.1593  0.2320  0.1742  0.1070  0.1365
# 2019-04-29 17:45:00  0.0914  0.0934  0.1432  0.1218  0.1425  0.1217  0.1050
#
#                       T8680   T1730   T2730   T3730   T4730   T5730   T6730  \
# date_time
# 2019-04-17 21:00:00  0.1255  0.1040  0.1043  0.1012  0.1029  0.1017  0.1035
# 2019-04-18 17:30:00  0.1310  0.1720  0.1835  0.1837  0.1780  0.1943  0.0998
# 2019-04-19 12:30:00  0.1874  0.1310  0.1371  0.1853  0.1636  0.1841  0.1188
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2019-04-27 18:15:00  0.2105  0.0971  0.1082  0.1432  0.1404  0.1132  0.1241
# 2019-04-28 18:45:00  0.2233  0.1131  0.1070  0.1453  0.1522  0.1321  0.1024
# 2019-04-29 17:45:00  0.3114  0.0920  0.0955  0.1323  0.1043  0.1175  0.1044
#
#                       T7730   T8730   T1750   T2750   T3750   T4750   T5750  \
# date_time
# 2019-04-17 21:00:00  0.1061  0.1034  0.1052  0.1055  0.1029  0.1047  0.1036
# 2019-04-18 17:30:00  0.1041  0.1072  0.1720  0.1808  0.1799  0.1758  0.1895
# 2019-04-19 12:30:00  0.1173  0.1306  0.1313  0.1374  0.1831  0.1620  0.1816
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2019-04-27 18:15:00  0.1172  0.1419  0.0992  0.1102  0.1445  0.1392  0.1147
# 2019-04-28 18:45:00  0.1083  0.1531  0.1140  0.1091  0.1466  0.1495  0.1325
# 2019-04-29 17:45:00  0.0972  0.1813  0.0946  0.0973  0.1332  0.1062  0.1185
#
#                       T6750   T7750   T8750
# date_time
# 2019-04-17 21:00:00  0.1055  0.1069  0.1042
# 2019-04-18 17:30:00  0.1017  0.1058  0.1081
# 2019-04-19 12:30:00  0.1200  0.1183  0.1300
# ...                     ...     ...     ...
# 2019-04-27 18:15:00  0.1254  0.1189  0.1409
# 2019-04-28 18:45:00  0.1042  0.1096  0.1518
# 2019-04-29 17:45:00  0.1063  0.0994  0.1822
#
# [13 rows x 24 columns]
#                       T1680   T2680   T3680   T4680   T5680   T6680   T7680  \
# date_time
# 2019-05-11 19:00:00  0.1310  0.1265  0.1251  0.1259  0.1286  0.1280  0.1327
# 2019-05-12 19:30:00  0.1503  0.1372  0.1444  0.1413  0.1372  0.1384  0.1269
# 2019-05-13 19:45:00  0.1098  0.1060  0.1195  0.0992  0.1160  0.1094  0.1049
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2019-05-22 15:15:00  0.1142  0.1045  0.1024  0.0927  0.0974  0.0850  0.0975
# 2019-05-23 15:00:00  0.1112  0.1332  0.1276  0.1172  0.1276  0.0848  0.1110
# 2019-05-24 16:45:00  0.1159  0.1437  0.0912  0.0953  0.0950  0.0947  0.1052
#
#                       T8680   T1730   T2730   T3730   T4730   T5730   T6730  \
# date_time
# 2019-05-11 19:00:00  0.1289  0.1060  0.1033  0.1035  0.1044  0.1056  0.1053
# 2019-05-12 19:30:00  0.1089  0.1115  0.1115  0.1100  0.1063  0.1082  0.1080
# 2019-05-13 19:45:00  0.1070  0.0957  0.0952  0.0988  0.0910  0.0996  0.0966
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2019-05-22 15:15:00  0.1156  0.0993  0.0987  0.0969  0.0898  0.0925  0.0876
# 2019-05-23 15:00:00  0.1175  0.0959  0.1068  0.1038  0.1050  0.1028  0.0869
# 2019-05-24 16:45:00  0.0892  0.1030  0.1110  0.0905  0.0910  0.0899  0.0928
#
#                       T7730   T8730   T1750   T2750   T3750   T4750   T5750  \
# date_time
# 2019-05-11 19:00:00  0.1096  0.1042  0.1070  0.1046  0.1048  0.1057  0.1071
# 2019-05-12 19:30:00  0.1066  0.0961  0.1121  0.1126  0.1112  0.1075  0.1092
# 2019-05-13 19:45:00  0.0973  0.0966  0.0980  0.0973  0.0999  0.0931  0.1015
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2019-05-22 15:15:00  0.0915  0.1041  0.1005  0.1012  0.0992  0.0917  0.0940
# 2019-05-23 15:00:00  0.0955  0.1017  0.0971  0.1073  0.1049  0.1061  0.1038
# 2019-05-24 16:45:00  0.1046  0.0918  0.1032  0.1123  0.0921  0.0931  0.0907
#
#                       T6750   T7750   T8750
# date_time
# 2019-05-11 19:00:00  0.1070  0.1114  0.1052
# 2019-05-12 19:30:00  0.1089  0.1082     NaN
# 2019-05-13 19:45:00  0.0992  0.0996  0.0987
# ...                     ...     ...     ...
# 2019-05-22 15:15:00  0.0892  0.0945  0.1053
# 2019-05-23 15:00:00  0.0890  0.0968  0.1028
# 2019-05-24 16:45:00  0.0948  0.1093  0.0944
#
# [12 rows x 24 columns]

# %% [markdown]
# # Cell Count Data + Pre-Process

# %%
# Import Cell Count Data

    # Segregate Exp2 & 3 and obtain an average and stdev on a per day per tube basis
    # Segregate each of the two experiments by cell type
    # for each cell type [b, c] in each of two segregated experiments get mean and stdev
    #

# %%
pd.options.display.max_rows = 15
# Entire cell count data
ccdf = pd.read_csv(pbr_data_loc+'/all_pbr_cell_counter_results.csv')

# some coulter CC data is denoted as 0, this should be handled as pd.nan instead
# as there were some problems with the data collection at that time. 
ccdf.loc[ccdf['Sample_concentration']==0, 'Sample_concentration'] = np.nan

# ensure completeness
ccdf.info()
ccdf

pd.options.display.max_rows = 15
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2120 entries, 0 to 2119
# Data columns (total 7 columns):
# experiment              2120 non-null int64
# sampling_day            2120 non-null int64
# pbr_tube                2120 non-null int64
# Sample_concentration    2104 non-null float64
# cc_sampling_time        2120 non-null object
# Filename                2120 non-null object
# type_of_cell            2120 non-null object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 116.1+ KB
#       experiment  sampling_day  pbr_tube  Sample_concentration  \
# 0              1            29         1          2.522750e+07
# 1              1            29         1          2.010160e+04
# 2              1            29         1          3.015239e+06
# 3              1            29         1          2.010160e+04
# 4              1            29         1          1.346807e+06
# ...          ...           ...       ...                   ...
# 2115           4             8         8          5.075653e+05
# 2116           4             8         8          3.911771e+07
# 2117           4             8         8          7.186321e+05
# 2118           4             8         8          4.111782e+07
# 2119           4             8         8          5.980225e+05
#
#      cc_sampling_time                  Filename type_of_cell
# 0     3/26/2019 10:01  JF_PBR_xp1_d29_t1_01.#m4            b
# 1     3/26/2019 10:01  JF_PBR_xp1_d29_t1_01.#m4            c
# 2     3/26/2019 10:02  JF_PBR_xp1_d29_t1_02.#m4            b
# 3     3/26/2019 10:02  JF_PBR_xp1_d29_t1_02.#m4            c
# 4     3/26/2019 10:02  JF_PBR_xp1_d29_t1_03.#m4            b
# ...               ...                       ...          ...
# 2115   7/9/2019 17:26   JF_PBR_xp4_d8_t8_01.#m4            c
# 2116   7/9/2019 17:27   JF_PBR_xp4_d8_t8_02.#m4            b
# 2117   7/9/2019 17:27   JF_PBR_xp4_d8_t8_02.#m4            c
# 2118   7/9/2019 17:27   JF_PBR_xp4_d8_t8_03.#m4            b
# 2119   7/9/2019 17:27   JF_PBR_xp4_d8_t8_03.#m4            c
#
# [2120 rows x 7 columns]

# %%
# Segregation of Data & Pre-processing

# While all PBR Samples have coulter cell count data only ex3 and ex4 samples were tecan-measured
# therefore we will use these values to correlate against the predicted fractions of the tecan data

ccdfx2 = ccdf[ccdf['experiment']==2].reset_index(drop=True).drop(labels=['experiment', 'Filename'], axis=1)
ccdfx3 = ccdf[ccdf['experiment']==3].reset_index(drop=True).drop(labels=['experiment', 'Filename'], axis=1)

ccdfx2 = ccdfx2.rename({'cc_sampling_time':'date_time', 
                        'type_of_cell':'cell_type',
                        'Sample_concentration':'concentration'}, axis=1).sort_values(by=['sampling_day', 'pbr_tube'])

ccdfx3 = ccdfx3.rename({'cc_sampling_time':'date_time', 
                        'type_of_cell':'cell_type',
                        'Sample_concentration':'concentration'}, axis=1).sort_values(by=['sampling_day', 'pbr_tube'])

ccdfx2['date_time'] = pd.to_datetime(ccdfx2['date_time']).dt.round('15min')
ccdfx3['date_time'] = pd.to_datetime(ccdfx3['date_time']).dt.round('15min')

# %%
# check that date_time count matches sampling_day counts
# and that they're in order

#ccdfx2['date_time'].dt.round('D').unique()
#ccdfx2['sampling_day'].unique()

#x2g = ccdfx2.groupby(['sampling_day', 'pbr_tube', 'type_of_cell']).mean().unstack(level=0)

# %%
pd.options.display.max_rows = 6
# Group each dataset by the cell type and find the mean and standard deviation

#Exp2 Cell Counts
x2gb = ccdfx2.groupby(by='cell_type')

cell_counts_x2 = []
for name, group in x2gb:
    cell_counts_x2.append(group.drop(labels=['cell_type'], axis=1))
    

# Mean & Standard Deviation Calculation and DF reformatting
x2_cell_counts = []
for df in cell_counts_x2:
    tdf = df.groupby(['sampling_day', 'pbr_tube'], as_index=False).agg({'concentration':['mean', 'std'],'date_time':'last'})
    tdf.columns = ['sampling_day', 'pbr_tube', 'conc_mean', 'conc_std', 'date_time']
    tdf = tdf.sort_values(by=['sampling_day', 'pbr_tube'])
    tdf = tdf.set_index('date_time')
    x2_cell_counts.append(tdf)
    
    #tdf.info()
    tdf


# Exp3 Cell Counts 
x3gb = ccdfx3.groupby(by='cell_type')

cell_counts_x3 = []
for name, group in x3gb:
    cell_counts_x3.append(group.drop(labels=['cell_type'], axis=1))

# Mean & Standard Deviation Calculation and DF reformatting
x3_cell_counts = []
for df in cell_counts_x3:
    tdf = df.groupby(['sampling_day', 'pbr_tube'], as_index=False).agg({'concentration':['mean', 'std'],'date_time':'last'})
    tdf.columns = ['sampling_day', 'pbr_tube', 'conc_mean', 'conc_std', 'date_time']
    tdf = tdf.sort_values(by=['sampling_day', 'pbr_tube'])
    tdf = tdf.set_index('date_time')
    x3_cell_counts.append(tdf)
    
    #tdf.info()
    tdf
pd.options.display.max_rows = 15
# Out:
#                      sampling_day  pbr_tube     conc_mean      conc_std
# date_time
# 2019-04-17 19:45:00             0         1  2.429613e+06  9.347595e+05
# 2019-04-17 19:45:00             0         2  2.237978e+06  5.233150e+05
# 2019-04-17 20:00:00             0         3  2.691604e+06           NaN
# ...                           ...       ...           ...           ...
# 2019-04-29 16:15:00            12         6  4.548740e+07  3.187484e+06
# 2019-04-29 16:15:00            12         7  2.058152e+07  5.650055e+05
# 2019-04-29 16:15:00            12         8  1.345048e+07  1.645268e+06
#
# [104 rows x 4 columns]
#                      sampling_day  pbr_tube     conc_mean       conc_std
# date_time
# 2019-04-17 19:45:00             0         1  1.085486e+05   13926.794580
# 2019-04-17 19:45:00             0         2  1.634930e+05   45232.314518
# 2019-04-17 20:00:00             0         3  1.748839e+05            NaN
# ...                           ...       ...           ...            ...
# 2019-04-29 16:15:00            12         6  3.015239e+05   28427.950396
# 2019-04-29 16:15:00            12         7  1.583001e+05   46195.419375
# 2019-04-29 16:15:00            12         8  3.045392e+06  149246.740108
#
# [104 rows x 4 columns]
#                      sampling_day  pbr_tube     conc_mean      conc_std
# date_time
# 2019-05-11 17:15:00             0         1  6.533019e+05  2.132096e+04
# 2019-05-11 17:15:00             0         2  1.155842e+06  9.239084e+04
# 2019-05-11 17:15:00             0         3  1.047796e+06  3.198144e+04
# ...                           ...       ...           ...           ...
# 2019-05-24 15:00:00            12         6  4.310285e+07  6.112009e+05
# 2019-05-24 15:00:00            12         7  1.164134e+07  2.455464e+06
# 2019-05-24 15:15:00            12         8  4.656284e+07  4.086518e+05
#
# [96 rows x 4 columns]
#                      sampling_day  pbr_tube      conc_mean      conc_std
# date_time
# 2019-05-11 17:15:00             0         1  120609.579100  21320.962832
# 2019-05-11 17:15:00             0         2  160812.772150  14213.975198
# 2019-05-11 17:15:00             0         3  185939.767850  35534.938030
# ...                           ...       ...            ...           ...
# 2019-05-24 15:00:00            12         6  165838.171300  42641.925664
# 2019-05-24 15:00:00            12         7  120609.579150  14213.975198
# 2019-05-24 15:15:00            12         8   32665.094345  24874.456621
#
# [96 rows x 4 columns]

# %% [markdown]
# # Cell Counts Visualize
#
#     Looking at the following graphs there are some obvious outliers, I would get rid of them:
#         Exp2:
#             12th day of Tube 8, Give it the measure of the average of all the tubes including itself
#
#         Exp3:
#             8th day of Tube 7, Give it the measure of the average of all the tubes including itself
#
#
#     Once you've done this you can start correlating against the values
#
#     How do we do the conversions between these models

# %%
sns.barplot(data=x2_cell_counts[0], y='conc_mean',x='sampling_day', hue='pbr_tube')

# %%
sns.barplot(data=x2_cell_counts[1], y='conc_mean',x='sampling_day', hue='pbr_tube')

# %%
sns.barplot(data=x3_cell_counts[0], y='conc_mean',x='sampling_day', hue='pbr_tube')

# %%
sns.barplot(data=x3_cell_counts[1], y='conc_mean',x='sampling_day', hue='pbr_tube')

# %% [markdown]
# # Model B|C Fractions against Cell count data
#
#     In order to get fractions, first apply the models to the Tecan Data
#     e.g. T1680 * T1720 || T1680 * T1750 || T1680 * T1730
#
#     Note that we do not have tecan 720 data for these samples, but we do have 730 data. We should note that these wavelengths althought not the same are similar enough in the regression fractions. Alter

# %%
def get_wav_ks(df, regressor='560'):
    
    return df.loc[regressor].values


def get_predictions(df, coef_list, regressor='560'):
    """
    This function uses the coefficients obtained from the simple linear and Beer-Lambert's law
    to make predictions. Each prediction is composed of either the [bacterial] or [chlamy] 
    fraction of the regressor signal. Ensure that you're using the coefficient dictionary for 
    the proper regressand wavelengths, and take note of
    """
    
    tdf = df.copy()
    
    tmp = pd.DataFrame()
    
    # columns
    cols = tdf.columns.values
    
    # coefficients for 680_730 models
    kB1, kC1, kB2, kC2 = coef_list[0]
    yT1, yT2 = cols[0:2:1]
    
    # checking columns
    #print(yT1, yT2)
    
    # tube and model naming scheme
    B = yT1[0:2]+'B_p'+yT1[2:]+'_'+yT2[2:]+'_'+regressor
    C = yT1[0:2]+'C_p'+yT1[2:]+'_'+yT2[2:]+'_'+regressor
    
    
    # predictions
    tmp[B] = (kC2*tdf[yT1] - kC1*tdf[yT2]) / (-kC1*kB2 + kC2*kB1)
    tmp[C] = (kB2*tdf[yT1] - kB1*tdf[yT2]) / (-kB1*kC2 + kB2*kC1)

    # coefficients for 680_750 models
    kB1, kC1, kB2, kC2 = coef_list[1]
    yT1, yT2 = cols[0:3:2]
    #print(yT1, yT2)
    
    # tube and model naming scheme
    B = yT1[0:2]+'B_p'+yT1[2:]+'_'+yT2[2:]+'_'+regressor
    C = yT1[0:2]+'C_p'+yT1[2:]+'_'+yT2[2:]+'_'+regressor
    
    # predictions
    tmp[B] = (kC2*tdf[yT1] - kC1*tdf[yT2]) / (-kC1*kB2 + kC2*kB1)
    tmp[C] = (kB2*tdf[yT1] - kB1*tdf[yT2]) / (-kB1*kC2 + kB2*kC1)
    
    return tmp.copy()


def model_to_tecan_data(tec_df, coeff_dfs, regressor='560'):
    
    # TubeCallerGenerator - in the dataframe the tube values are set up along the
    # columns in order to make the models easier to apply, this generator calls
    # and groups the tubes by their number and wavelength
    #print(tec_df.columns.values.reshape(3,8))
    generator = zip(*tec_df.columns.values.reshape(3,8))
    
    # obtain relevant regressor coeffs from the two regressand models
    coef_list = []
    for cos in coeff_dfs:
        #print(cos)
        coef_list.append(get_wav_ks(cos, regressor))
    
    
    mdf = tec_df.copy()
    for tubes in generator:
        #print(tubes)
        mdf = mdf.join(get_predictions(tec_df[list(tubes)], coef_list, regressor=regressor))
        #break
    return mdf.copy()

# %% [markdown]
# # Community Models

# %%
# Import Community Models
    #[x] establish that the models are behaving properly given that they behave significantly 
    #different from the original single strain models
model_loc = """/home/rdmtinez/Documents/B-IT MS Program/Masters Thesis/data_o/calibration/community_calibration/created_models"""

a680_a720 = pd.read_csv(model_loc+'/a680_a720_coefficients.csv',index_col=0)
a680_730  = pd.read_csv(model_loc+'/a680_730_coefficients.csv',index_col=0)
a680_a750 = pd.read_csv(model_loc+'/a680_a750_coefficients.csv',index_col=0)

# %%
# There are 
pd.options.display.max_rows = 6


# all the previously calculated model coefficients are loaded
# to a list which allows one later to choose a different
# regressor. As we have noted not all the wavelengths are 
# behaving like expected, e.g. A600 data, REVIST A600
rel_models = [a680_730, a680_a750]
for df in rel_models:
    df

pd.options.display.max_rows = 100
# Out:
#          kB680     kC680     kB730     kC730
# A600  0.877526  1.617013  0.756929  0.796985
# 500   0.739568  1.003908  0.639104  0.495227
# 510   0.755922  1.152351  0.653205  0.568540
# ...        ...       ...       ...       ...
# 730   1.155928  2.026922  1.000000  1.000000
# 740   1.174883  2.070518  1.016454  1.021531
# 750   1.197120  2.111985  1.035713  1.041998
#
# [27 rows x 4 columns]
#          kB680     kC680     kB750     kC750
# A600  0.877526  1.617013  0.768603  0.761013
# 500   0.739568  1.003908  0.647349  0.471613
# 510   0.755922  1.152351  0.661699  0.541536
# ...        ...       ...       ...       ...
# 730   1.155928  2.026922  1.012212  0.952570
# 740   1.174883  2.070518  1.028828  0.972983
# 750   1.197120  2.111985  1.048327  0.992382
#
# [27 rows x 4 columns]

# %% [markdown]
# ### Apply Models to Tecan-measure PBR Samples
#
#     # We Will Use 560 as the regressor wavelength, but in reality any wavelength can be used
#     # to regress back to and obtain rations
#
#     # Two models are used a680_730 and a680_750 which both regress back to '560'
#     # However we're only interested in the '730' models

# %%
# Using the models to  regress back to 560 B and C signal partitions
tec_x2_partitions = model_to_tecan_data(tecdfx2, rel_models, regressor='560')
tec_x3_partitions = model_to_tecan_data(tecdfx3, rel_models, regressor='560')

# %%
# Segregate the A680_A730 signal partitions for each experiment

# %%
# These are the relevant columns we need to compare against the Cell Counter Data
[i for i in tec_x3_partitions.columns.values[24:] if 'B' in i and '730' in i]
[i for i in tec_x3_partitions.columns.values[24:] if 'C' in i and '730' in i]

# %% [markdown]
# ### Exp2 B & C Predicted 560 Partitions
#
# Note: We don't know the TRUE 560 Measurements, but what you can do is use either 730 as the regressor

# %%
# You Also NEED To assess these results against the PBR Measurements data
# for these exact dates

# %%
NOTE: The values of the predicted C partitions are very low and sometimes negative... this will
    be a problem during the regression, the best we can do here take note of the cell counts
    which are NOT ENOUGH to induce a good enough signal at '680', this will be because the chalmy
    are too diluted at those levels in the tubes.

# %% [markdown]
# # Vis Predicted

# %%
x2_B_p = tec_x2_partitions[[i for i in tec_x2_partitions.columns.values[24:] if 'B' in i and '730' in i]]
x2_C_p = tec_x2_partitions[[i for i in tec_x2_partitions.columns.values[24:] if 'C' in i and '730' in i]]

# %%
x3_B_p = tec_x3_partitions[[i for i in tec_x3_partitions.columns.values[24:] if 'B' in i and '730' in i]]
x3_C_p = tec_x3_partitions[[i for i in tec_x3_partitions.columns.values[24:] if 'C' in i and '730' in i]]

# %%
x2_B_p.plot(kind='bar', legend=False, style='.')

x2_C_p.plot(kind='bar', legend=False, style='.')

# %% [markdown]
# # Together Vis

# %%
fs = (9, 10)
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=fs)

sns.barplot(data=x2_cell_counts[0], y='conc_mean', x='sampling_day', hue='pbr_tube', ax=ax[0])
x2_B_p.plot(kind='bar', legend=False, style='.', width=0.7, ax=ax[1])

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=fs)

sns.barplot(data=x2_cell_counts[1], y='conc_mean', x='sampling_day', hue='pbr_tube', ax=ax[0])
x2_C_p.plot(kind='bar', legend=False, style='.', width=0.7, ax=ax[])

# %%
sns.barplot(data=x3_cell_counts[0], y='conc_mean',x='sampling_day', hue='pbr_tube')
x3_B_p.plot(kind='bar', legend=False, style='.', width=0.8)

# %%
sns.barplot(data=x3_cell_counts[1], y='conc_mean',x='sampling_day', hue='pbr_tube')
x3_C_p.plot(kind='bar', legend=False, style='.', width=0.8)

# %% [markdown]
# # Correlation :
#
#     Well, it looks like nothing was captured at those wavelengths using the
#     tecan, but we still need to check those days values against the actual
#     measured values at the pbr

# %%
x2_B_counts = x2_cell_counts[0]
x2_C_counts = x2_cell_counts[1]

x3_B_counts = x3_cell_counts[0]
x3_C_counts = x3_cell_counts[1]
