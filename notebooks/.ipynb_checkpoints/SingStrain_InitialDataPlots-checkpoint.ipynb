# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import os

#from scipy.optimize import curve_fit
import scipy

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set(style='whitegrid')

import itertools as it

#%config InteractiveShell.ast_node_interactivity='all'
# %config InteractiveShell.ast_node_interactivity='last_expr'

# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Data

# %%
dirname = '/home/rdmtinez/Desktop/MScThesis/data/abs-flu/exp1/tecan_results/'
fname = 'abs-fluo_exp1_main.csv'
df_main = pd.read_csv(dirname+fname, index_col=0)
df_main.head()
# Out:
#   row  col  chlamy_cnt  bact_cnt  abs_680  blank_680  corr_abs_680  fluo_680  \
# 0   A    1        0.25     0.200   0.8037     0.0827        0.7210    4669.0
# 1   B    1        0.25     0.175   0.8649     0.0827        0.7822    4835.0
# 2   C    1        0.25     0.150   0.7752     0.0827        0.6925    4641.0
# 3   D    1        0.25     0.125   0.7808     0.0827        0.6981    4778.0
# 4   E    1        0.25     0.100   0.7615     0.0827        0.6788    4939.0
#
#    blank_fluo  corr_fluo  abs_750  blank_750  corr_abs_750
# 0         3.0     4666.0   0.5047     0.0901        0.4146
# 1         3.0     4832.0   0.5056     0.0901        0.4155
# 2         3.0     4638.0   0.4730     0.0901        0.3829
# 3         3.0     4775.0   0.4494     0.0901        0.3593
# 4         3.0     4936.0   0.4315     0.0901        0.3414

# %% [markdown]
# # Alternative Visualization
#
#     #1 plot absorbace data on one figure
#
#         # Alternative plots as substiutes for broad overview:
#         # ----- Rows -------
#         # - A680 v. [chlamy]
#         # - A750 v. [chlamy]
#
#         #--- Cols ---------
#         # - A750 v. [bacter]
#
#     #2 plot fluorescence data on one figure
#
#         # --- Rows ---------
#         # - F680 v. [chlamy]
#
#
#         #--- Cols --------- <<<<----doubtful that this is very informative
#         # - A680 v. [bacter]

# %%
# create list of absorbance and fluorescence values

# chlamy gradient is the same for all rows
chlamy_cnt = df_main.loc[df_main['row']=='A']['chlamy_cnt']

# store absorbance values that will be plotted on one figure
corr_abs_680 = []
corr_abs_750 = []
corr_flu_680 = []

rows=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
for row in rows:
    
    #append the values to their respective list
    corr_abs_680.append(df_main.loc[df_main['row']==row]['corr_abs_680'].to_list())
    corr_abs_750.append(df_main.loc[df_main['row']==row]['corr_abs_750'].to_list())
    corr_flu_680.append(df_main.loc[df_main['row']==row]['corr_fluo'].to_list())


# [bacter] gradients is the same for all columns
bacter_cnt = df_main.loc[df_main['col']==1]['bact_cnt']
# store fluorescence values
corr_abs_750_col = []
corr_abs_680_col = []
corr_flu_680_col = []

cols = [i for i in range (1, 13)]
for col in cols:
    
    # append
    corr_abs_680_col.append(df_main.loc[df_main['col']==col]['corr_abs_680'].to_list())
    corr_abs_750_col.append(df_main.loc[df_main['col']==col]['corr_abs_750'].to_list())
    corr_flu_680_col.append(df_main.loc[df_main['col']==col]['corr_fluo'].to_list())

# %%
# concentrations as standard python lists
chlamy_cnt_lst = df_main.loc[df_main['row']=='A']['chlamy_cnt'].to_list()
bacter_cnt_lst = df_main.loc[df_main['col']==1]['bact_cnt'].to_list()

# %%
#define figure
fig=plt.figure(figsize=(8,10))

#subplots
gs = gridspec.GridSpec(2, 1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))
        

axes[0].set_ylim(-0.1, 1)
axes[0].set_title("A680 @ k=[bacter]")
for l in corr_abs_680:
    axes[0].plot(chlamy_cnt, l, marker='*')
    axes[0].set_ylabel('Abs')
    axes[0].set_xlabel('[chlamy]')
    axes[0].legend(bacter_cnt_lst, title='[bacter]')
    

#fig=plt.figure(figsize=(7,4))
axes[1].set_ylim(-0.1, 1)
axes[1].set_title("A680 @ k=[chlamy]")
for l in corr_abs_680_col:
    axes[1].plot(bacter_cnt, l, marker='*')
    axes[1].set_ylabel('Abs')
    axes[1].set_xlabel('[bacter]')
    axes[1].legend(chlamy_cnt_lst, title='[chlamy]',
                   ncol=2, prop={'size':8}, loc=2)
    
plt.tight_layout()
plt.savefig('A680.pdf')

# %%
plt.figure(figsize=(8,10))

gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))

axes[0].set_ylim(-0.1,.7)
axes[0].set_title("A750 @ k=[bacter]")
for l in corr_abs_750:
    axes[0].plot(chlamy_cnt, l, marker='*')
    axes[0].set_ylabel('Abs')
    axes[0].set_xlabel('[chlamy]')
    axes[0].legend(bacter_cnt_lst, title='[bacter]',
                  prop={'size':10})
    
    
axes[1].set_ylim(-0.1,.7)
axes[1].set_title("A750 @ k=[chlamy]")
for l in corr_abs_750_col:
    axes[1].plot(bacter_cnt, l, marker='*')
    axes[1].set_ylabel('Abs')
    axes[1].set_xlabel('[bacter]')
    axes[1].legend(chlamy_cnt_lst, title='[chlamy]',
                  ncol=2, prop={'size':10})
    
plt.tight_layout()
plt.savefig('A750.pdf')

# %%
plt.figure(figsize=(8,10))
gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))
        

axes[0].set_ylim(-100,7000)
axes[0].set_title("F680 @ k=[bacter]")
for l in corr_flu_680[::-1]:
    axes[0].plot(chlamy_cnt, l, marker='*')
    axes[0].set_ylabel('Intensity')
    axes[0].set_xlabel('[chlamy]')
    axes[0].legend(bacter_cnt_lst[::-1], title='[bacter]')
    
    
#fig=plt.figure(figsize=(7,4))
axes[1].set_ylim(-100,7000)
axes[1].set_title("F680 @ k=[chlamy]")
for l in corr_flu_680_col:
    axes[1].plot(bacter_cnt, l, marker='*')
    axes[1].set_ylabel('Intensity')
    axes[1].set_xlabel('[bacter]')
    axes[1].legend(chlamy_cnt_lst, title='[chlamy]',
                  loc=1, ncol=2, prop={'size':7})
    
plt.tight_layout()
plt.savefig('F680.pdf')

# %% [markdown]
# # Curve Fitting Definitions

# %%
# linear curve

def linear_curve(parameters, xdata):
    """
    A680 & A750 show a linear relationship:
    y = m*x + b
    
    m = slope
    b = y-intercept
    """
    m = parameters[0]
    b = parameters[1]
    
    return m*xdata + b


def linear_curve_residuals(parameters, xdata, ydata, function):
    """
    xdata = [chlamy] or [bacter]
    
    ydata = observed A680 or A750
    
    Computes the residuals of y_pred -y_obs, where:
        y_pred = line(parameters, xdata)
    """
    
    return linear_curve(parameters,xdata) - ydata


# root curves
def root_curve(parameters, xdata):
    """
    F680 shows an obvious root-function relationship:
    
    y = a√(b*x)
    
    'a' and 'b' control area under the curve with
    'b' doing so much more slowly
    
    NOTE: 
        
        the following permutations of this model were
        also made :
            y = √(b*x)
            y = a√(x)
        
        however these mono-parameter models produce large
        coefficients thus the best model to use is below:
            y = a√(b*x)
    
    """
    
    a = parameters[0]
    b = parameters[1]
    
    return a*np.sqrt(b*xdata)


def root_curve_residuals(parameters, xdata, ydata, function):
    """
    xdata = [chlamy] or [bacter]
    
    ydata = observed F680
    
    Computes the residuals of y_pred - y_obs, where
    y_pred = root_curve(parameters, xdata)
    
    """
    
    return root_curve(parameters, xdata) - ydata

# %% [markdown]
# # Parameter Fitting

# %%
# Note: For a given row (e.g. 'A'), the constant is a [bacter] 
#       For a given col (e.g. '1'), the constant is a [chlamy]

params_A680_B = []
x0=[0,0]
for ydata in corr_abs_680:
    optimize_result = scipy.optimize.least_squares(linear_curve_residuals, x0, 
                                               args = (chlamy_cnt, ydata,
                                                      linear_curve))

    params_A680_B.append(optimize_result.x)

    
    
params_A680_C = []
x0=[0,0]
for ydata in corr_abs_680_col:
    optimize_result = scipy.optimize.least_squares(linear_curve_residuals, x0, 
                                               args = (bacter_cnt, ydata,
                                                      linear_curve))

    params_A680_C.append(optimize_result.x)
    
    
    
params_A750_B = []
x0=[0,0]
for ydata in corr_abs_750:
    optimize_result = scipy.optimize.least_squares(linear_curve_residuals, x0, 
                                               args = (chlamy_cnt, ydata,
                                                      linear_curve))

    params_A750_B.append(optimize_result.x)
       

params_A750_C = []
x0=[0,0]
for ydata in corr_abs_750_col:
    optimize_result = scipy.optimize.least_squares(linear_curve_residuals, x0, 
                                               args = (bacter_cnt, ydata,
                                                      linear_curve))

    params_A750_C.append(optimize_result.x)


params_F680 = []
x0 = [1,1]
for ydata in corr_flu_680:
    optimize_result = scipy.optimize.least_squares(root_curve_residuals, x0,
                                                   args=(chlamy_cnt, ydata, root_curve))

    params_F680.append(optimize_result.x)
# Out:
# /home/rdmtinez/program_files/anaconda3/envs/fluxy/lib/python3.7/site-packages/ipykernel_launcher.py:56: RuntimeWarning: invalid value encountered in sqrt

# %% [markdown]
# ## F680 | 2-Parameters

# %%
plt.figure(figsize=(8,10))
gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))


xmock = np.linspace(0, .25, 100)
for ab in params_F680[::-1]:
    axes[0].plot(xmock, root_curve(ab,xmock))
    axes[0].set_title("F680 @ k=[bacter]")
    axes[0].set_ylabel('Abs')
    axes[0].set_xlabel('[chlamy]')

axes[0].legend(bacter_cnt_lst[::-1], title='[bacter]')


# plot with [bacter] decreasing by half the former 
# [bacter] = .2, .1, .05, .025, 0
idx = [0, 4, 5, 6, 7]
param_halves = [params_F680[i] for i in idx]
for par in param_halves[::-1]:
    plt.plot(xmock, root_curve(par,xmock))
    axes[1].set_title("F680 @ k=[bacter]")
    axes[1].set_ylabel('Abs')
    axes[1].set_xlabel('[chlamy]')
    
legend = [bacter_cnt_lst[i] for i in idx]    
axes[1].legend(legend[::-1], title='[bacter]') 

plt.tight_layout()
plt.savefig('Fitted F680 BACTER_2.pdf')

# %% [markdown]
# ## A680

# %%
plt.figure(figsize=(8,10))
gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))

xmock = np.linspace(0, .26, 25)
for mb in params_A680_B:
    
    axes[0].plot(xmock, linear_curve(mb, xmock))
    axes[0].set_xlabel('[chlamy]')
    axes[0].set_ylabel('Abs')
    axes[0].set_title('A680 @ k=[bacter] | Fitted Curves')
    axes[0].set_ylim(-0.1, 1.2)
axes[0].legend(bacter_cnt_lst, title='[bacter]')


xmock = np.linspace(0, .45, 25)
for mb in params_A680_C:
    
    axes[1].plot(xmock, linear_curve(mb, xmock))
    axes[1].set_xlabel('[bacter]')
    axes[1].set_ylabel('Abs')
    axes[1].set_title('A680 @ k=[chlamy] | Fitted_Curves')
    axes[1].set_ylim(-0.1, 1.2)

axes[1].legend(chlamy_cnt_lst, title='[chlamy]', ncol=2, prop={'size':8})


plt.tight_layout()
plt.savefig('Fitted A680.pdf')

# %% [markdown]
# ## A750

# %%
plt.rcParams["figure.figsize"] = [8,11]
gs = gridspec.GridSpec(2, 1, hspace=.3)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))


slope_yint_A750_B = [] # constant [bacteria] | [chlamy] gradient 

x0=[0,0]
for ydata in corr_abs_750:
    optimize_result = scipy.optimize.least_squares(linear_curve_residuals, x0, 
                                               args = (chlamy_cnt, ydata,
                                                      linear_curve))

    slope_yint_A750_B.append(optimize_result.x)
    

# this returns (m, b) paremeters 
xmock = np.linspace(0, .26, 25)
for mb in slope_yint_A750_B:
    
    axes[0].set_ylim(-0.1, 1)
    axes[0].plot(xmock, linear_curve(mb, xmock))
    axes[0].set_title('A750 @ k= [bacter] | Fitted Curves')
    axes[0].set_xlabel('[chlamy]')
    axes[0].set_ylabel('Abs')
    axes[0].legend(bacter_cnt, title='[bacter]')
    
#axes[0].axvline(x=.2, linestyle=':')    
#axes[0].plot(xmock, linear_curve(slope_yint_A750_B[0], xmock), 'b-*')
#axes[0].plot(xmock, linear_curve(slope_yint_A750_B[7], xmock), 'k-*', alpha=0.1)







for mb in slope_yint_A750_C_col:
    
    axes[1].plot(xmock, linear_curve(mb, xmock))
    axes[1].set_title('A750 @ k=[chlamy] | Fitted Curves')
    axes[1].set_xlabel('[bacter]')
    axes[1].set_ylabel('Abs')
    axes[1].legend(chlamy_cnt, title='[chlamy]')

plt.savefig('Fitted A7500.pdf')

# %% [markdown]
# ## A680 @ Constant [bacter]

# %%
plt.figure(figsize=(11,6))
xmock = np.linspace(0, .42, 25)
for mb in params_A680_B:
    
    plt.plot(xmock, linear_curve(mb, xmock))
    plt.xlabel('[chlamy]')
    plt.ylabel('Abs')
    plt.title('A680 @ k=[bacter] | Fitted Curves')
    plt.ylim(-0.05, 1.25)


plt.axvline(x=.40, linestyle='-')
plt.axhline(y=.67, linestyle=':')
plt.axhline(y=.60, linestyle=':')
plt.axvline(x=.22, linestyle=':')
plt.axvline(x=.24, linestyle=':')    
plt.plot(xmock, linear_curve(params_A680_B[0], xmock), 'b-*')
plt.plot(xmock, linear_curve(params_A680_B[7], xmock), 'k-*', alpha=.15)

plt.legend(bacter_cnt_lst, title='[bacter]')
plt.tight_layout()
plt.savefig('Fitted A680 BACTER_extended.pdf')

# %% [markdown]
# ## A750 @ Constant [chlamy]

# %%
xmock = np.linspace(0, .7, 25)
plt.figure(figsize=(11,6))
for mb in params_A750_C:
    
    plt.plot(xmock, linear_curve(mb, xmock))
    plt.title('A750 @ k=[chlamy] | Fitted Curves')
    plt.xlabel('[bacter]')
    plt.ylabel('Abs')

plt.legend(chlamy_cnt, title='[chlamy]')
plt.plot(xmock, linear_curve(params_A750_C[0], xmock), 'b-*')
plt.plot(xmock, linear_curve(params_A750_C[11], xmock), 'r-*', alpha=.3)

plt.tight_layout()
plt.savefig('Fitted A750 CHLAMY_extended.pdf')

# %%
plt.figure(figsize=(8,10))

gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))
        
        
xmock = np.linspace(0, .22, 25)
for mb in params_A750_C:
    
    axes[0].plot(xmock, linear_curve(mb, xmock))
    axes[0].set_title('A750 @ k=[chlamy] | Fitted Curves')
    axes[0].set_xlabel('[bacter]')
    axes[0].set_ylabel('Abs')
    
axes[0].legend(chlamy_cnt_lst, title='[chlamy]', ncol=2)
axes[0].plot(xmock, linear_curve(params_A750_C[0], xmock), 'b-*')
axes[0].plot(xmock, linear_curve(params_A750_C[11], xmock), 'r-*', alpha=.15)




#idx = [0,1,2,3]
idx = [0,3,4,5,6,7,8,9,10,11]
params = [params_A750_C[i] for i in idx]
legend = [chlamy_cnt_lst[i] for i in idx]

for par in params:
    axes[1].plot(xmock, linear_curve(par,xmock))
    axes[1].set_title('A750 @ k=[chlamy] | Fitted Curves')
    axes[1].set_xlabel('[bacter]')
    axes[1].set_ylabel('Abs')
    axes[1].set_ylim(-0.1, .5)

axes[1].legend(legend, title='[chlamy]', ncol=2)
axes[1].plot(xmock, linear_curve(params_A750_C[0], xmock), 'r*')
axes[1].plot(xmock, linear_curve(params_A750_C[3], xmock), 'g*')

plt.tight_layout()
plt.savefig('Fitted A750 CHLAMY.pdf')

# %%
# 4 create the following

# ---------------------------M = slope of curve---------------------------
#
# plot: A750_Mi v. [bacter] ---- i.e. best fit curve
    #################ANALYSIS##########################
    # the slopes are quite parallel unlike 

# plot: 680_Mi v. [bacter] ---- i.e. best fit curve
#
# - I expect that the each plot's slope for a given wavelen
# - is equivalent to all others M1=M2=...=Mn


# ---------------------------A = area between curves----------------------
# plot: Ai v. [bacter]  | Ai = A_680 - A_750
#
# - I expect that the areas are also all equivalent A1=A2=...=Mn
# ------------------------------------------------------------------------

# %%
# ---------------------------M = slope of curve---------------------------
# plot: 750_Mi v. [chlamy]
#
# - I expect that the each plot's slope is
# - equivalent to all others M1=M2=...=Mn = M_ave
#
# plot: d[Mi] vs [chlamy] & d|y-int| vs [chlamy]
# - I expected that amplitude of the A750 curve
# - is linearly dependent on [chlamy], both the
# - d[Mi] & d|y-int| should equal
# -------------------------------------------------------------------------

# %%
# ---------------------------A = area under curves----------------------
# plot: Ai v. [bacter] 
# - I expect that the areas show this (-)linear dependency
# ------------------------------------------------------------------------
