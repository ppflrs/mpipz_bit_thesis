# %% [markdown]
# # Imports

# %% [markdown]
# # Data

# %%
import numpy as np
import pandas as pd
import os


import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set(style='whitegrid')

# %config InteractiveShell.ast_node_interactivity='all'
# %config InlineBackend.figure_format = 'svg'

# %%
def get_regr_coefficients(coeff_df, wavelength='560', and_mlr_model=False):
    
    """This function extracts the Tecan data regression coefficients and
    them as an array. The simple regresssion coefficient are modified
    for application to the PBR pathlength, while the MLR coefficients are
    return as are."""
    
    ks = coeff_df.loc[wavelength].values[:4]

    
    return ks

def apply_model_basic(pbr_data, Ks, and_mlr_model=False):
    
    """This function applies the models to PBR A680, A720 data and returns a copy of the input
    dataframe and new calculated values. IFF the model hold true, then the values obtained here 
    should match those that are obtained at the the Tecan reader. At the very least the ratios
    should match.
    """
    tdf = pbr_data.copy()
    
    if and_mlr_model == False:

        tdf['B_p' ] = (Ks[1]*tdf['A750c'] - Ks[3]*tdf['A680c']) / (Ks[1]*Ks[2] - Ks[3]*Ks[0])
        tdf['C_p' ] = (Ks[0]*tdf['A750c'] - Ks[2]*tdf['A680c']) / (Ks[0]*Ks[3] - Ks[2]*Ks[1])
        tdf['SS_p'] = tdf['B_p'] + tdf['C_p']
        tdf['B/C_p'] = tdf['B_p'] / tdf['C_p']
    
    return tdf

# %%
path = '../data_o/calibration/community_calibration/created_models/reqd_corr_funcs_parameters.csv'

def get_corr_params(file_loc, model='A680_A750_560'):
    
    print(model)
    
    df = pd.read_csv(path, index_col=0)
    
    return df.loc[model].values

def  corr_func_Bsc(pB, pC, parameters, which_a2=None):
    
    # There are 3 options about which a2 to use,
    # a2 refers to the breadth of the correcting
    # parabola. These are either the:
        # mean
        # median
        # a2 @ [B]= 0 (Row12)
    
    
    a2s = parameters[:-2]
    hfit = parameters[-2:]
    # WHICH Parabolic BREADTH to use for correction
    if which_a2 =='mean':
        a2 = np.mean(a2s) # this is the mean
        
    elif which_a2 =='median':
        a2 = np.median(a2s) # this should be more robust to outliers
    
    # set as default
    else:
        a2 = -0.499525586 #global over 3 models... also this has the effect
        # of 'canceling out' the need for 'b' as 

    # given the fitted line avove, use poly1d to create a 
    # prediction function
    htor = np.poly1d(hfit)
    
    # takes in the predicted pB and spits out h in (h, k) the parabola
    # that lives at this pB... i.e. vertex is at (h,pB)
    lH = htor(pB)
    
    
    # IMPORTANT #
    # this is from an algebraic manipulation of the parabolic function
    # in polynomial and parabolic form where h = -b/2*a2 --- since we
    # "know: a2 and p_h is dependant on the concetration of B we 
    # estimate the likely value of b in f(x) = a2*x^2 + b*x + c
    b = np.multiply(-2*lH,a2 )    
    cv_tor = np.poly1d([a2, b, 0])
    
    return cv_tor(pC)

# %% [markdown]
# # Load & Model PreProcessed

# %%
# screen 4 folder
s4_pp = '/home/rdmtinez/Desktop/MScThesis/data_o/screens/screens_preprocessed_data/'
csv_list = [f for f in os.listdir(s4_pp) if 'sc4' in f]
csv_list
sc_c ,b_c,  b = [pd.read_csv(os.path.join(s4_pp, i), index_col=0) for i in csv_list]

# Model Predictions

### SLR

# models
params_slr= '/home/rdmtinez/Documents/B-IT MS Program/Masters Thesis/data_o/calibration/\
community_calibration/created_models/a680_a750_coefficients.csv' 
slr = pd.read_csv(params_slr, index_col=0)

ks = get_regr_coefficients(slr, '560')

sc_c, b_c,  b = [apply_model_basic(i, ks, False) for i in [sc_c ,b_c, b]]
# Out:
# ['sc4_non_supernatant_test_ratios_condition_sc+c.csv',
#  'sc4_non_supernatant_test_ratios_condition_b+c.csv',
#  'sc4_supernatant_test_ratio_control.csv']

# %% [markdown]
# # Spread of Predicted Values

# %%
for df in [sc_c, b_c, b]:
    df[['B_p', 'C_p']].plot(kind='hist', bins=50)

# %% [markdown]
# # Visualizations
#
# # SC + C

# %%
slr_predictions_SC = {}

# %%
sc_c ,b_c,  b = [pd.read_csv(os.path.join(s4_pp, i), index_col=0) for i in csv_list]
sc_c, b_c,  b = [apply_model_basic(i, ks, False) for i in [sc_c ,b_c, b]]


sc_c = sc_c.groupby(by=['t(h)', 'content', 'b_c_ratio']).agg('mean').reset_index()
b_c = b_c.groupby(by=['t(h)',  'content', 'b_c_ratio']).agg('mean').reset_index()
b = b.groupby(by=['t(h)',  'content', 'b_c_ratio']).agg('mean').reset_index()

# %%
sc_c.head(10)
sc_c.tail(10)

b_c.head()
sc_c.tail(10)

b.head()
# Out:
#    t(h)  content b_c_ratio  replicate      A680     A680c      A750     A750c  \
# 0     0    BLANK       1.6          1  0.091200 -0.017813  0.097900 -0.010167
# 1     0    BLANK        16          1  0.095167 -0.013847  0.100567 -0.007500
# 2     0    BLANK       160          1  0.097433 -0.011580  0.101200 -0.006867
# 3     0   CHLAMY       1.6          1  0.178233  0.069220  0.133867  0.025800
# 4     0   CHLAMY        16          1  0.105033 -0.003980  0.104633 -0.003433
# 5     0   CHLAMY       160          1  0.099333 -0.009680  0.101900 -0.006167
# 6     0  ICL_100       1.6          1  0.173167  0.064153  0.129933  0.021867
# 7     0  ICL_100        16          1  0.101967 -0.007047  0.101033 -0.007033
# 8     0  ICL_100       160          1  0.096433 -0.012580  0.100167 -0.007900
# 9     0  ICL_101       1.6          1  0.173000  0.063987  0.128967  0.020900
#
#         B_p       C_p      SS_p     B/C_p
# 0 -0.005307 -0.008168 -0.013475  1.067652
# 1 -0.002935 -0.006955 -0.009890  2.552893
# 2 -0.004212 -0.004922 -0.009134  3.317384
# 3 -0.019900  0.052366  0.032465 -0.383985
# 4 -0.004621 -0.000077 -0.004698 -3.062330
# 5 -0.004782 -0.003473 -0.008255  1.640681
# 6 -0.024490  0.051610  0.027120 -0.474486
# 7 -0.011004  0.001301 -0.009703 -2.580780
# 8 -0.005877 -0.004685 -0.010562  1.878733
# 9 -0.027116  0.052845  0.025729 -0.512274
#       t(h) content b_c_ratio  replicate      A680     A680c      A750  \
# 1006   162  ICL_24       160          1  0.147200  0.038187  0.133867
# 1007   162  ICL_41         -          1  0.117667  0.008653  0.115667
# 1008   162  ICL_41        16          1  0.151600  0.042587  0.132133
# 1009   162  ICL_41       160          1  0.147400  0.038387  0.130433
# 1010   162  ICL_48         -          1  0.120933  0.011920  0.117233
# 1011   162  ICL_48        16          1  0.147900  0.038887  0.129067
# 1012   162  ICL_48       160          1  0.142367  0.033353  0.127667
# 1013   162  ICL_60         -          1  0.116267  0.007253  0.115900
# 1014   162  ICL_60        16          1  0.150400  0.041387  0.132500
# 1015   162  ICL_60       160          1  0.146900  0.037887  0.134067
#
#          A750c       B_p       C_p      SS_p      B/C_p
# 1006  0.025800  0.023221  0.011482  0.034703   2.277784
# 1007  0.007600  0.010447 -0.000037  0.010410  -3.089802
# 1008  0.024067  0.011982  0.019887  0.031869   0.598739
# 1009  0.022367  0.012792  0.016912  0.029704   0.796022
# 1010  0.009167  0.010540  0.001909  0.012449 -22.117879
# 1011  0.021000  0.008056  0.019628  0.027684   0.407155
# 1012  0.019600  0.011605  0.014445  0.026050   0.816393
# 1013  0.007833  0.013082 -0.002232  0.010849  -6.223531
# 1014  0.024433  0.014733  0.017755  0.032488   0.838317
# 1015  0.026000  0.024229  0.010786  0.035015   2.280752
#    t(h) content b_c_ratio  replicate      A680     A680c      A750     A750c  \
# 0     0   BLANK         -        1.5  0.099650 -0.009363  0.102058 -0.006008
# 1     0   BLANK       1.6        1.5  0.132350  0.023337  0.127217  0.019150
# 2     0   BLANK        16        1.5  0.090617 -0.018397  0.096983 -0.011083
# 3     0   BLANK       160        1.5  0.145617  0.036603  0.124333  0.016267
# 4     0  CHLAMY       1.6        1.5  0.199600  0.090587  0.134800  0.026733
#
#         B_p       C_p      SS_p      B/C_p
# 0 -0.004754 -0.003294 -0.008048   2.417707
# 1  0.024193  0.001926  0.026119  -2.994774
# 2 -0.007207 -0.007557 -0.014764   4.567421
# 3 -0.002766  0.023743  0.020977 -18.489387
# 4 -0.046830  0.079110  0.032280  -0.528856
#       t(h) content b_c_ratio  replicate      A680     A680c      A750  \
# 1006   162  ICL_24       160          1  0.147200  0.038187  0.133867
# 1007   162  ICL_41         -          1  0.117667  0.008653  0.115667
# 1008   162  ICL_41        16          1  0.151600  0.042587  0.132133
# 1009   162  ICL_41       160          1  0.147400  0.038387  0.130433
# 1010   162  ICL_48         -          1  0.120933  0.011920  0.117233
# 1011   162  ICL_48        16          1  0.147900  0.038887  0.129067
# 1012   162  ICL_48       160          1  0.142367  0.033353  0.127667
# 1013   162  ICL_60         -          1  0.116267  0.007253  0.115900
# 1014   162  ICL_60        16          1  0.150400  0.041387  0.132500
# 1015   162  ICL_60       160          1  0.146900  0.037887  0.134067
#
#          A750c       B_p       C_p      SS_p      B/C_p
# 1006  0.025800  0.023221  0.011482  0.034703   2.277784
# 1007  0.007600  0.010447 -0.000037  0.010410  -3.089802
# 1008  0.024067  0.011982  0.019887  0.031869   0.598739
# 1009  0.022367  0.012792  0.016912  0.029704   0.796022
# 1010  0.009167  0.010540  0.001909  0.012449 -22.117879
# 1011  0.021000  0.008056  0.019628  0.027684   0.407155
# 1012  0.019600  0.011605  0.014445  0.026050   0.816393
# 1013  0.007833  0.013082 -0.002232  0.010849  -6.223531
# 1014  0.024433  0.014733  0.017755  0.032488   0.838317
# 1015  0.026000  0.024229  0.010786  0.035015   2.280752
#    t(h) content    b_c_ratio  replicate      A680     A680c      A750  \
# 0     0   BLANK       b_high          1  0.107833 -0.000922  0.112933
# 1     0   BLANK        b_low          1  0.111767  0.003011  0.114867
# 2     0   BLANK  sc_low-high          1  0.106667 -0.002089  0.111333
# 3     0  CHLAMY       b_high          1  0.109433  0.000678  0.113467
# 4     0  CHLAMY        b_low          1  0.100433 -0.008322  0.104100
#
#       A750c       B_p       C_p      SS_p     B/C_p
# 0 -0.000111  0.000953 -0.001048 -0.000095 -5.344780
# 1  0.001822  0.001204  0.001225  0.002428 -3.746534
# 2 -0.001711 -0.002157 -0.000177 -0.002334 -8.875953
# 3  0.000422  0.000307  0.000258  0.000564 -2.569774
# 4 -0.008944 -0.014882  0.002496 -0.012385 -6.706512

# %%
sc_c['content'].unique()
sc_c[sc_c['content']=='ICL_100']
# Out:
# array(['BLANK', 'CHLAMY', 'ICL_100', 'ICL_101', 'ICL_103', 'ICL_108',
#        'ICL_112', 'ICL_114B', 'ICL_115', 'ICL_116', 'ICL_117', 'ICL_118B',
#        'ICL_129A', 'ICL_129B', 'ICL_132', 'ICL_139A', 'ICL_144',
#        'ICL_160', 'ICL_162', 'ICL_163', 'ICL_170', 'ICL_172', 'ICL_184BA',
#        'ICL_186B', 'ICL_199', 'ICL_201', 'ICL_208B', 'ICL_20BA', 'ICL_24',
#        'ICL_41', 'ICL_48', 'ICL_60'], dtype=object)
#      t(h)  content b_c_ratio  replicate      A680     A680c      A750  \
# 6       0  ICL_100       1.6          1  0.173167  0.064153  0.129933
# 7       0  ICL_100        16          1  0.101967 -0.007047  0.101033
# 8       0  ICL_100       160          1  0.096433 -0.012580  0.100167
# 97      1  ICL_100         -          1  0.155400  0.046387  0.152867
# 134    20  ICL_100         -          1  0.122133  0.013120  0.124433
# 135    20  ICL_100       1.6          1  0.160167  0.051153  0.130733
# 136    20  ICL_100        16          1  0.113133  0.004120  0.112033
# 137    20  ICL_100       160          1  0.111200  0.002187  0.112533
# 260    44  ICL_100       1.6          1  0.151233  0.042220  0.129267
# 261    44  ICL_100        16          1  0.128100  0.019087  0.124867
# 262    44  ICL_100       160          1  0.132233  0.023220  0.126967
# 351    45  ICL_100         -          1  0.114700  0.005687  0.117600
# 387    70  ICL_100       1.6          1  0.169633  0.060620  0.143200
# 388    70  ICL_100        16          1  0.134133  0.025120  0.125633
# 389    70  ICL_100       160          1  0.131800  0.022787  0.126100
# 478    71  ICL_100         -          1  0.118167  0.009153  0.119633
# 510    97  ICL_100        16          1  0.142933  0.033920  0.135900
# 545    98  ICL_100         -          1  0.103300 -0.005713  0.105133
# 546    98  ICL_100       1.6          1  0.155033  0.046020  0.138167
# 547    98  ICL_100       160          1  0.147300  0.038287  0.135567
# 641   121  ICL_100       1.6          1  0.173367  0.064353  0.143300
# 642   121  ICL_100        16          1  0.136367  0.027353  0.122767
# 643   121  ICL_100       160          1  0.144800  0.035787  0.132000
# 732   122  ICL_100         -          1  0.118967  0.009953  0.119900
# 769   141  ICL_100         -          1  0.122867  0.013853  0.121667
# 770   141  ICL_100       1.6          1  0.179700  0.070687  0.146633
# 771   141  ICL_100        16          1  0.147067  0.038053  0.127067
# 772   141  ICL_100       160          1  0.147867  0.038853  0.131233
# 891   161  ICL_100       1.6          1  0.166267  0.057253  0.147200
# 926   162  ICL_100         -          1  0.115967  0.006953  0.116667
# 927   162  ICL_100        16          1  0.149400  0.040387  0.130267
# 928   162  ICL_100       160          1  0.153300  0.044287  0.138033
#
#         A750c       B_p       C_p      SS_p     B/C_p
# 6    0.021867 -0.024490  0.051610  0.027120 -0.474486
# 7   -0.007033 -0.011004  0.001301 -0.009703 -2.580780
# 8   -0.007900 -0.005877 -0.004685 -0.010562  1.878733
# 97   0.044800  0.068002 -0.006307  0.061696 -1.662939
# 134  0.016367  0.030160 -0.007345  0.022815 -4.194573
# 135  0.022667 -0.004061  0.033280  0.029219 -0.130042
# 136  0.003967  0.006003 -0.000541  0.005462 -1.430117
# 137  0.004467  0.010168 -0.003841  0.006327  0.480602
# 260  0.021200  0.004016  0.023718  0.027734  0.182463
# 261  0.016800  0.023150 -0.000136  0.023014 -8.341098
# 262  0.018900  0.023616  0.002149  0.025765  1.138417
# 351  0.009533  0.020285 -0.006854  0.013430 -2.867190
# 387  0.035133  0.019645  0.026991  0.046635  0.865765
# 388  0.017567  0.017034  0.006658  0.023692  2.685068
# 389  0.018033  0.021656  0.002882  0.024538 -3.307272
# 478  0.011567  0.021480 -0.005347  0.016132 -5.795097
# 510  0.027833  0.035161  0.002802  0.037962 -5.373960
# 545 -0.002933 -0.000734 -0.003113 -0.003847  3.486994
# 546  0.030100  0.025050  0.015331  0.040381  2.396923
# 547  0.027500  0.028108  0.009056  0.037164  3.945315
# 641  0.035233  0.014753  0.031759  0.046511  0.468685
# 642  0.014700  0.005455  0.013914  0.019369  0.447033
# 643  0.023933  0.021036  0.011130  0.032166 -6.693898
# 732  0.011833  0.021157 -0.004695  0.016462 -4.703438
# 769  0.013600  0.020961 -0.002215  0.018745 -1.397046
# 770  0.038567  0.015808  0.035086  0.050894  0.449956
# 771  0.019000  0.003301  0.021540  0.024840  0.174323
# 772  0.023167  0.014508  0.016323  0.030832  1.017229
# 891  0.039133  0.036149  0.016536  0.052685  2.280200
# 926  0.008600  0.015765 -0.003781  0.011984 -6.915509
# 927  0.022200  0.009520  0.019798  0.029318  0.518743
# 928  0.029967  0.027064  0.013248  0.040312  2.813069

# %% [markdown]
# # Without Corrections

# %%
def quickplot(dframe, kind):
    
    
    l = len(dframe['content'].unique())
    
    # Figure Settings

    axes = []
   
    if kind == 'NS' or 'NScr':
        fig, ax = plt.subplots(nrows=l, ncols=3, figsize=(12,60))
        gs = gridspec.GridSpec(l,3)
        
        for r in range(0,l):
            for c in [0,1,2]:
                axes.append(plt.subplot(gs[r,c]))
    else:
        fig, ax = plt.subplots(nrows=l, ncols=4, figsize=(12,60))
        gs = gridspec.GridSpec(l,4)
        
        for r in range(0,l):
            for c in [0,1,2,3]:
                axes.append(plt.subplot(gs[r,c]))
    
    axes = (ax for ax in axes)
    
    
    ratio = dframe['b_c_ratio'].unique()
    print(ratio)
    # Loop through each Strain
    
    for cont in dframe['content'].unique():
        
        #print(cont)
        #break
        try:

            component = ['C_p', 'B_p']


            df = dframe[dframe['content']==cont]

            #print(df)
            #wells = df['well'].unique()
            

            ax = next(axes)
            df[df['b_c_ratio']==ratio[-1]].plot(x='t(h)',
                        y=component, ax=ax,  style=['g-*', 'r-.'], legend=False)

            ax.set_title(kind+' @ ratio: '+ratio[-1])
            ax.set_ylabel('['+cont+'] & [C]')
            ax.set_ylim(bottom=-0.03, top=.10)



            ax = next(axes)
            df[df['b_c_ratio']==ratio[-2]].plot(x='t(h)',
                        y=component, ax=ax,  style=['g-*', 'r-.'], legend=False)
            
            ax.set_title(kind+' @ ratio: '+ratio[-2])
            ax.set_ylim(bottom=-0.03, top=.10)



            ax=next(axes)
            df[df['b_c_ratio']==ratio[-3]].plot(x='t(h)',
                        y=component, ax=ax,  style=['g-*', 'r-.'], legend=False)
            
            ax.set_title(kind+' @ ratio '+ratio[-3])
            ax.set_ylim(bottom=-0.03, top=.10)



            if len(ratio)>3:

                # SC only
                ax=next(axes)
                df[df['b_c_ratio']==ratio[0]].plot(x='t(h)',
                        y=component, ax=ax,  style=['g-*', 'r-.'], legend=False)

                ax.set_title('['+cont+'] @ ratio '+ratio[0])
                ax.set_ylim(bottom=-0.03, top=.10)



        
        except:
        
            continue
            
    plt.tight_layout()

# %%
sc_c.mean()
# Out:
# t(h)         82.059055
# replicate     1.000000
# A680          0.138124
# A680c         0.029111
# A750          0.127144
# A750c         0.019078
# B_p           0.015957
# C_p           0.009641
# SS_p          0.025598
# B/C_p         0.452493
# dtype: float64

# %%
quickplot(sc_c, kind='SC+C')
# Out:
# ['1.6' '16' '160' '-']

# %%
quickplot(b_c, kind='B+C')

# %%
quickplot(b, kind='NS')

# %% [markdown]
# # Signal Correction Version

# %%
  ##### CORRECTING #####
    
    # CORRECT pB
    # use the uncorrected values to correct these 

corpars_path = '../data_o/calibration/community_calibration/created_models/reqd_corr_funcs_parameters.csv'
parameters = get_corr_params(corpars_path, 'A680_A750_560')

# %%
parameters
sc_c.head()

# %%
for df in [sc_c, b_c, b]:
    
    df['B_o'] = df['B_p'].copy()
    df['cv'] = df.apply(lambda x: corr_func_Bsc(x['B_p'], x['C_p'], parameters,
                                                which_a2=None), axis=1)
    df['B_p'] = df['B_o'] - df['cv']

# %%
for df in [sc_c, b_c, b]:
    df.head(8)

# %%
quickplot(sc_c, 'SC+Ccr')

# %%
quickplot(b_c, 'B_Ccr')

# %%
quickplot(b, 'NScr')
