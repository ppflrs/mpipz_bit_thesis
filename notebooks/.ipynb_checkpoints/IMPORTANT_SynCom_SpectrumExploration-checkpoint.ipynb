# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import os
import scipy

from sklearn import preprocessing

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set(style='whitegrid')

from os.path import join as pjoin

import itertools as it

# %config InteractiveShell.ast_node_interactivity='all'
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Data

# %%
path= '/home/rdmtinez/Desktop/MScThesis/data_o/calibration/single_species_calibration/parsed_data'

#load data
df = pd.read_csv(pjoin(path, 'ss_total_spectrum.csv'), index_col=0)

df.head()

# %%
# subtract 96th well's values from the rest as this 
# is the control well, i.e. BLANK
for col in df.columns[4:].values:
    #subtract 'blank' well values
    df.loc[:,col] = df.loc[:,col] - df.loc['H12',col]

# %% [markdown]
# # Explore

# %%
hwells = df[df.index.str.contains('H')]
zwells = df[df.index.str.contains('12')]
rwells = hwells.append(zwells).drop(['row', 'col'], axis=1)
#lambdas = [440, 485, 520, 560, 600, 635, 680, 720, 750, 800]
lambdas = [440, 485, 560, 600, 680, 720, 750]

# %%
def corr_map(dframe, lambdas, method='pearson'):
    """Plots the minimum of the pairwise correlations give, and is used to find
    the best possible Regress TO wavelength. This is the one that is least correlated
    to 720 AND 680... 
    
    The difference between the correlations to 720 and 680 is then taken by hmap_diffs
    with the thinking being that the greater the difference will show
    """
    corr = dframe.corr(method=method)
    crmp = corr.style.background_gradient(cmap='coolwarm')
    cmin  = pd.DataFrame(pd.Series(corr.min(), name='min'))
    cmin['x'] = [int(i) for i in corr.index.values]
    cmin = cmin[['x','min']]
    fig,ax = plt.subplots(figsize=(8,5))
    cmin.plot(x='x', y='min', ax=ax,  style='-.')
    ax.vlines(x=lambdas, ymin=cmin['min'].min(), ymax=cmin['min'].max(), colors=['y', 'r'] )
    
    ax.set_ylabel("λ's Min Pearson-Corr Value")
    ax.set_xlabel('λ')
    ax.set_title("λ-λ Correlation Minimums")
    hmap_diffs(corr, lambdas)
    hmap_minsum(corr,lambdas)

# %%
def hmap_diffs(hmap, lambdas):

    hdf = hmap.loc[['680','720']]
    hdf.loc['diff'] = pd.Series(hdf.loc['680'] - hdf.loc['720']).abs()
    hdf.loc['x'] = [int(i) for i in hdf.columns.values]
    hdf = hdf.transpose()
    hdf.head()
    
    fig, ax = plt.subplots(figsize=(5,3))
    hdf.plot(x='x' ,y='diff',style='-.', ax=ax)
    ax.vlines(x=lambdas, ymin=hdf['diff'].min(), ymax=hdf['diff'].max())

# %%
def hmap_minsum(hmap, lambdas):

    hdf = hmap.loc[['680','720']]
    hdf.loc['minsum'] = pd.Series((hdf.loc['680'] + hdf.loc['720'])).abs()
    hdf.loc['x'] = [int(i) for i in hdf.columns.values]
    hdf = hdf.transpose()
    
    fig, ax = plt.subplots(figsize=(5,3))
    hdf.plot(x='x' ,y='minsum',style='-.', ax=ax)
    ax.vlines(x=lambdas, ymin=hdf['minsum'].min(), ymax=hdf['minsum'].max())

# %%
hmap_pearson = corr_map(rwells, lambdas)
hmap_kendall = corr_map(rwells, lambdas, method='kendall')
hmap_spearman = corr_map(rwells, lambdas, method='spearman')

# %%
#hmap_diffs(hmap_pearson, lambdas)
#hmap_diffs(hmap_kendall, lambdas)
#hmap_diffs(hmap_spearman, lambdas)

# %% [markdown]
# DataFrame.corr() is as

# %% [markdown]
# The modeling approach has been to apply Beer-Lambert's Law such that we determine the extinction coefficients (k) for bacteria and chlamy at two predetermined wavelengths (A680, A720) as these are the wavelengths that the PBR experiments measure and no other. We then regress back to another wavelength (and eventually back to cell counts) and use these values to get a ratio that we can compare against other empirical ratio data from the same exeperiment. In order to determine which other wavelength we should regress back to, we need to find one which is least correlated to '680' and '720'. This is done to avoid collinearity effects
#
# To achieve this we looked at chlamy and bacteria gradients at the visible light spectrum and took their correlation values.
#
# that Looking at the bacteria and chalmy under the teacan microplate at the entire visible light spectrum allows us to determine which OTHER wavelength we can use as our response variable. The best wavelength other than 680 and 720 would be those which have
#
# basis for the model
# My objective here was to try and determine which wavele

# %%
# look at the interesting parts of the 96 plate
# A1, A12, H1, H12
hwells = df[df.index.str.contains('H')]
zwells = df[df.index.str.contains('12')]
wells = ['A1', 'A12', 'H1', 'H12']

# %%
cwellst = df.loc[wells].transpose().drop(labels=['row', 'col'], axis=0)
hwellst = hwells.transpose().drop(labels=['row', 'col'], axis=0)
zwellst = zwells.transpose().drop(labels=['row', 'col'], axis=0)

# %%
cwellst.head()
hwellst.head()
zwellst.head()
# Out:
# well      A1     A12      H1     H12
# 320   1.2715  0.8139  1.0345  0.4316
# 325   1.2378    0.78  1.0036  0.4019
# 330   0.8349  0.3728  0.6053       0
# 335   0.8356  0.3676   0.611       0
# 340   0.8319  0.3625  0.6115       0
# well      H1      H2      H3      H4      H5      H6      H7      H8      H9  \
# 320   1.0345  1.0014   0.867  0.8479  0.7856  0.7431  0.6808  0.6348  0.5597
# 325   1.0036  0.9701  0.8353  0.8166  0.7553   0.712  0.6496  0.6033  0.5304
# 330   0.6053  0.5715  0.4341  0.4148  0.3557  0.3105  0.2478  0.2007  0.1294
# 335    0.611  0.5765  0.4363  0.4167  0.3586  0.3117  0.2482  0.2008  0.1306
# 340   0.6115  0.5766  0.4353  0.4158  0.3586  0.3107  0.2472  0.1995  0.1309
#
# well     H10         H11     H12
# 320    0.501      0.4401  0.4316
# 325   0.4717      0.4111  0.4019
# 330   0.0706  0.00959998       0
# 335   0.0712  0.00999999       0
# 340   0.0714      0.0101       0
# well     A12     B12     C12     D12     E12     F12     G12     H12
# 320   0.8139  0.7592  0.6893   0.634  0.5957   0.507  0.4646  0.4316
# 325     0.78  0.7264  0.6568  0.6024  0.5646   0.476  0.4349  0.4019
# 330   0.3728  0.3207  0.2517  0.1981  0.1606  0.0726  0.0323       0
# 335   0.3676  0.3166  0.2483  0.1954  0.1585  0.0711  0.0318       0
# 340   0.3625   0.313  0.2451  0.1931  0.1566  0.0698  0.0312       0

# %%
slambdas = [str(i) for i in lambdas]

# %%
cwellst['wav'] = cwellst.index.values.astype(int)
hwellst['wav'] = hwellst.index.values.astype(int)
zwellst['wav'] = zwellst.index.values.astype(int)

# %%
def quickplot():

    fig, ax = plt.subplots(figsize=(9,6))
    cwellst.plot(x='wav', style='.', ax=ax)
    lambdas = [440, 485, 560, 600, 680, 720, 750]    
    ax.vlines(x=lambdas, ymin=0, ymax=1.4, colors=['y', 'r'], alpha=.85)
    
    
    
    ax.set_ylabel("Absorbance")
    ax.set_xlabel('λ')
    ax.set_title("Specific Well's Absorbance Spectrum")
    
    
    ax.legend(loc='upper left')
    #ax.hlines(y=[.26, .35, .52], xmin=350, xmax=600)
    # 0 bacteria + chlamy (MAX)
    # 11 bacteria only
    # 84 chlamy only
    # 95 BLANK

    # a metabolite in the medium must be absorbing at the lower wavelengths


    # What is the sum of the values at 560:
        # b = .26
        # c = .35
        # ---------
            # .61


    # 560T = .52

# %%
quickplot()

# %%
fig, ax = plt.subplots(figsize=(9,6))
hwellst.plot(x='wav', style='.', ax=ax)

# %%
fig, ax = plt.subplots(figsize=(9,6))
zwellst.plot(x='wav', style='.', ax=ax)

# %% [markdown]
#
#     In the above graph I note that at higher-energe wavelengths the bacterial strain present at A12 tends to absorb more light; and that the absorbance gradually decreases as the wavelength increaes. Recall that the concentration of bacterium inside this well is constant, thus the decrease here is due to less light being absorbed. As the wavelength increases the contents of the bacterial cell are much smaller than the lightwave itself thus they are less readily absorbed. We do not yet know what the cell count at this well is, which is extremely unfortunate.

# %%
df[].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col1 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col2 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col3 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col4 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col6 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col7 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col8 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col9 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row0_col10 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col0 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col2 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col3 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col4 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col5 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col6 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col7 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col8 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col9 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row1_col10 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col0 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col1 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col3 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col4 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col5 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col6 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col7 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col8 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col9 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row2_col10 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col0 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col2 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col5 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col6 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col7 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col8 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col9 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row3_col10 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col0 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col1 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col2 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col5 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col6 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col7 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col8 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col9 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row4_col10 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row5_col0 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row5_col1 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row5_col2 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row5_col3 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_79312a5a_e6bd_11e9_a760_45358539b7e8row5_col4 {
#             background-color:  #ba162b;
#             color:  #f1f1f1

# %%
regress_to = ['440', '480', '500', '560', '635', '680', '720', '750', '800']

# %%
#hwells.iloc[:,5:].corr().style.background_gradient(cmap='coolwarm')

# %%
rwells = hwells.append(zwells)
rwells.head()
# Out:
#      row  col     320     325     330     335     340     345     350     355  \
# well
# H1     H    1  1.0345  1.0036  0.6053  0.6110  0.6115  0.6035  0.5930  0.5844
# H2     H    2  1.0014  0.9701  0.5715  0.5765  0.5766  0.5689  0.5578  0.5487
# H3     H    3  0.8670  0.8353  0.4341  0.4363  0.4353  0.4288  0.4201  0.4119
# H4     H    4  0.8479  0.8166  0.4148  0.4167  0.4158  0.4097  0.4013  0.3943
# H5     H    5  0.7856  0.7553  0.3557  0.3586  0.3586  0.3549  0.3497  0.3454
#
#       ...     755     760     765     770     775     780     785     790  \
# well  ...
# H1    ...  0.2625  0.2602  0.2579  0.2553  0.2535  0.2516  0.2497  0.2480
# H2    ...  0.2410  0.2390  0.2367  0.2343  0.2324  0.2307  0.2289  0.2275
# H3    ...  0.1826  0.1808  0.1791  0.1774  0.1756  0.1741  0.1725  0.1710
# H4    ...  0.1746  0.1728  0.1710  0.1693  0.1676  0.1664  0.1649  0.1638
# H5    ...  0.1577  0.1565  0.1551  0.1538  0.1525  0.1516  0.1505  0.1496
#
#          795     800
# well
# H1    0.2462  0.2448
# H2    0.2258  0.2243
# H3    0.1695  0.1682
# H4    0.1625  0.1614
# H5    0.1485  0.1476
#
# [5 rows x 99 columns]

# %%
hmap = rwells.iloc[:,2:].corr(method='spearman')#.style.background_gradient(cmap='coolwarm')
#rwells.iloc[:,2:].corr().min()
#hmap

# %%
hmap.loc[['680','720']].style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col7 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col8 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col9 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col10 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col11 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col12 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col13 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col14 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col15 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col16 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col17 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col18 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col19 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col20 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col21 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col22 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col23 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col24 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col25 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col26 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col27 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col28 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col29 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col30 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col31 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col32 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col33 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col34 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col35 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col36 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col37 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col38 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col39 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col40 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col41 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col42 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col43 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col44 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col45 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col46 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col47 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col48 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col49 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col50 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col51 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col52 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col53 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col54 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col55 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col56 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col57 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col58 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_797e1e50_e6bd_11e9_a760_45358539b7e8row0_col59 {
#             background

# %%
hdf = hmap.loc[['680','720']]
hdf.loc['diff'] = pd.Series(hdf.loc['680'] - hdf.loc['720']).abs()
hdf.loc['x'] = [int(i) for i in hdf.columns.values]
hdf = hdf.transpose()
hdf.head()
# Out:
#           680       720      diff      x
# 320  0.977427  0.980436  0.003010  320.0
# 325  0.977427  0.980436  0.003010  325.0
# 330  0.977427  0.980436  0.003010  330.0
# 335  0.978932  0.978932  0.000000  335.0
# 340  0.983446  0.974417  0.009029  340.0

# %%
fig, ax = plt.subplots(figsize=(9,6))
hdf.plot(x='x' ,y='diff',style='-.', ax=ax)
ax.vlines(x=[440, 485, 515, 560, 565, 635, 680, 720, 750], ymin=0, ymax=.12)

# %%
corr_min = pd.DataFrame(pd.Series(rwells.iloc[:,2:].corr().min(), name='min'))
# create an x-axis to be able to set vertical lines
corr_min['x'] = [int(i) for i in corr_min.index.values]

# %%
corr_min = corr_min[['x','min']]

# %%
corr_min.head()

# %%
fig,ax = plt.subplots()
lambdas = [440, 485, 515, 520, 560, 600, 635, 680, 720, 750, 800]
corr_min.plot(x='x', y='min', ax=ax, figsize=(9,6))
ax.vlines(x=lambdas, ymin=0.840, ymax=1, colors=['y', 'r'] )
