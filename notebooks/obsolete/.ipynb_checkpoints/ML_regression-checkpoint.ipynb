# %%
import numpy as np
import pandas as pd
import os
import scipy

from sklearn import preprocessing

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set(style='whitegrid')

import itertools as it

# %config InteractiveShell.ast_node_interactivity='all'
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Data

# %%
tecan_main = '/home/rdmtinez/Documents/B-IT MS Program/Masters Thesis/data/abs-flu/exp1/tecan_results/abs-fluo_exp1_main.csv'
df_main = pd.read_csv(tecan_main, index_col=0)
df_tmp = df_main.copy()

# %% [markdown]
# # Pre-Processing

# %%
# for the standardization of the fluorescence signal
from sklearn.preprocessing import StandardScaler

# %%
# reduction of parameter variables
df_main = df_main[['bact_cnt', 'chlamy_cnt', 'corr_abs_680', 'corr_abs_750', 'corr_fluo', 'log(corr_fluo)']]
df_main.head()
# Out:
#    bact_cnt  chlamy_cnt  corr_abs_680  corr_abs_750  corr_fluo  log(corr_fluo)
# 0     0.200        0.25        0.7210        0.4146     4666.0        3.668945
# 1     0.175        0.25        0.7822        0.4155     4832.0        3.684127
# 2     0.150        0.25        0.6925        0.3829     4638.0        3.666331
# 3     0.125        0.25        0.6981        0.3593     4775.0        3.678973
# 4     0.100        0.25        0.6788        0.3414     4936.0        3.693375

# %%
# ensure that variables follow a normal distribution
for col in df_main.columns:
    break
    col
    fig = scipy.stats.probplot(df_main[col], dist='norm', plot=plt)
    plt.show()

# %%
# checking for Multicolinearity
# we already know that our measurements (Abs and Fluo) are highly dependant
# on the concentration of Chlamy, and therefore we will drop this column
# during the multiple-linear regression fitting and let the other variables
# camputure the variability of [B]

check=['corr_abs_680', 'corr_abs_750', 'corr_fluo', 'log(corr_fluo)']
df_main[check].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_9aab7346_8562_11e9_9517_b722507084c8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row0_col1 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row0_col2 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row0_col3 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row1_col0 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row2_col0 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row2_col1 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row2_col3 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row3_col2 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_9aab7346_8562_11e9_9517_b722507084c8row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_9aab7346_8562_11e9_9517_b722507084c8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >corr_abs_680</th>        <th class="col_heading level0 col1" >corr_abs_750</th>        <th class="col_heading level0 col2" >corr_fluo</th>        <th class="col_heading level0 col3" >log(corr_fluo)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9aab7346_8562_11e9_9517_b722507084c8level0_row0" class="row_heading level0 row0" >corr_abs_680</th>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row0_col1" class="data row0 col1" >0.934561</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row0_col2" class="data row0 col2" >0.796077</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row0_col3" class="data row0 col3" >0.602894</td>
#             </tr>
#             <tr>
#                         <th id="T_9aab7346_8562_11e9_9517_b722507084c8level0_row1" class="row_heading level0 row1" >corr_abs_750</th>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row1_col0" class="data row1 col0" >0.934561</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row1_col2" class="data row1 col2" >0.568538</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row1_col3" class="data row1 col3" >0.479698</td>
#             </tr>
#             <tr>
#                         <th id="T_9aab7346_8562_11e9_9517_b722507084c8level0_row2" class="row_heading level0 row2" >corr_fluo</th>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row2_col0" class="data row2 col0" >0.796077</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row2_col1" class="data row2 col1" >0.568538</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row2_col3" class="data row2 col3" >0.76481</td>
#             </tr>
#             <tr>
#                         <th id="T_9aab7346_8562_11e9_9517_b722507084c8level0_row3" class="row_heading level0 row3" >log(corr_fluo)</th>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row3_col0" class="data row3 col0" >0.602894</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row3_col1" class="data row3 col1" >0.479698</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row3_col2" class="data row3 col2" >0.76481</td>
#                         <td id="T_9aab7346_8562_11e9_9517_b722507084c8row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # ML Parameter Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# ALL IN and then remove predictor-wise
# SL = 0.05 ... consider the predictor
# with highest P-value, and then remove if P > SL

# check as many possible models and then choose Akaike best

# %% [markdown]
# # Fit Multiple Linear Regression to [C]

# %%
#X = df_main[['corr_abs_680', 'corr_abs_750', 'log(corr_fluo)']].values # R-sq = 0.936
X = df_main[['corr_abs_680', 'corr_abs_750']].values # R-sq = .934
#X = df_main[['corr_abs_680', 'log(corr_fluo)']].values # R-sq = .859
#X = df_main[['corr_abs_750', 'log(corr_fluo)']].values # R-sq = .677

yc = df_main[['chlamy_cnt']].values
Xtrn, Xtst, ytrn, ytst = train_test_split(X, yc, test_size=0.1, random_state=77)

regressor = LinearRegression().fit(Xtrn,ytrn)
print('Coefficients: ', regressor.coef_[0])
# Out:
# Coefficients:  [ 0.68140123 -0.6624534 ]

# %%
# statistics on the regression above

# note that the models are only slightly different
# this is due to the the statsmodel library requiring
# an extra dimension of ONEs as constants see below...
X = np.append(arr=np.ones((96,1)).astype(int), values=X, axis=1)
Xopt = X[:,[0,1,2]]

regressor_OLS = sm.OLS(endog=yc, exog=Xopt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     659.9
# Date:                Sun, 02 Jun 2019   Prob (F-statistic):           1.13e-55
# Time:                        20:17:18   Log-Likelihood:                 233.73
# No. Observations:                  96   AIC:                            -461.5
# Df Residuals:                      93   BIC:                            -453.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0049      0.005     -0.963      0.338      -0.015       0.005
# x1             0.6810      0.030     22.873      0.000       0.622       0.740
# x2            -0.6512      0.057    -11.333      0.000      -0.765      -0.537
# ==============================================================================
# Omnibus:                       78.265   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              899.127
# Skew:                          -2.369   Prob(JB):                    5.71e-196
# Kurtosis:                      17.224   Cond. No.                         32.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#df_tmp['C_mlr'] = regressor.predict(df_main[['corr_abs_680', 'corr_abs_750', 'log(corr_fluo)']])
#df_tmp['C_mlr'] = regressor.predict(df_main[['corr_abs_680', 'log(corr_fluo)']])
df_tmp['C_mlr'] = regressor.predict(df_main[['corr_abs_680', 'corr_abs_750']])

# %% [markdown]
# # Fit Multiple Linear Regression to [B]

# %%
X = df_main[['corr_abs_750', 'corr_abs_680']].values # R-sq = .978
#X = df_main[['corr_abs_680', 'corr_abs_750', 'log(corr_fluo)']].values # R-sq = .977

yb= df_main[['bact_cnt']].values

Xtrn, Xtst, ytrn, ytst = train_test_split(X, yb, test_size=0.1, random_state=77)
regressor = LinearRegression().fit(Xtrn, ytrn)
print('Coefficients: ', regressor.coef_[0])
# Out:
# Coefficients:  [ 1.6731363  -0.70549502]

# %%
# statistics on the regression above

# note that the models are only slightly different
# this is due to the the statsmodel library requiring
# an extra dimension of ONEs as constants see below...

X = np.append(arr=np.ones((96,1)).astype(int), values=X, axis=1)
#Xopt = X[:,[0,1,2,3]]
Xopt = X[:,[0,1,2]]

regressor_OLS = sm.OLS(endog=yb, exog=Xopt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     2068.
# Date:                Sun, 02 Jun 2019   Prob (F-statistic):           8.15e-78
# Time:                        20:17:25   Log-Likelihood:                 305.34
# No. Observations:                  96   AIC:                            -604.7
# Df Residuals:                      93   BIC:                            -597.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0059      0.002      2.475      0.015       0.001       0.011
# x1             1.6592      0.027     60.881      0.000       1.605       1.713
# x2            -0.6993      0.014    -49.517      0.000      -0.727      -0.671
# ==============================================================================
# Omnibus:                        0.551   Durbin-Watson:                   1.498
# Prob(Omnibus):                  0.759   Jarque-Bera (JB):                0.216
# Skew:                          -0.086   Prob(JB):                        0.898
# Kurtosis:                       3.157   Cond. No.                         32.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#df_tmp['B_mlr'] = regressor.predict(df_main[['corr_abs_680', 'corr_abs_750', 'log(corr_fluo)']])
df_tmp['B_mlr'] = regressor.predict(df_main[['corr_abs_750', 'corr_abs_680']])

# %%
df_main = df_tmp.copy()
#df_tmp.head()
df_main.head()
# Out:
#   row  col  chlamy_cnt  bact_cnt  abs_680  blank_680  corr_abs_680  fluo_680  \
# 0   A    1        0.25     0.200   0.8037     0.0827        0.7210    4669.0
# 1   B    1        0.25     0.175   0.8649     0.0827        0.7822    4835.0
# 2   C    1        0.25     0.150   0.7752     0.0827        0.6925    4641.0
# 3   D    1        0.25     0.125   0.7808     0.0827        0.6981    4778.0
# 4   E    1        0.25     0.100   0.7615     0.0827        0.6788    4939.0
#
#    blank_fluo  corr_fluo  log(corr_fluo)  abs_750  blank_750  corr_abs_750  \
# 0         3.0     4666.0        3.668945   0.5047     0.0901        0.4146
# 1         3.0     4832.0        3.684127   0.5056     0.0901        0.4155
# 2         3.0     4638.0        3.666331   0.4730     0.0901        0.3829
# 3         3.0     4775.0        3.678973   0.4494     0.0901        0.3593
# 4         3.0     4936.0        3.693375   0.4315     0.0901        0.3414
#
#       C_mlr     B_mlr
# 0  0.213576  0.190188
# 1  0.254682  0.148518
# 2  0.215156  0.157256
# 3  0.234606  0.113820
# 4  0.233313  0.097486

# %% [markdown]
# # Verification of Multiple Linear Regression Models

# %% [markdown]
#
#     The better the models are to 'Truth', the closer the values will trace along the  1:1 curve
#
# # $\hat{[B]} $$_{mlr}$

# %%
fig = plt.figure(figsize=(8,10))
gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(fig.add_subplot(gs[r,c]))

sns.scatterplot(x='bact_cnt', y='B_mlr', data=df_main, hue='row',
                palette=sns.color_palette('YlOrRd_r', 8), ax=axes[0])

handles, labels = axes[0].get_legend_handles_labels()
axes[0].legend(handles[::-1], labels[:-9:-1], title='[B] gradient')
axes[0].set_title('Predicted vs. Actual [B]')
axes[0].set_ylabel('$\hat{[B]}$$_{mlr}$')
axes[0].set_xlabel('$[B]_{known}$')

axes[0].plot((0,1), 'r--',)
axes[0].set_xlim(left=-0.01, right=.25)
axes[0].set_ylim(bottom=-0.01, top=.25)



sns.scatterplot(x='bact_cnt', y='B_mlr', data=df_main, hue='col',
                palette=sns.color_palette("YlGn_r", 12), ax=axes[1])

handles, labels = axes[1].get_legend_handles_labels()
axes[1].legend(handles[::-1], labels[:-13:-1], title='[C] gradient')
axes[1].set_ylabel('$\hat{[B]}$$_{mlr}$')
axes[1].set_xlabel('$[B]_{known}$')

axes[1].set_title('Predicted vs. Actual [B]')
axes[1].plot((0,1), 'r--',)
axes[1].set_xlim(left=-0.01, right=.25)
axes[1].set_ylim(bottom=-0.01, top=.25)


plt.suptitle("[Bacteria] Predictions Using Multiple Linear Regression Models", y=.95)

fig.suptitle("$A_{680}$ Predictions Using Simple Linear Regression Models", y=.95)
fig.subplots_adjust(hspace=.3)
fig.savefig("Predicted A680 with SLR Models")

plt.tight_layout()
# Out:
# Text(0.5, 1.03, '[Bacteria] Predictions Using Multiple Linear Regression Models')
# Text(0.5, 1.0, 'Predicted vs. Actual [B]')
# Text(0, 0.5, '$\\hat{[B]}$$_{mlr}$')
# Text(0.5, 0, '$[B]_{known}$')
# (-0.01, 0.25)
# (-0.01, 0.25)
# Text(0, 0.5, '$\\hat{[B]}$$_{mlr}$')
# Text(0.5, 0, '$[B]_{known}$')
# Text(0.5, 1.0, 'Predicted vs. Actual [B]')
# (-0.01, 0.25)
# (-0.01, 0.25)

# %% [markdown]
# # $\hat{[C]}$$_{mlr}$

# %%
plt.figure(figsize=(8,10))
gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))


sns.scatterplot(x='chlamy_cnt', y='C_mlr', data=df_main, hue='row',
                palette=sns.color_palette("YlOrRd_r", 8), ax=axes[0])

plt.suptitle("[Chlamy] Predictions Using Multiple Linear Regression Models",
            y=1.03)

handles, labels = axes[0].get_legend_handles_labels()
axes[0].legend(handles[::-1], labels[:-9:-1], title='[B] gradient')
axes[0].set_title('Predicted vs. Actual [C]')
axes[0].set_ylabel('$\hat{[C]}$$_{pred}$')
axes[0].set_xlabel('$[C]_{known}$')

axes[0].plot((0,1), 'r--')
axes[0].set_xlim(left=-0.01, right=.30)
axes[0].set_ylim(bottom=-0.01, top=.30)



sns.scatterplot(x='chlamy_cnt', y='C_mlr', data=df_main, hue='col',
                      palette=sns.color_palette("YlGn_r", 12), ax=axes[1])

handles, labels = axes[1].get_legend_handles_labels()
axes[1].legend(handles[::-1], labels[:-13:-1], title='[C] gradient')
axes[1].set_title('Predicted vs. Actual [C]')
axes[1].set_ylabel('$\hat{[C]}$$_{pred}$')
axes[1].set_xlabel('$[C]_{known}$')

axes[1].plot((0,1),'r--')
axes[1].set_xlim(left=-0.01, right=.30)
axes[1].set_ylim(bottom=-0.01, top=.30)

plt.tight_layout()
# Out:
# Text(0.5, 1.03, '[Chlamy] Predictions Using Multiple Linear Regression Models')
# Text(0.5, 1.0, 'Predicted vs. Actual [C]')
# Text(0, 0.5, '$\\hat{[C]}$$_{pred}$')
# Text(0.5, 0, '$[C]_{known}$')
# (-0.01, 0.3)
# (-0.01, 0.3)
# Text(0.5, 1.0, 'Predicted vs. Actual [C]')
# Text(0, 0.5, '$\\hat{[C]}$$_{pred}$')
# Text(0.5, 0, '$[C]_{known}$')
# (-0.01, 0.3)
# (-0.01, 0.3)

# %% [markdown]
# # Predict $B_{[C]}$$_{mlr}7$ and $B_{[C]}$$_{mlr}6$
#
#     These predictions are meant to check whether combining the [C]_pred from the MLR
#     models enhances the predictions of [B] from the SLR models....
#
#
#     #NOTE:
#     # IT DOESN'T!

# %%
fitted = '/home/rdmtinez/Documents/B-IT MS Program/Masters Thesis/data/regression/regression_fitted_parameters.csv' 
fitted = pd.read_csv(fitted, index_col=0)
fitted.head()

# k_C comes from the A680 signal when we hold B=0 or constant
# k_C * [C] the same goes for the other signals

k_C = fitted['A680_B'][0]
k_B = fitted['A680_C'][0]
kp_C = fitted['A750_B'][0]
kp_B = fitted['A750_C'][0]
# Out:
#      A680_B    A680_C    A750_B    A750_C      F680_B
# 0  2.519103  1.237138  1.111135  1.141418  586.359911
# 1 -0.009530 -0.008192 -0.009239 -0.009334  497.401393

# %% [markdown]
# We were hoping to use the Fluorescence signal to estimate the
# concentration of Chlamy and then hoped to use that value to
# regress back to the concentration of bacteria. However, a good
# model to regress back to $[C]_{kwn}$ from the flurescence signal is
# not trivial and difficult. Therefore I used a multiple linear
# regression to arrive at $[C]_{prd}$ and then use the simple linear
# regression models to arrive at $[B]_{prd}$ $[B]_{prd} = \frac{A_{680}-\mathit{k_C}[C]}{\mathit{k_B}} $
# or $[B]_{prd} = \frac{A_{750}-\mathit{k'_{C}}[C]}{\mathit{k'_{B}}} $, however it doesn't seem very fruitful, as the plots do not concord very well

# %%
df_tmp['B_[c]_mlr7'] = (df_tmp['corr_abs_750'] - kp_C*df_tmp['C_mlr']) / kp_B

# %%
df_tmp['B_[c]_mlr6']= (df_tmp['corr_abs_680'] - k_C*df_tmp['C_mlr']) / k_B

# %%
df_main = df_tmp.copy()
df_main.head()
# Out:
#   row  col  chlamy_cnt  bact_cnt  abs_680  blank_680  corr_abs_680  fluo_680  \
# 0   A    1        0.25     0.200   0.8037     0.0827        0.7210    4669.0
# 1   B    1        0.25     0.175   0.8649     0.0827        0.7822    4835.0
# 2   C    1        0.25     0.150   0.7752     0.0827        0.6925    4641.0
# 3   D    1        0.25     0.125   0.7808     0.0827        0.6981    4778.0
# 4   E    1        0.25     0.100   0.7615     0.0827        0.6788    4939.0
#
#    blank_fluo  corr_fluo  log(corr_fluo)  abs_750  blank_750  corr_abs_750  \
# 0         3.0     4666.0        3.668945   0.5047     0.0901        0.4146
# 1         3.0     4832.0        3.684127   0.5056     0.0901        0.4155
# 2         3.0     4638.0        3.666331   0.4730     0.0901        0.3829
# 3         3.0     4775.0        3.678973   0.4494     0.0901        0.3593
# 4         3.0     4936.0        3.693375   0.4315     0.0901        0.3414
#
#       C_mlr     B_mlr  B_[c]_mlr7  B_[c]_mlr6
# 0  0.213576  0.190188    0.155323    0.147905
# 1  0.254682  0.148518    0.116096    0.113674
# 2  0.215156  0.157256    0.126012    0.121651
# 3  0.234606  0.113820    0.086402    0.086574
# 4  0.233313  0.097486    0.071979    0.073606

# %% [markdown]
# #  $\hat{[B]}_{[c]}$$_{mlr}7$ and $\hat{[B]}_{[c]}$$_{mlr}6$

# %%
plt.figure(figsize=(8,10))
gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))

sns.scatterplot(x='bact_cnt', y='B_[c]_mlr7', data=df_main, hue='row',
                palette=sns.color_palette('YlOrRd_r', 8), ax=axes[0])

plt.suptitle("[Bacteria] Prediction From SLR Model as function of [C]_pred from MLR",
            y=1.03)

handles, labels = axes[0].get_legend_handles_labels()
axes[0].legend(handles[::-1], labels[:-9:-1], title='[B] gradient')
axes[0].set_title('Predicted vs. Actual [B]')
axes[0].set_ylabel('$\hat{[B]}_{[c]}$$_{mlr}7$')
axes[0].set_xlabel('$[B]_{known}$')

axes[0].plot((0,1), 'r--',)
axes[0].set_xlim(left=-0.01, right=.25)
axes[0].set_ylim(bottom=-0.01, top=.25)



sns.scatterplot(x='bact_cnt', y='B_[c]_mlr7', data=df_main, hue='col',
                palette=sns.color_palette("YlGn_r", 12), ax=axes[1])

handles, labels = axes[1].get_legend_handles_labels()
axes[1].legend(handles[::-1], labels[:-13:-1], title='[C] gradient')
axes[1].set_ylabel('$\hat{[B]}_{[c]}$$_{mlr}7$')
axes[1].set_xlabel('$[B]_{known}$')

axes[1].set_title('Predicted vs. Actual [B]')
axes[1].plot((0,1), 'r--',)
axes[1].set_xlim(left=-0.01, right=.25)
axes[1].set_ylim(bottom=-0.01, top=.25)

plt.tight_layout()




plt.figure(figsize=(8,10))
gs = gridspec.GridSpec(2,1)
axes = []
for r in [0,1]:
    for c in [0]:
        axes.append(plt.subplot(gs[r,c]))

sns.scatterplot(x='bact_cnt', y='B_[c]_mlr6', data=df_main, hue='row',
                palette=sns.color_palette('YlOrRd_r', 8), ax=axes[0])


plt.suptitle("[Bacteria] Prediction From SLR Model as function of [C]_pred from MLR",
            y=1.03)

handles, labels = axes[0].get_legend_handles_labels()
axes[0].legend(handles[::-1], labels[:-9:-1], title='[B] gradient')
axes[0].set_title('Predicted vs. Actual [B]')
axes[0].set_ylabel('$\hat{[B]}_{[c]}$$_{mlr}6$')
axes[0].set_xlabel('$[B]_{known}$')

axes[0].plot((0,1), 'r--',)
axes[0].set_xlim(left=-0.01, right=.25)
axes[0].set_ylim(bottom=-0.01, top=.25)



sns.scatterplot(x='bact_cnt', y='B_[c]_mlr6', data=df_main, hue='col',
                palette=sns.color_palette("YlGn_r", 12), ax=axes[1])

handles, labels = axes[1].get_legend_handles_labels()
axes[1].legend(handles[::-1], labels[:-13:-1], title='[C] gradient')
axes[1].set_ylabel('$\hat{[B]}_{[c]}$$_{mlr}6$')
axes[1].set_xlabel('$[B]_{known}$')

axes[1].set_title('Predicted vs. Actual [B]')
axes[1].plot((0,1), 'r--',)
axes[1].set_xlim(left=-0.01, right=.25)
axes[1].set_ylim(bottom=-0.01, top=.25)

plt.tight_layout()
# Out:
# Text(0.5, 1.03, '[Bacteria] Prediction From SLR Model as function of [C]_pred from MLR')
# Text(0.5, 1.0, 'Predicted vs. Actual [B]')
# Text(0, 0.5, '$\\hat{[B]}_{[c]}$$_{mlr}7$')
# Text(0.5, 0, '$[B]_{known}$')
# (-0.01, 0.25)
# (-0.01, 0.25)
# Text(0, 0.5, '$\\hat{[B]}_{[c]}$$_{mlr}7$')
# Text(0.5, 0, '$[B]_{known}$')
# Text(0.5, 1.0, 'Predicted vs. Actual [B]')
# (-0.01, 0.25)
# (-0.01, 0.25)
# Text(0.5, 1.03, '[Bacteria] Prediction From SLR Model as function of [C]_pred from MLR')
# Text(0.5, 1.0, 'Predicted vs. Actual [B]')
# Text(0, 0.5, '$\\hat{[B]}_{[c]}$$_{mlr}6$')
# Text(0.5, 0, '$[B]_{known}$')
# (-0.01, 0.25)
# (-0.01, 0.25)
# Text(0, 0.5, '$\\hat{[B]}_{[c]}$$_{mlr}6$')
# Text(0.5, 0, '$[B]_{known}$')
# Text(0.5, 1.0, 'Predicted vs. Actual [B]')
# (-0.01, 0.25)
# (-0.01, 0.25)
