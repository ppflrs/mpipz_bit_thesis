# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import os

#from scipy.optimize import curve_fit
import scipy

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set(style='whitegrid')

import itertools as it

# %config InteractiveShell.ast_node_interactivity='all'
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Data

# %%
fitted = '/home/rdmtinez/Documents/B-IT MS Program/Masters Thesis/data/regression/regression_fitted_parameters.csv'
tecan = '/home/rdmtinez/Documents/B-IT MS Program/Masters Thesis/data/abs-flu/exp1/tecan_results/abs-fluo_exp1_main.csv'

df_fitted = pd.read_csv(fitted, index_col=0)
df_fitted.head()


df_tecan = pd.read_csv(tecan, index_col=0)
df_tecan.head()
# Out:
#      A680_B    A680_C    A750_B    A750_C      F680_B
# 0  2.519103  1.237138  1.111135  1.141418  586.359911
# 1 -0.009530 -0.008192 -0.009239 -0.009334  497.401393
#   row  col  chlamy_cnt  bact_cnt  abs_680  blank_680  corr_abs_680  fluo_680  \
# 0   A    1        0.25     0.200   0.8037     0.0827        0.7210    4669.0
# 1   B    1        0.25     0.175   0.8649     0.0827        0.7822    4835.0
# 2   C    1        0.25     0.150   0.7752     0.0827        0.6925    4641.0
# 3   D    1        0.25     0.125   0.7808     0.0827        0.6981    4778.0
# 4   E    1        0.25     0.100   0.7615     0.0827        0.6788    4939.0
#
#    blank_fluo  corr_fluo  abs_750  blank_750  corr_abs_750
# 0         3.0     4666.0   0.5047     0.0901        0.4146
# 1         3.0     4832.0   0.5056     0.0901        0.4155
# 2         3.0     4638.0   0.4730     0.0901        0.3829
# 3         3.0     4775.0   0.4494     0.0901        0.3593
# ...

# %% [markdown]
# # Pre-processing

# %% [markdown]
#     # k_C == A680_B[7]
#     # k_B == A680_C[11]
#
#     # kp_C == A750_B[7]
#     # kp_B == A750_C[11]
#
#
#     # A680_T = k_C*[chlamy] + k_B*[bacter]
#     # A750_T = kp_C*[chlamy] + kp_B*[bacter]
#
#
#     #[bacter]_pred = A680_T * kp_C - A750_T * k_C    /     k_B * kp_C - kp_B * k_C
#     #[chlamy]_pred = A680_T * kp_B - A750_T * k_B    /     kp_B * k_C - k_B * kp_C

# %%
 df_main = df_tecan.copy()

# %%
k_C = df_fitted['A680_B'][0]
k_B = df_fitted['A680_C'][0]

kp_C = df_fitted['A750_B'][0]
kp_B = df_fitted['A750_C'][0]

k_C
k_B
kp_C
kp_B
# Out:
# 2.5191031356712745
# 1.2371380485701755
# 1.1111348300633832
# 1.1414182203456336

# %%
df_main['bacter_cnt_prd'] = (df_main['corr_abs_680']*kp_C - df_main['corr_abs_750']*k_C) / (k_B*kp_C - kp_B*k_C) 
df_main['chlamy_cnt_prd'] = (df_main['corr_abs_680']*kp_B - df_main['corr_abs_750']*k_B) / (kp_B*k_C - k_B*kp_C)

# %%
df_main.head(10)
# Out:
#   row  col  chlamy_cnt  bact_cnt  abs_680  blank_680  corr_abs_680  fluo_680  \
# 0   A    1       0.250     0.200   0.8037     0.0827        0.7210    4669.0
# 1   B    1       0.250     0.175   0.8649     0.0827        0.7822    4835.0
# 2   C    1       0.250     0.150   0.7752     0.0827        0.6925    4641.0
# 3   D    1       0.250     0.125   0.7808     0.0827        0.6981    4778.0
# 4   E    1       0.250     0.100   0.7615     0.0827        0.6788    4939.0
# 5   F    1       0.250     0.050   0.7242     0.0827        0.6415    5389.0
# 6   G    1       0.250     0.025   0.7175     0.0827        0.6348    6295.0
# 7   H    1       0.250     0.000   0.7161     0.0827        0.6334    6657.0
# 8   A    2       0.225     0.200   0.7442     0.0827        0.6615    4216.0
# 9   B    2       0.225     0.175   0.7221     0.0827        0.6394    4186.0
#
#    blank_fluo  corr_fluo  abs_750  blank_750  corr_abs_750  chlamy_cnt_prd  \
# ...

# %%
df_main.plot(x='chlamy_cnt', y='chlamy_cnt_prd', kind='scatter')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df_main.plot(x='bact_cnt', y='bacter_cnt_prd', kind='scatter')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
print(bact_cnt_lst)

df_main['corr_abs_680'] - df_main[df_main['bact_cnt']==0]['corr_abs_680']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-efb78f856b5d> in <module>
# ----> 1 print(bact_cnt_lst)
#       2
#       3 df_main['corr_abs_680'] - df_main[df_main['bact_cnt']==0]['corr_abs_680']
#
# NameError: name 'bact_cnt_lst' is not defined

# %%
df_main['diff_680']  = df_main[df_main['bact_cnt']==0]['corr_abs_680'] - df_m
df_main['diff_750']
