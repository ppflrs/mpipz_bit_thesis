# %%
import numpy as np
import pandas as pd
import os
import scipy

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set(style='whitegrid')

import itertools as it

from os.path import join as pjoin

# %config InteractiveShell.ast_node_interactivity='all'
# %config InlineBackend.figure_format = 'svg'

# %%
def get_series(tdf, column='440'):
    """Returns a specific column as a Pandas Series"""
    
    return tdf[column]


def plot_relationship(tdf, column='440'):

    """Given a wavelength of interest this function displays a
    plot of the sum of the predicted values vs the values at
    that wavelength"""
    
    s1 = get_series(tdf, column)
    sm = get_series(tdf, 'B_p'+column) + get_series(tdf, 'C_p'+column)
    
    sns.regplot(x=s1, y=sm)
    plt.show()
    plt.close()
    
    

def get_96position(tdf, column='440'):
    """Returns the values of wanted column (lamda) as a DataFrame
    resembling its 96well plate layout. Facilitates comparison"""
    ninsix = pd.DataFrame()
    for l in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']:
        c = tdf[tdf.index.str.contains(l)][column].values
        ninsix[l] = c
    ninsix = ninsix.transpose()
    ninsix.columns = ninsix.columns+1

    return ninsix.round(6)


def set_B_and_C(tdf, column):
    """This helper function sets the concentraiton values B and
    C on the dataframe for regressiong purposes and so that the 
    plotting function can plot the right values on the x-axis"""
    
    df = tdf.copy()
    
    rows = df['row'].unique()
    cols =  df['col'].unique()
    
    for row in rows:
        #print(row)
        value = df.loc[(df['row']==row) & (df['col']==12), column].iloc[0]
        df.loc[df['row']==row, 'B'] = value

    for col in cols:
        value = df.loc[(df['row']=='H') & (df['col']==col), column].iloc[0]
        df.loc[df['col']==col, 'C'] = value
    
    return df


def plot_pred_vs_known(mdf, column='440', ml_model=False):
    
    """This function takes in the previously calculated prediction values and
    outputs the the predicted vs known values for [chlamy] and [bacter], 
    column refers to the variable wavelength used to construct the regression
    that gave rise to the predicted values"""
    
    df = mdf.copy()

    df = set_B_and_C(df, column)
    
    # figsize
    fs = (8, 10)
    # alpha value for plot markers (see-throughness)
    a = 0.65
    # bacter figure
    fig0 = plt.figure(figsize=fs)
    gs = gridspec.GridSpec(2,1)
    axes = []
    for r in [0,1]:
        for c in [0]:
            axes.append(fig0.add_subplot(gs[r,c]))

    
    # get predicted values from column named
    if ml_model:
        Bp = 'B_pML_'+column
    else:
        Bp = 'B_p'+column
        
    if ml_model:
        Cp = 'C_pML_'+column
    else:
        Cp = 'C_p'+column
        
    # set the scale maximum of the plot to be the maximum value of the maximum
    # of the predicted and known values, which -ever is greater
    smx = max(df[Bp].max(), df['B'].max(), df[Cp].max(), df['C'].max())
    smx = smx+.1*smx
    
    sns.scatterplot(x='B', y=Bp, data=df, hue='row',
                    palette=sns.color_palette("YlOrRd_r", 8),
                    edgecolor='black', alpha=a, ax=axes[0])
    
    handles, labels = axes[0].get_legend_handles_labels()
    axes[0].legend(handles[::-1], labels[:-9:-1], title='[B] gradient')
    axes[0].set_title('Predicted vs. Actual [B]')
    axes[0].set_ylabel('$\hat{[B]}$$_{pred}$')
    axes[0].set_xlabel('$[B]_{known}$')

    axes[0].plot((0,1), 'r--',)
    axes[0].set_xlim(left=-0.02, right=smx) 
    axes[0].set_ylim(bottom=-0.02, top=smx)


    sns.scatterplot(x='B', y=Bp, data=df, hue='col',
                    palette=sns.color_palette("YlGn_r", 12),
                    edgecolor='black', alpha=a, ax=axes[1])

    handles, labels = axes[1].get_legend_handles_labels()
    axes[1].legend(handles[::-1], labels[:-13:-1], title='[C] gradient',
                   loc=2, prop={'size':9})
    axes[1].set_title('Predicted vs. Actual [B]')
    axes[1].set_ylabel('$\hat{[B]}$$_{pred}$')
    axes[1].set_xlabel('$[B]_{known}$')

    axes[1].plot((0,1), 'r--',)
    axes[1].set_xlim(left=-0.02, right=smx)
    axes[1].set_ylim(bottom=-0.02, top=smx)

    if ml_model:
        fig0.suptitle("[Bacteria] Predictions Using ML Multiple Linear Regression @"+column, y=.95)
    else:
        fig0.suptitle("[Bacteria] Predictions Using Simple Linear Regression Models @"+column, y=.95)
        
    fig0.subplots_adjust(hspace=.3)
    
    #plt.show()
    #plt.close()



    # CHLAMY
    fig1=plt.figure(figsize=fs)
    gs = gridspec.GridSpec(2,1)
    axes = []
    for r in [0,1]:
        for c in [0]:
            axes.append(fig1.add_subplot(gs[r,c]))

        
    # set the scale maximum of the plot to be the maximum value of the maximum
    # of the predicted and known values, which -ever is greater
    smx = max(df[Cp].max(), df['C'].max(), df[Bp].max(), df['B'].max())
    smx = smx+.1*smx
    
    
    
    sns.scatterplot(x='C', y=Cp, data=df, hue='row',
                    palette=sns.color_palette("YlOrRd_r", 8),
                    edgecolor='black', alpha=a,ax=axes[0])


    handles, labels = axes[0].get_legend_handles_labels()
    axes[0].legend(handles[::-1], labels[:-9:-1], title='[B] gradient')
    axes[0].set_title('Predicted vs. Actual [C]')
    axes[0].set_ylabel('$\hat{[C]_{pred}}$')
    axes[0].set_xlabel('$[C]_{known}$')

    axes[0].plot((0,1), 'r--',)
    axes[0].set_xlim(left=-0.02, right=smx)
    axes[0].set_ylim(bottom=-0.02, top=smx)


    sns.scatterplot(x='C', y=Cp, data=df, hue='col',
                    palette=sns.color_palette("YlGn_r", 12),
                    edgecolor='black', alpha=a, ax=axes[1])

    handles, labels = axes[1].get_legend_handles_labels()
    axes[1].legend(handles[::-1], labels[:-13:-1], title='[C] gradient',
                  prop={'size':9}, loc=2)
    axes[1].set_title('Predicted vs. Actual [C]')
    axes[1].set_ylabel('$\hat{[C]_{pred}}$')
    axes[1].set_xlabel('$[C]_{known}$')

    axes[1].plot((0,1), 'r--',)
    axes[1].set_xlim(left=-0.02, right=smx)
    axes[1].set_ylim(bottom=-0.02, top=smx)
    
    if ml_model:
        fig1.suptitle("[Chlamy] Predictions Using ML Multiple Linear Regression @"+column, y=.95)
    else:
        fig1.suptitle("[Chlamy] Predictions Using Simple Linear Regression Models @"+column, y=.95)
    
    fig1.subplots_adjust(hspace=.3)

    plt.show()
    plt.close()
    

# Data

## SingStrainRegression @ 560

# %%
path = '../data_o/calibration/community_calibration/predicted_fractions'
fname='a680_a750_pred_fractions.csv'
scdf = pd.read_csv(pjoin(path,fname), index_col=0)

scdf.head()

wc='560'
# Working Wavelength
wd = wc

scdf = set_B_and_C(scdf, wc)
# Out:
#      row  col  B_lbl  C_lbl    A600  A600_sdv    A680  A680_sdv    A720  \
# well
# A1     A    1    0.4   0.50  1.0938    0.0618  1.4928    0.0686  0.8732
# A2     A    2    0.4   0.46  1.0292    0.0746  1.3929    0.0742  0.8300
# A3     A    3    0.4   0.42  0.9685    0.0768  1.2995    0.0818  0.7890
# A4     A    4    0.4   0.38  0.9106    0.0732  1.2021    0.0791  0.7450
# A5     A    5    0.4   0.34  0.8852    0.0785  1.1458    0.0879  0.7252
#
#       A720_sdv  ...    B_p710    C_p710    B_p720    C_p720    B_p730  \
# well            ...
# A1      0.0660  ...  0.278040  0.643211  0.273367  0.606678  0.267915
# A2      0.0714  ...  0.289253  0.582131  0.284374  0.549069  0.278681
# A3      0.0758  ...  0.301672  0.523855  0.296567  0.494104  0.290609
# A4      0.0742  ...  0.311609  0.464905  0.306322  0.438503  0.300149
# A5      0.0804  ...  0.327708  0.424568  0.322135  0.400459  0.315627
#
#         C_p730    B_p740    C_p740    B_p750    C_p750
# well
# A1    0.583698  0.263674  0.571362  0.258862  0.560095
# A2    0.528272  0.274257  0.517107  0.269239  0.506911
# A3    0.475389  0.285984  0.465343  0.280739  0.456169
# A4    0.421895  0.295362  0.412981  0.289932  0.404840
# A5    0.385292  0.310584  0.377152  0.304864  0.369719
#
# [5 rows x 90 columns]

# %%
# set 'empirical 560_nm values at B_only or C_only wells
tcdf = scdf.copy()
tcdf = set_B_and_C(tcdf, wc)

# %%
# PREDICTED 560 fractions Fractions
pB = get_96position(tcdf, 'B_p'+wc)
pC = get_96position(tcdf, 'C_p'+wc)

# 'KNOWN Concentrations as Measured by 560 at row H and col 12'
B = get_96position(tcdf, 'B')
C = get_96position(tcdf, 'C')

# empirical measurements
e560 = get_96position(tcdf, wc)

cm = [sns.light_palette("brown", as_cmap=True),
      sns.light_palette("green", as_cmap=True), 
      sns.light_palette("purple", as_cmap=True)]

"Predicted Values @ 560 vs. Expcted 'Known' Concentration @ 560"
'pB'
pB.style.background_gradient(cmap=cm[0], axis=None)
'B_known'
B.style.background_gradient(cmap=cm[0], axis=None)


'pC'
pC.style.background_gradient(cmap=cm[1], axis=None)
'C_known'
C.style.background_gradient(cmap=cm[1], axis=None)

# How should these sums behave
'Sum of B&C-only measured wells  @560'
'Note that this is not the same as A560_total = kB560*[B] + kC560*[C]'
'This is a just a helpful first approximation of what to expect'
msm = B+C
msm.style.background_gradient(cmap=cm[0], axis=None)

print("""Compare emperical measurements vs predicted fraction additions
We note that the Beer-Lamber Law holds True. Meaning that discrepancies
Come from the signals of one analyte being gleaned off and attributed
to the other. This is why individual predictions look terrible, but the
sum of the predictions are solid. The next step would be to correct of this 
signal theft""")

'Empirical @ 560'
e560.style.background_gradient(cmap=cm[2], axis=None)

'Predicted pB & pC @ 560 sums'
sm = pB + pC
sm.style.background_gradient(cmap=cm[2], axis=None )



# pB.to_csv(pjoin(path,'p560B_a680_a750.csv'))
# pC.to_csv(pjoin(path,'p560C_a680_a750.csv'))
# e560.to_csv(pjoin(path,'emp560_96well.csv'))
# Out:
# "Predicted Values @ 560 vs. Expcted 'Known' Concentration @ 560"
# 'pB'
# <style  type="text/css" >
#     #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col0 {
#             background-color:  #b95757;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col1 {
#             background-color:  #b65151;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col2 {
#             background-color:  #b44b4b;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col3 {
#             background-color:  #b14646;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col4 {
#             background-color:  #ae3e3e;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col5 {
#             background-color:  #aa3535;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col6 {
#             background-color:  #aa3636;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col7 {
#             background-color:  #a93232;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col8 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col9 {
#             background-color:  #a52b2b;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col10 {
#             background-color:  #a72e2e;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row0_col11 {
#             background-color:  #a52b2b;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col0 {
#             background-color:  #c36e6e;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col1 {
#             background-color:  #be6363;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col2 {
#             background-color:  #bb5c5c;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col3 {
#             background-color:  #b85555;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col4 {
#             background-color:  #b75353;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col5 {
#             background-color:  #b44b4b;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col6 {
#             background-color:  #b14646;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col7 {
#             background-color:  #af4141;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col8 {
#             background-color:  #af4141;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col9 {
#             background-color:  #b04242;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col10 {
#             background-color:  #b34949;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row1_col11 {
#             background-color:  #b34a4a;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col0 {
#             background-color:  #ca7d7d;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col1 {
#             background-color:  #c36f6f;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col2 {
#             background-color:  #bb5d5d;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col3 {
#             background-color:  #bb5b5b;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col4 {
#             background-color:  #b95757;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col5 {
#             background-color:  #b54f4f;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col6 {
#             background-color:  #b24747;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col7 {
#             background-color:  #ad3c3c;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col8 {
#             background-color:  #af4141;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col9 {
#             background-color:  #af4141;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col10 {
#             background-color:  #b14646;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row2_col11 {
#             background-color:  #b75353;
#             color:  #f1f1f1;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col0 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col1 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col2 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col3 {
#             background-color:  #c47070;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col4 {
#             background-color:  #c06868;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col5 {
#             background-color:  #be6363;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col6 {
#             background-color:  #bb5c5c;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col7 {
#             background-color:  #bc5f5f;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col8 {
#             background-color:  #bd6060;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col9 {
#             background-color:  #c06767;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col10 {
#             background-color:  #c36e6e;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row3_col11 {
#             background-color:  #c87a7a;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col0 {
#             background-color:  #d89d9d;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col1 {
#             background-color:  #d39292;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col2 {
#             background-color:  #cf8888;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col3 {
#             background-color:  #cd8484;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col4 {
#             background-color:  #cb8080;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col5 {
#             background-color:  #c97b7b;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col6 {
#             background-color:  #c77777;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col7 {
#             background-color:  #c77676;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col8 {
#             background-color:  #c67575;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col9 {
#             background-color:  #c87979;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col10 {
#             background-color:  #c87a7a;
#             color:  #000000;
#         }    #T_f1028caa_0593_11ea_9bb0_9bdc84970eb8row4_col11 {
#             background-color:  #ce8888;
#             color:  #0
# 'B_known'
# <style  type="text/css" >
#     #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col0 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col1 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col2 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col3 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col4 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col5 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col6 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col7 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col8 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col9 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col10 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row0_col11 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col0 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col1 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col2 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col3 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col4 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col5 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col6 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col7 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col8 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col9 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col10 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row1_col11 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col0 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col1 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col2 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col3 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col4 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col5 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col6 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col7 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col8 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col9 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col10 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row2_col11 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col0 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col1 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col2 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col3 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col4 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col5 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col6 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col7 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col8 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col9 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col10 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row3_col11 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col0 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col1 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col2 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col3 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col4 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col5 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col6 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col7 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col8 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col9 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col10 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f10b75e0_0593_11ea_9bb0_9bdc84970eb8row4_col11 {
#             background-color:  #ca7f7f;
#             color:  #0
# 'pC'
# <style  type="text/css" >
#     #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col1 {
#             background-color:  #168c16;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col2 {
#             background-color:  #2a972a;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col3 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col4 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col5 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col6 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col7 {
#             background-color:  #84c984;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col8 {
#             background-color:  #98d498;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col9 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col10 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row0_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col0 {
#             background-color:  #028102;
#             color:  #f1f1f1;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col1 {
#             background-color:  #188d18;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col2 {
#             background-color:  #2c982c;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col3 {
#             background-color:  #3ba13b;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col4 {
#             background-color:  #4eab4e;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col5 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col6 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col7 {
#             background-color:  #85ca85;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col8 {
#             background-color:  #9ad59a;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col9 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col10 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col0 {
#             background-color:  #068306;
#             color:  #f1f1f1;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col1 {
#             background-color:  #1c8f1c;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col2 {
#             background-color:  #2a972a;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col3 {
#             background-color:  #379e37;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col4 {
#             background-color:  #4caa4c;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col5 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col6 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col7 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col8 {
#             background-color:  #9ad59a;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col9 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col10 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row2_col11 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col0 {
#             background-color:  #078407;
#             color:  #f1f1f1;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col1 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col2 {
#             background-color:  #2e992e;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col3 {
#             background-color:  #3ba13b;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col4 {
#             background-color:  #4caa4c;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col5 {
#             background-color:  #5db35d;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col6 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col7 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col8 {
#             background-color:  #9ad59a;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col9 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col10 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row3_col11 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col0 {
#             background-color:  #078407;
#             color:  #f1f1f1;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col1 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col2 {
#             background-color:  #2f9a2f;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col3 {
#             background-color:  #3ca13c;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col4 {
#             background-color:  #4daa4d;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col5 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col6 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col7 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col8 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col9 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col10 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_f115b94c_0593_11ea_9bb0_9bdc84970eb8row4_col11 {
#             background-color:  #e3fee3;
#             color:  #0
# 'C_known'
# <style  type="text/css" >
#     #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row0_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row2_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row3_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_f11f6244_0593_11ea_9bb0_9bdc84970eb8row4_col11 {
#             background-color:  #e5ffe5;
#             color:  #0
# 'Sum of B&C-only measured wells  @560'
# 'Note that this is not the same as A560_total = kB560*[B] + kC560*[C]'
# 'This is a just a helpful first approximation of what to expect'
# <style  type="text/css" >
#     #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col0 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col1 {
#             background-color:  #aa3535;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col2 {
#             background-color:  #ad3c3c;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col3 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col4 {
#             background-color:  #b34949;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col5 {
#             background-color:  #b75353;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col6 {
#             background-color:  #bb5d5d;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col7 {
#             background-color:  #c06767;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col8 {
#             background-color:  #c67474;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col9 {
#             background-color:  #ca7d7d;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col10 {
#             background-color:  #ce8787;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row0_col11 {
#             background-color:  #d89d9d;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col0 {
#             background-color:  #ab3838;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col1 {
#             background-color:  #b04444;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col2 {
#             background-color:  #b34a4a;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col3 {
#             background-color:  #b54f4f;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col4 {
#             background-color:  #b95858;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col5 {
#             background-color:  #be6262;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col6 {
#             background-color:  #c26b6b;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col7 {
#             background-color:  #c77676;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col8 {
#             background-color:  #cc8383;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col9 {
#             background-color:  #d08b8b;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col10 {
#             background-color:  #d59696;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row1_col11 {
#             background-color:  #deabab;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col0 {
#             background-color:  #ab3838;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col1 {
#             background-color:  #b04444;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col2 {
#             background-color:  #b34a4a;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col3 {
#             background-color:  #b54f4f;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col4 {
#             background-color:  #b95858;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col5 {
#             background-color:  #be6262;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col6 {
#             background-color:  #c26b6b;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col7 {
#             background-color:  #c77676;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col8 {
#             background-color:  #cc8383;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col9 {
#             background-color:  #d08b8b;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col10 {
#             background-color:  #d59696;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row2_col11 {
#             background-color:  #deabab;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col0 {
#             background-color:  #b24747;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col1 {
#             background-color:  #b75252;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col2 {
#             background-color:  #ba5959;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col3 {
#             background-color:  #bc5d5d;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col4 {
#             background-color:  #c06666;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col5 {
#             background-color:  #c47070;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col6 {
#             background-color:  #c87979;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col7 {
#             background-color:  #cd8585;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col8 {
#             background-color:  #d39292;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col9 {
#             background-color:  #d69a9a;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col10 {
#             background-color:  #dba4a4;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row3_col11 {
#             background-color:  #e4baba;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col0 {
#             background-color:  #b44c4c;
#             color:  #f1f1f1;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col1 {
#             background-color:  #b95757;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col2 {
#             background-color:  #bc5e5e;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col3 {
#             background-color:  #be6363;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col4 {
#             background-color:  #c26c6c;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col5 {
#             background-color:  #c67676;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col6 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col7 {
#             background-color:  #cf8a8a;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col8 {
#             background-color:  #d59797;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col9 {
#             background-color:  #d99f9f;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col10 {
#             background-color:  #ddaaaa;
#             color:  #000000;
#         }    #T_f12adb42_0593_11ea_9bb0_9bdc84970eb8row4_col11 {
#             background-color:  #e7bfbf;
#             color:  #0
# Compare emperical measurements vs predicted fraction additions
# We note that the Beer-Lamber Law holds True. Meaning that discrepancies
# Come from the signals of one analyte being gleaned off and attributed
# to the other. This is why individual predictions look terrible, but the
# sum of the predictions are solid. The next step would be to correct of this
# signal theft
# 'Empirical @ 560'
# <style  type="text/css" >
#     #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col0 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col1 {
#             background-color:  #850a85;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col2 {
#             background-color:  #8c178c;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col3 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col4 {
#             background-color:  #942594;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col5 {
#             background-color:  #9a2f9a;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col6 {
#             background-color:  #a03aa0;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col7 {
#             background-color:  #a543a5;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col8 {
#             background-color:  #ab4eab;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col9 {
#             background-color:  #b057b0;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col10 {
#             background-color:  #b866b8;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row0_col11 {
#             background-color:  #c67ec6;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col0 {
#             background-color:  #840784;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col1 {
#             background-color:  #8a128a;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col2 {
#             background-color:  #901d90;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col3 {
#             background-color:  #952695;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col4 {
#             background-color:  #9a309a;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col5 {
#             background-color:  #a03aa0;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col6 {
#             background-color:  #a544a5;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col7 {
#             background-color:  #aa4daa;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col8 {
#             background-color:  #b35cb3;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col9 {
#             background-color:  #ba68ba;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col10 {
#             background-color:  #c176c1;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row1_col11 {
#             background-color:  #d192d1;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col0 {
#             background-color:  #8a138a;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col1 {
#             background-color:  #8e198e;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col2 {
#             background-color:  #8f1c8f;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col3 {
#             background-color:  #942494;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col4 {
#             background-color:  #992e99;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col5 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col6 {
#             background-color:  #a543a5;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col7 {
#             background-color:  #a94aa9;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col8 {
#             background-color:  #b159b1;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col9 {
#             background-color:  #b865b8;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col10 {
#             background-color:  #c073c0;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row2_col11 {
#             background-color:  #d091d0;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col0 {
#             background-color:  #8b148b;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col1 {
#             background-color:  #942494;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col2 {
#             background-color:  #972997;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col3 {
#             background-color:  #9b319b;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col4 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col5 {
#             background-color:  #a442a4;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col6 {
#             background-color:  #ab4dab;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col7 {
#             background-color:  #b35db3;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col8 {
#             background-color:  #bb6bbb;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col9 {
#             background-color:  #c47bc4;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col10 {
#             background-color:  #cb88cb;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row3_col11 {
#             background-color:  #dba5db;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col0 {
#             background-color:  #932293;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col1 {
#             background-color:  #992d99;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col2 {
#             background-color:  #9e379e;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col3 {
#             background-color:  #a23ea2;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col4 {
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col5 {
#             background-color:  #ad51ad;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col6 {
#             background-color:  #b35db3;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col7 {
#             background-color:  #ba69ba;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col8 {
#             background-color:  #c176c1;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col9 {
#             background-color:  #c882c8;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col10 {
#             background-color:  #cf8fcf;
#             color:  #000000;
#         }    #T_f134dac0_0593_11ea_9bb0_9bdc84970eb8row4_col11 {
#             background-color:  #dfacdf;
#             color:  #0
# 'Predicted pB & pC @ 560 sums'
# <style  type="text/css" >
#     #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col0 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col1 {
#             background-color:  #860b86;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col2 {
#             background-color:  #8c168c;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col3 {
#             background-color:  #922092;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col4 {
#             background-color:  #942594;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col5 {
#             background-color:  #992d99;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col6 {
#             background-color:  #a03aa0;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col7 {
#             background-color:  #a644a6;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col8 {
#             background-color:  #aa4daa;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col9 {
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col10 {
#             background-color:  #b967b9;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row0_col11 {
#             background-color:  #c781c7;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col0 {
#             background-color:  #870d87;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col1 {
#             background-color:  #8c168c;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col2 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col3 {
#             background-color:  #952795;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col4 {
#             background-color:  #9b319b;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col5 {
#             background-color:  #9f399f;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col6 {
#             background-color:  #a442a4;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col7 {
#             background-color:  #aa4daa;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col8 {
#             background-color:  #b25ab2;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col9 {
#             background-color:  #b967b9;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col10 {
#             background-color:  #c176c1;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row1_col11 {
#             background-color:  #d091d0;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col0 {
#             background-color:  #8d188d;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col1 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col2 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col3 {
#             background-color:  #952795;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col4 {
#             background-color:  #9b319b;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col5 {
#             background-color:  #9f399f;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col6 {
#             background-color:  #a644a6;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col7 {
#             background-color:  #a94aa9;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col8 {
#             background-color:  #b25ab2;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col9 {
#             background-color:  #b865b8;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col10 {
#             background-color:  #c074c0;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row2_col11 {
#             background-color:  #d294d2;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col0 {
#             background-color:  #8e198e;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col1 {
#             background-color:  #962896;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col2 {
#             background-color:  #982c98;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col3 {
#             background-color:  #9d349d;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col4 {
#             background-color:  #a03aa0;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col5 {
#             background-color:  #a544a5;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col6 {
#             background-color:  #aa4daa;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col7 {
#             background-color:  #b35db3;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col8 {
#             background-color:  #bb6abb;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col9 {
#             background-color:  #c37ac3;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col10 {
#             background-color:  #cc8acc;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row3_col11 {
#             background-color:  #dea9de;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col0 {
#             background-color:  #972997;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col1 {
#             background-color:  #9c329c;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col2 {
#             background-color:  #9f399f;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col3 {
#             background-color:  #a340a3;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col4 {
#             background-color:  #a848a8;
#             color:  #f1f1f1;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col5 {
#             background-color:  #ac50ac;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col6 {
#             background-color:  #b35cb3;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col7 {
#             background-color:  #b967b9;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col8 {
#             background-color:  #c175c1;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col9 {
#             background-color:  #c882c8;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col10 {
#             background-color:  #cf8fcf;
#             color:  #000000;
#         }    #T_f13deb10_0593_11ea_9bb0_9bdc84970eb8row4_col11 {
#             background-color:  #e2b0e2;
#             color:  #0

# %% [markdown]
# # Correcting for Signal Theft
#
#     I think this helps determine how the models glean signal from one analyted and adds it to the other (e.g. how the model takes [B] signal and adds it to pC

# %% [markdown]
# # Correct C

# %%
from sklearn.linear_model import LinearRegression

# %%
def quick_scrip():
    
    """Here we're visualizing the predicted values of C (pC) at each well in a column by
    column basis with respect to the known concetration of B. The lines should all be
    flat if the predictions were perfect, but there is a bit of signal addition given by 
    the bacteria. The addition to the signal is dependant on the concentration of B"""
    
    fig, ax = plt.subplots(figsize=(8,5))
    coefs = []
    yints = []
    c_at_cols = [i for i in C.loc['H'].values]
    for i in range(1,13):

        # create a regression object for pC v [B] (B known) and extract coefficients
        regr = LinearRegression()
        k = regr.fit(y=pC[i].values.reshape(-1,1), X=B[12].values.reshape(-1,1))
                    
        coefs.append(k.coef_[0][0])

        sns.regplot(y=pC[i], x=B[12], order=1)
        #sns.regplot(y=pC[i]-pC[i]['H'], x=B[12], order=1)
        

    ax.set_ylabel('pC')
    ax.set_xlabel('B')


    ax.set_ylim(-0.2, .8)
    ax.set_xlim(-0.4, .8)
    ax.legend(c_at_cols, 
              title='C_known @ Col')
    plt.show()
    print('coefs', coefs)
    print()
    print('c_at_cols', c_at_cols)

# %%
quick_scrip()
# Out:
# coefs [0.05656595866524967, 0.09692445824567747, 0.06310798510369094, 0.02004658756026922, 0.012604848631297547, 0.03507500526114857, 0.03606568342979373, 0.027922980144893382, 0.02740167591277025, 0.034829465899238896, 0.023432031060093228, 3.5934184411490945e-07]
#
# c_at_cols [0.6999, 0.6313, 0.5892, 0.563, 0.5084, 0.4475, 0.3913, 0.3235, 0.2445, 0.1935, 0.1298, 0.0]

# %%
# Given that the coefficients are very steady, there is likely only the dependency on the
# amount of bacteria added, therefore tak the average to model correction function

# %%
def quick_scrip():
    #plot_pred_vs_known(ssdf, wc)
    coefs = [0.05656595866524967, 0.06310798510369094, 0.09692445824567747,
             0.02004658756026922, 0.012604848631297547, 0.03507500526114857,
             0.03606568342979373, 0.027922980144893382, 0.02740167591277025, 
             0.034829465899238896, 0.023432031060093228, 3.5934184411490945e-07]
    # the zero is artificial as we first correct for the blank

    c_at_cols = [0.6999, 0.6313, 0.563, 0.5084, 0.5892,
                 0.4475, 0.3913, 0.3235, 0.2445, 0.1935,
                 0.1298, 0.0]

    
    print('coefs', coefs)
    print()
    print('c_at_cols', c_at_cols)
    
    fig, ax = plt.subplots(figsize=(8,5))
    
    # the coefficients have a slight dependency on the concentration of chlamy 
    # which we can exploit to correct for the values of pB
    k_fit = np.polyfit(x=c_at_cols, y=coefs, deg=1)
    k_ptor = np.poly1d(k_fit)

    xs = np.linspace(-0.05, .7, 100)
    plt.plot(c_at_cols, coefs, 'b.', xs, k_ptor(xs), 'r.', xs, np.poly1d([0, np.median(coefs)])(xs), 'k-')

    plt.xlabel('C')
    plt.ylabel('correcting_k')
    print()
    print('k_coefs_mean', np.mean(coefs[:-1]),
          'k_median', np.median(coefs[:-1]))

# %%
quick_scrip()

# It would seem that the it would probably be best to use an average or median of the ks in these
# above regressions as they seem overwhelmingly parallel, thus to make the regression above as in
# the figure below would be a stretch, use the median as it should be robust to outliers in
# Out:
# coefs [0.05656595866524967, 0.06310798510369094, 0.09692445824567747, 0.02004658756026922, 0.012604848631297547, 0.03507500526114857, 0.03606568342979373, 0.027922980144893382, 0.02740167591277025, 0.034829465899238896, 0.023432031060093228, 3.5934184411490945e-07]
#
# c_at_cols [0.6999, 0.6313, 0.563, 0.5084, 0.5892, 0.4475, 0.3913, 0.3235, 0.2445, 0.1935, 0.1298, 0.0]
#
# k_coefs_mean 0.039452425446738444 k_median 0.034829465899238896

# %%
def  corr_func_Csc(pB, pC, Ktype='median'):
    
    # obtained from the empirical data itself, regression coefficients of each
    # column's pC vs. B_known @ [C]=0 (i.e B_only well) (96-well format)
    Ks = [0.05656595866524967, 0.09692445824567747, 0.06310798510369094,
         0.02004658756026922, 0.012604848631297547, 0.03507500526114857,
         0.03606568342979373, 0.027922980144893382, 0.02740167591277025,
         0.034829465899238896, 0.023432031060093228, 3.5934184411490945e-07]
    
    
    c_at_cols = [0.6999, 0.6313, 0.563, 0.5084, 0.5892,
                 0.4475, 0.3913, 0.3235, 0.2445, 0.1935,
                 0.1298, 0.0]
    
    k_fit = np.polyfit(y=Ks, x=c_at_cols, deg=1)
    k_tor = np.poly1d(k_fit)
    
    if Ktype == 'median':
        k = np.median(Ks)
    elif Ktype== 'mean':
        k = np.mean(Ks)
    elif Ktype=='adaptive':
        k = k_tor(pC)
    
    cv_ptor = np.poly1d([k, 0])
    
    return cv_ptor(pB)

# %% [markdown]
# # CORRECT B

# %%
def quick_scrip(ylim=.8):
    
    """Here we're visualizing the predicted values of B (pB) at each well in a row by
    row basis with respect to the known concetration of C. The lines should all be
    flat if the predictions were perfect, but there is a bit of signal addition given by 
    the bacteria. The addition to the signal is dependant on the concentration of B"""
    
    fig, ax = plt.subplots(figsize=(8,5))
    b_max = []
    b_at_cols = []
    for i in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']:
        
        b_at_cols.append(B.loc[i][12])
        # append max value of each column
        b_max.append(max(pB.loc[i]))
        # create a regression plot for pB v [C] (C known)
        if ylim <= .2:
            sns.regplot(y=pB.loc[i]-pB.loc[i][12], x=C.loc['H'], order=2, truncate=False)
        else:
            sns.regplot(y=pB.loc[i], x=C.loc['H'], order=2, truncate=False)
            
        # check for any patterns --- none exist, but we do see the same


    ax.set_ylabel('pB')
    ax.set_xlabel('C')


    ax.set_ylim(-0.3, ylim)
    ax.set_xlim(-0.4, 1.4)
    ax.legend(b_at_cols, 
              title='B_known @ Row')
    plt.show()
    print('coefs', coefs)
    print('b_known_at_cols, b_max_at_col', [i for i in zip(b_at_cols, b_max)])

# %%
quick_scrip(ylim=1)
# Out:
# coefs 0.04256825724076642
# b_known_at_cols, b_max_at_col [(0.478, 0.483985), (0.3868, 0.421214), (0.3888, 0.431038), (0.3008, 0.359926), (0.2673, 0.300049), (0.2041, 0.248695), (0.1378, 0.192354), (0.0, 0.089508)]

# %%
quick_scrip(ylim=.2)
# Out:
# coefs 0.04256825724076642
# b_known_at_cols, b_max_at_col [(0.478, 0.483985), (0.3868, 0.421214), (0.3888, 0.431038), (0.3008, 0.359926), (0.2673, 0.300049), (0.2041, 0.248695), (0.1378, 0.192354), (0.0, 0.089508)]

# %%
# What I think is going is that there is definitely a a parabolic dependency on the amount of 
# signal added to pB from the actual concentration of [C]. At [C]=0 we know that that value is
# close to the actual amount of B in all those wells, but when actual concentration of B is low
# beer-lambert's model add C's signal to B, until a certain threshold at which point it begins to
# be distinguishable. Note also that the amount of B has the effect of shi shifting the parabola
# leftward causing the values... this indicates to me that the parabolas H,K

# %%
def h_k(a2a1a0):
    a, b, c = a2a1a0
    
    h = -(b / 2*a)    
    k = a*(h**2) + b*h + c
    
    #print(2*h, k)
    
    return h, k

def quick_scrip(ylim):
    x = C.loc['H'] # pB at 96-well plate row where there should be no bacteria present
    y = pB.loc['H'] # [C] of C_only wells

    fig, ax = plt.subplots(figsize=(8,8))

    a2s = [] # a2*x**2 + a1*x + a0    
    b_max = []

    rows = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
    Hs = []
    for row in rows:
        b_max.append(min(pB.loc[row]))

        y = pB.loc[row]
        pBfit = np.polyfit(x, y, deg=2)# rcond=None, full=True, w=None, cov=False)

        # We are interested in getting an average 'a2' (breadth) of the parabolas
        # alternatively we can use the 'a2' of the [B] = 0 parabola or list median
        a2s.append(pBfit[0])

        # a0 represents the y-intercept of the fitted parabola, when we truncate his
        # at 0, we essentially bring the apex of the down given that the following
        # f(x) = a2*(x-h) + k     where: h= (1/2)*(-b/a2)   and k = f(h) and h,k 
        # represents the vertex, it must be that a0 only increases the vertex's y
        # k = a2*(h)**2 + a1*x + a0
        c = pBfit[2]
        pBfit[2] = 0 
        pBtor = np.poly1d(pBfit)

        xp = np.linspace(-1, 1.5, 1000)
        plt.plot(x, y-c, '.', xp, pBtor(xp))
        
        # numerically obtain the location of x-coordinate of the vertex
        # as the analytic determinination (h_k)is not suitable
        ps=pBtor(xp).copy()
        k=max(ps)
        h=xp[np.argmax(ps)]
        Hs.append(h)
        ph,pk = h_k(pBfit)
        plt.plot(h,k, 'ro', ph, pk, 'ko')
        plt.ylim(-0.2, ylim)
        plt.xlim(-0.5, 1)
        ax.set_xlabel('C')
        ax.set_ylabel('pB')
        #plt.show()
        
    print(Hs, a2s, pBfit)
    return a2s, Hs

# %%
a2s, Hs = quick_scrip(ylim=.1)
# Out:
# [0.05855855855855863, 0.1936936936936937, 0.22622622622622623, 0.3063063063063063, 0.26626626626626626, 0.24374374374374375, 0.28128128128128127, 0.3613613613613613] [-0.35858663683087716, -0.5095722051618977, -0.745803568144804, -0.6991032754990237, -0.6124032964940198, -0.5253132108936088, -0.47844649340678086, -0.5985173374093159] [-0.59851734  0.43152119  0.        ]

# %%
def quick_scrip():

    fig, ax = plt.subplots(figsize=(9,5))

    # here were are modeling the apparent relationship that 'h' in f(h) = a(x - h)**2 + k=0 
    # pB[12] # predicted at [C] =0
    # B[12] # empirical at [C] =0
    Hs = [0.05851855851855858, 0.19423619423619432, 0.22500872500872493, 0.3058838058838058,
          0.26529126529126534, 0.24323624323624315, 0.28152128152128153, 0.36049136049136044]

    Hs = np.array(Hs)
    #Hs[0] = 0
    Hs
    b_at_c0= np.array(B[12])

    hfit = np.polyfit(b_at_c0, Hs, deg=1)
    htor = np.poly1d(hfit)
    xp = np.linspace(-0.05, .6)
    plt.plot(b_at_c0, Hs, 'ro', xp, htor(xp))
    
    ax.set_xlabel('B')
    ax.set_ylabel('H of (h,k) = C_estimated @ pBmax')
    
    plt.show()
    return htor

# %%
htor = quick_scrip()

# %%
# There are 3 options about which a2 to use, a2 refers to the breadth of the 
# correcting parabolas. These are either:
# the average, the median, or a2 @ [B]=0

a2_at_b0 = -0.5985173374093159 # this we know has  good fit independant of bacteria
a2_medn = np.median(a2s) # this should be more robust to outliers
a2_mean = np.mean(a2s) # this is the median

p_h = htor(pB)

#
b = -2*a2_medn*p_h
corr_func = np.poly1d(np.array([a2_medn, b, 0 ])) # use this to test things, but this block
# isn't necessary

# %%
def  corr_func_Bsc(pB, pC, which_a=None):
    
    # There are 3 options about which a2 to use, a2 refers to the breadth of the 
    # correcting parabolas. These are either:
    # the average, the median, or a2 @ [B]=0
    
    # a2 obtained from from the regression above from high B to B=0
    a2s = [-0.35858663683087716, -0.5095722051618977, -0.745803568144804, -0.6991032754990237,
           -0.6124032964940198, -0.5253132108936088, -0.47844649340678086, -0.5985173374093159]
    
    if which_a =='mean':
        a2 = np.mean(a2s) # this is the mean
    elif which_a =='median':
        a2 = np.median(a2s) # this should be more robust to outliers
    else:
        a2 = a2s[-1] # this we know has good fit independant of bacteria
    
    # takes in the predicted pB and spits out a likely H, one should decide whether to use
    # the predicted B values directed from the model calculations or the corrected B values
    # from the B corrections
    p_h = htor(pB)
    
    # this is from an algebraic manipulation of the parabolic function
    # in polynomial and parabolic form where h = -b/2*a2 --- since we
    # 'know' a2 and p_h is dependant on the concetration of B we 
    # estimate the likely value of b in f(x) = a2*x^2 + b*x + c
    b = -2*a2*p_h
    
    
    cv_tor = np.poly1d([a2, b, 0])
    
    return cv_tor(pC)

# %%
# LOGIC --- I use the fact that the predictions for Chlamy (pC) fit very well to CORRECT THE B
# signal first, then I HAVE to use the CORRECT B values to correct for C otherwise I will lose
# information... else I should should add what I subtracted... but I think we saw that din't work
# too well




#tcdf = ssdf.copy()
tcdf = scdf.copy()

tcdf['Btmp_'+wc] = tcdf['B_p'+wc].copy()
tcdf['Ctmp_'+wc] = tcdf['C_p'+wc].copy()


# CORRECT pB
# use the uncorrected values to correct these 
tcdf['cv'] =  tcdf.apply(lambda x: corr_func_Bsc(x['Btmp_'+wc], x['Ctmp_'+wc],
                         which_a='median'), axis=1)

tcdf['B_p'+wc] = tcdf['Btmp_'+wc] - tcdf['cv']

# since there is a big dependency on B already on the amount of chlamy, it doesn't make sense to
# use the uncorrected values to correct for C
tcdf['cv2'] =  tcdf.apply(lambda x: corr_func_Csc(x['B_p'+wc], x['Ctmp_'+wc],
                          Ktype='adaptive'), axis=1)
# CORRECT pC
tcdf['C_p'+wc] = tcdf['Ctmp_'+wc] - tcdf['cv2']

# in this case it does not make sense to reattribute gleaned signal to B
#tcdf['B_'+wc] = tcdf['Btmp_'+wc] - tcdf['cf']





# sample of corrections made
tcdf[['Btmp_'+wc,'B', 'cv', 'B_p'+wc,'Ctmp_'+wc,'C', 'C_p'+wc]].sample(n=10).sort_values(by='well')
# Out:
#       Btmp_560       B        cv    B_p560  Ctmp_560       C    C_p560
# well
# A3    0.378696  0.4780 -0.074885  0.453581  0.600190  0.5892  0.576915
# B6    0.386605  0.3868 -0.013991  0.400596  0.428547  0.4475  0.413030
# C1    0.258366  0.3888 -0.085147  0.343513  0.709029  0.6999  0.688662
# C10   0.423304  0.3888  0.015511  0.407792  0.187455  0.1935  0.178866
# C3    0.338274  0.3888 -0.060066  0.398339  0.596661  0.5892  0.576324
# D8    0.346169  0.3008  0.018369  0.327800  0.301341  0.3235  0.291700
# E6    0.282771  0.2673  0.010155  0.272616  0.429468  0.4475  0.418890
# F10   0.245646  0.2041  0.033191  0.212455  0.180554  0.1935  0.176186
# F8    0.243366  0.2041  0.035006  0.208360  0.306985  0.3235  0.300771
# H3    0.052071  0.0000  0.039584  0.012487  0.573309  0.5892  0.572693

# %%
# corrected values
tcdf['sum'] = tcdf[['C_p560', 'B_p560']].apply(np.sum, axis=1)

# original values
tcdf['sum2'] = tcdf[['Ctmp_560', 'Btmp_560']].apply(np.sum, axis=1)

np.corrcoef(x=tcdf['560'], y=tcdf['sum'])
np.corrcoef(x=tcdf['560'], y=tcdf['sum2'])

'original'
plot_pred_vs_known(scdf, column=wc, ml_model=False)

'corrected'
plot_pred_vs_known(tcdf, column=wc, ml_model=False)
# Out:
# array([[1.        , 0.99711904],
#        [0.99711904, 1.        ]])
# array([[1.       , 0.9985835],
#        [0.9985835, 1.       ]])
# 'original'
# 'corrected'

# %%
tcdf['sum'] = tcdf['C_p560']+ tcdf['B_p560']
tcdf['sum2'] = tcdf['Ctmp_560']+ tcdf['Btmp_560']

#sns.scatterplot(data=tcdf, x='560', y='sum')
sns.regplot(data=tcdf, x='560', y='sum', marker='.')
np.corrcoef(x=tcdf['560'], y=tcdf['sum'])

np
# Out:
# array([[1.        , 0.99711904],
#        [0.99711904, 1.        ]])
# <module 'numpy' from '/home/rdmtinez/program_files/anaconda3/envs/fluxy/lib/python3.7/site-packages/numpy/__init__.py'>

# %%
sns.regplot(data=tcdf, x='560', y='sum2', marker='.')
np.corrcoef(x=tcdf['560'], y=tcdf['sum2'])
# Out:
# array([[1.       , 0.9985835],
#        [0.9985835, 1.       ]])

# %%
trc = tcdf[(tcdf['B']<=0.4) & (tcdf['C']<=0.4) ].copy()

# %%
trc['sum'] = trc[['C_p560', 'B_p560']].apply(np.sum, axis=1)
trc['sum2'] = trc[['Ctmp_560', 'Btmp_560']].apply(np.sum, axis=1)

# %%
np.corrcoef(x=trc['560'], y=trc['sum'])
np.corrcoef(x=trc['560'], y=trc['sum2'])
# Out:
# array([[1.        , 0.99874316],
#        [0.99874316, 1.        ]])
# array([[1.        , 0.99719497],
#        [0.99719497, 1.        ]])

# %%
def apply_correcting_functions(df, wc='560'):
    # LOGIC --- I use the fact that the predictions for Chlamy (pC) fit very well to CORRECT THE B
    # signal first, then I HAVE to use the CORRECT B values to correct for C otherwise I will lose
    # information... else I should should add what I subtracted... but I think we saw that din't work
    # too well




    cdf = df.copy()
    
    # creates a copy of the uncorrected values (pB and pC), this allows renaming using 
    # the plotting function without making to many changes to it
    cdf['Btmp_'+wc] = cdf['B_p'+wc].copy()
    cdf['Ctmp_'+wc] = cdf['C_p'+wc].copy()


    # CORRECT pB
    # pass the uncorrected values of both predictions to correct B
    cdf['cv'] =  cdf.apply(lambda x: corr_func_Bsc(x['Btmp_'+wc], x['Ctmp_'+wc],
                             which_a='median'), axis=1)

    cdf['B_p'+wc] = cdf['Btmp_'+wc] - cdf['cv']

    # CORRECT pC
    # pass the uncorrected values of C pC and the corrected values of B (cPc), since we
    # are working on the idea that the Chlamy predictions are close to ground truth we
    # first correct B with those C values, and then get the B values as close to their
    # respective ground truth to correct C
    cdf['cv2'] =  cdf.apply(lambda x: corr_func_Csc(x['B_p'+wc], x['Ctmp_'+wc],
                              Ktype='adaptive'), axis=1)
    cdf['C_p'+wc] = cdf['Ctmp_'+wc] - cdf['cv2']


    
    return cdf

# %% [markdown]
# # Validation
#
# ### Method 1

# %% [markdown]
#     # to use Calibratioin 1 data as validation----
#     # the problem with this is that the data collected was very noisy, and its not at all
#     # clear whether it was experiemental error or if the tecan itself was affected, thus
#     # there can be random variability in our measurements that cannot be corrected
#
#     # search for instrument failure in research , random error vs exp. error vs. other kinds of errso, what can be corrected for and what cannot be
#
#     # two methods:
#         1. apply SynCom correction functions to pB, pC in current dataframe even though the predictions were made using models derived from its own data (i.e. those models aren't that good at having consistent prediction)
#
#         2. apply SynCom a680_a720 ~ a560 models to Cal1 Data, then apply correction function

# %%
# Method 1 was a failure --- I already half-heartedly expected that

# %%
# single strain with predicitons
#c_ssdf = apply_correcting_functions(df=ssdf, wc='560')

# %%
#plot_pred_vs_known(c_ssdf, column='560', ml_model=False)

# the plot does not show any good results

# %% [markdown]
# ### Method 2

# %%
# apply SC models to SS data and predict 560 'concentrations' [x]
path = '../data_o/calibration/validation'

# load validation data
validata = pd.read_csv(pjoin(path,'sc_models_on_ss_data_pred_560_a680_a720.csv'),
                      index_col='well')
validata.head()
# Out:
#      row  col  B_lbl  C_lbl    F680    A680    A750     320     325     330  \
# well
# A1     A    1  0.200   0.25  4666.0  0.7210  0.4146  0.8399  0.8359  0.8349
# B1     B    1  0.175   0.25  4832.0  0.7822  0.4155  0.8916  0.8890  0.8907
# C1     C    1  0.150   0.25  4638.0  0.6925  0.3829  0.7923  0.7897  0.7912
# D1     D    1  0.125   0.25  4775.0  0.6981  0.3593  0.7690  0.7657  0.7669
# E1     E    1  0.100   0.25  4936.0  0.6788  0.3414  0.7440  0.7413  0.7438
#
#       ...     765     770     775     780     785     790     795     800  \
# well  ...
# A1    ...  0.4095  0.4067  0.4043  0.4019  0.3995  0.3977  0.3955  0.3937
# B1    ...  0.4099  0.4070  0.4041  0.4014  0.3989  0.3967  0.3943  0.3923
# C1    ...  0.3741  0.3710  0.3688  0.3665  0.3642  0.3622  0.3600  0.3582
# D1    ...  0.3418  0.3389  0.3366  0.3342  0.3319  0.3299  0.3277  0.3258
# E1    ...  0.3266  0.3236  0.3214  0.3191  0.3168  0.3146  0.3124  0.3105
#
#         B_p560    C_p560
# well
# A1    0.230315  0.322719
# B1    0.158287  0.396723
# C1    0.173351  0.334322
# D1    0.077361  0.386595
# E1    0.061885  0.382696
#
# [5 rows x 106 columns]

# %%
c_validata = apply_correcting_functions(df=validata, wc='560')

# %%
plot_pred_vs_known(c_validata, column='560', ml_model=False)

# %%
plot_pred_vs_known(ssdf, column='560', ml_model=False)
