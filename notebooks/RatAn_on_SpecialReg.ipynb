# %% [markdown]
# # Ratio Analyses and Correcting Functions
#
#     Original script made to develop the correcting functions... the work here is rewritten in a more general form in IMPORTANT_GNRL_SynC

# %%
import numpy as np
import pandas as pd
import os
import scipy

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.gridspec as gridspec

import seaborn as sns
sns.set(style='whitegrid')

import itertools as it

from os.path import join as pjoin

# %config InteractiveShell.ast_node_interactivity='all'
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Helper Functions

# %%
def get_series(tdf, column='440'):
    """Returns a specific column as a Pandas Series"""
    
    return tdf[column]


def plot_relationship(tdf, column='440'):

    """Given a wavelength of interest this function displays a
    plot of the sum of the predicted values vs the values at
    that wavelength"""
    
    s1 = get_series(tdf, column)
    sm = get_series(tdf, 'B_p'+column) + get_series(tdf, 'C_p'+column)
    
    sns.regplot(x=s1, y=sm)
    plt.show()
    plt.close()
    
    

def get_96position(tdf, column='440'):
    """Returns the values of wanted column (lamda) as a DataFrame
    resembling its 96well plate layout. Facilitates comparison"""
    ninsix = pd.DataFrame()
    for l in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']:
        c = tdf[tdf.index.str.contains(l)][column].values
        ninsix[l] = c
    ninsix = ninsix.transpose()
    ninsix.columns = ninsix.columns+1

    return ninsix.round(6)


def set_B_and_C(tdf, column):
    """This helper function sets the concentraiton values B and
    C on the dataframe for regressiong purposes and so that the 
    plotting function can plot the right values on the x-axis"""
    
    df = tdf.copy()
    
    rows = df['row'].unique()
    cols =  df['col'].unique()
    
    for row in rows:
        #print(row)
        value = df.loc[(df['row']==row) & (df['col']==12), column].iloc[0]
        df.loc[df['row']==row, 'B'] = value

    for col in cols:
        value = df.loc[(df['row']=='H') & (df['col']==col), column].iloc[0]
        df.loc[df['col']==col, 'C'] = value
    
    return df


def plot_pred_vs_known(mdf, column='440', ml_model=False):
    
    """This function takes in the previously calculated prediction values and
    outputs the the predicted vs known values for [chlamy] and [bacter], 
    column refers to the variable wavelength used to construct the regression
    that gave rise to the predicted values"""
    
    df = mdf.copy()

    df = set_B_and_C(df, column)
    
    # figsize
    fs = (8, 10)
    # alpha value for plot markers (see-throughness)
    a = 0.65
    # bacter figure
    fig0 = plt.figure(figsize=fs)
    gs = gridspec.GridSpec(2,1)
    axes = []
    for r in [0,1]:
        for c in [0]:
            axes.append(fig0.add_subplot(gs[r,c]))

    
    # get predicted values from column named
    if ml_model:
        Bp = 'B_pML_'+column
    else:
        Bp = 'B_p'+column
        
    if ml_model:
        Cp = 'C_pML_'+column
    else:
        Cp = 'C_p'+column
        
    # set the scale maximum of the plot to be the maximum value of the maximum
    # of the predicted and known values, which -ever is greater
    smx = max(df[Bp].max(), df['B'].max(), df[Cp].max(), df['C'].max())
    smx = smx+.1*smx
    
    sns.scatterplot(x='B', y=Bp, data=df, hue='row',
                    palette=sns.color_palette("YlOrRd_r", 8),
                    edgecolor='black', alpha=a, ax=axes[0])
    
    handles, labels = axes[0].get_legend_handles_labels()
    axes[0].legend(handles[::-1], labels[:-9:-1], title='[B] gradient')
    axes[0].set_title('Predicted vs. Actual [B]')
    axes[0].set_ylabel('$\hat{[B]}$$_{pred}$')
    axes[0].set_xlabel('$[B]_{known}$')

    axes[0].plot((0,1), 'r--',)
    axes[0].set_xlim(left=-0.02, right=smx) 
    axes[0].set_ylim(bottom=-0.02, top=smx)


    sns.scatterplot(x='B', y=Bp, data=df, hue='col',
                    palette=sns.color_palette("YlGn_r", 12),
                    edgecolor='black', alpha=a, ax=axes[1])

    handles, labels = axes[1].get_legend_handles_labels()
    axes[1].legend(handles[::-1], labels[:-13:-1], title='[C] gradient',
                   loc=2, prop={'size':9})
    axes[1].set_title('Predicted vs. Actual [B]')
    axes[1].set_ylabel('$\hat{[B]}$$_{pred}$')
    axes[1].set_xlabel('$[B]_{known}$')

    axes[1].plot((0,1), 'r--',)
    axes[1].set_xlim(left=-0.02, right=smx)
    axes[1].set_ylim(bottom=-0.02, top=smx)

    if ml_model:
        fig0.suptitle("[Bacteria] Predictions Using ML Multiple Linear Regression @"+column, y=.95)
    else:
        fig0.suptitle("[Bacteria] Predictions Using Simple Linear Regression Models @"+column, y=.95)
        
    fig0.subplots_adjust(hspace=.3)
    
    #plt.show()
    #plt.close()



    # CHLAMY
    fig1=plt.figure(figsize=fs)
    gs = gridspec.GridSpec(2,1)
    axes = []
    for r in [0,1]:
        for c in [0]:
            axes.append(fig1.add_subplot(gs[r,c]))

        
    # set the scale maximum of the plot to be the maximum value of the maximum
    # of the predicted and known values, which -ever is greater
    smx = max(df[Cp].max(), df['C'].max(), df[Bp].max(), df['B'].max())
    smx = smx+.1*smx
    
    
    
    sns.scatterplot(x='C', y=Cp, data=df, hue='row',
                    palette=sns.color_palette("YlOrRd_r", 8),
                    edgecolor='black', alpha=a,ax=axes[0])


    handles, labels = axes[0].get_legend_handles_labels()
    axes[0].legend(handles[::-1], labels[:-9:-1], title='[B] gradient')
    axes[0].set_title('Predicted vs. Actual [C]')
    axes[0].set_ylabel('$\hat{[C]_{pred}}$')
    axes[0].set_xlabel('$[C]_{known}$')

    axes[0].plot((0,1), 'r--',)
    axes[0].set_xlim(left=-0.02, right=smx)
    axes[0].set_ylim(bottom=-0.02, top=smx)


    sns.scatterplot(x='C', y=Cp, data=df, hue='col',
                    palette=sns.color_palette("YlGn_r", 12),
                    edgecolor='black', alpha=a, ax=axes[1])

    handles, labels = axes[1].get_legend_handles_labels()
    axes[1].legend(handles[::-1], labels[:-13:-1], title='[C] gradient',
                  prop={'size':9}, loc=2)
    axes[1].set_title('Predicted vs. Actual [C]')
    axes[1].set_ylabel('$\hat{[C]_{pred}}$')
    axes[1].set_xlabel('$[C]_{known}$')

    axes[1].plot((0,1), 'r--',)
    axes[1].set_xlim(left=-0.02, right=smx)
    axes[1].set_ylim(bottom=-0.02, top=smx)
    
    if ml_model:
        fig1.suptitle("[Chlamy] Predictions Using ML Multiple Linear Regression @"+column, y=.95)
    else:
        fig1.suptitle("[Chlamy] Predictions Using Simple Linear Regression Models @"+column, y=.95)
    
    fig1.subplots_adjust(hspace=.3)

    plt.show()
    plt.close()
    

# Data

## SingStrainRegression @ 560

# %% [markdown]
# # Single Strain Calibration Data

# %%
path = '../data_o/calibration/single_species_calibration/predicted_fractions'
fname='a680_720_slr_predicted_fractions.csv'
ssdf = pd.read_csv(pjoin(path,fname), index_col=0)

ssdf.head()

# Working Column
wc = '560'
ssdf = set_B_and_C(ssdf, wc)
# Out:
#      row  col  B_lbl  C_lbl    F680    A680    A750     320     325     330  \
# well
# A1     A    1  0.200   0.25  4666.0  0.7210  0.4146  0.8399  0.8359  0.8349
# B1     B    1  0.175   0.25  4832.0  0.7822  0.4155  0.8916  0.8890  0.8907
# C1     C    1  0.150   0.25  4638.0  0.6925  0.3829  0.7923  0.7897  0.7912
# D1     D    1  0.125   0.25  4775.0  0.6981  0.3593  0.7690  0.7657  0.7669
# E1     E    1  0.100   0.25  4936.0  0.6788  0.3414  0.7440  0.7413  0.7438
#
#       ...    B_p780    C_p780    B_p785    C_p785    B_p790    C_p790  \
# well  ...
# A1    ...  0.218229  0.184846  0.217204  0.183421  0.216328  0.182232
# B1    ...  0.177936  0.225882  0.177097  0.224141  0.176378  0.222687
# C1    ...  0.178864  0.190785  0.178022  0.189315  0.177303  0.188087
# D1    ...  0.117760  0.219283  0.117201  0.217592  0.116722  0.216181
# E1    ...  0.105938  0.216913  0.105434  0.215240  0.105002  0.213844
#
#         B_p795    C_p795    B_p800    C_p800
# well
# A1    0.215366  0.180928  0.214393  0.179772
# B1    0.175592  0.221093  0.174794  0.219680
# C1    0.176513  0.186741  0.175713  0.185548
# D1    0.116199  0.214633  0.115667  0.213262
# E1    0.104531  0.212313  0.104051  0.210956
#
# [5 rows x 298 columns]

# %%
# set 'empirical 560_nm values at B_only or C_only wells
tsdf = ssdf.copy()
tsdf = set_B_and_C(tsdf, wc)

# %%
# PREDICTED 560 fractions Fractions
pB = get_96position(tsdf, 'B_p'+wc)
pC = get_96position(tsdf, 'C_p'+wc)

# 'KNOWN Concentrations as Measured by 560 at row H and col 12'
B = get_96position(tsdf, 'B')
C = get_96position(tsdf, 'C')

# empirical measurements
e560 = get_96position(tsdf, wc)

cm = [sns.light_palette("brown", as_cmap=True),
      sns.light_palette("green", as_cmap=True), 
      sns.light_palette("purple", as_cmap=True)]

"Predicted Values @ 560 vs. Expcted 'Known' Concentration @ 560"
'pB'
pB.style.background_gradient(cmap=cm[0], axis=None)
'B_known'
B.style.background_gradient(cmap=cm[0], axis=None)


'pC'
pC.style.background_gradient(cmap=cm[1], axis=None)
'C_known'
C.style.background_gradient(cmap=cm[1], axis=None)

# How should these sums behave
'Sum of B&C-only measured wells  @560'
'Note that this is not the same as A560_total = kB560*[B] + kC560*[C]'
'This is a just a helpful first approximation of what to expect'
msm = B+C
msm.style.background_gradient(cmap=cm[0], axis=None)

print("""Compare emperical measurements vs predicted fraction additions
We note that the Beer-Lamber Law holds True. Meaning that discrepancies
Come from the signals of one analyte being gleaned off and attributed
to the other. This is why individual predictions look terrible, but the
sum of the predictions are solid. The next step would be to correct of this 
signal theft""")

'Empirical @ 560'
e560.style.background_gradient(cmap=cm[2], axis=None)

'Predicted pB & pC @ 560 sums'
sm = pB + pC
sm.style.background_gradient(cmap=cm[2], axis=None )
# Out:
# "Predicted Values @ 560 vs. Expcted 'Known' Concentration @ 560"
# 'pB'
# <style  type="text/css" >
#     #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #ab3737;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #ac3b3b;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #a93333;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #b14545;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #ab3838;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #b14646;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #ac3b3b;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #aa3636;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #aa3535;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #ab3838;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #aa3636;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #b85555;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #ac3b3b;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #b95858;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #a62c2c;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #b44c4c;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #b24848;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #b34949;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #b44c4c;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #b65050;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #b14444;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #b44c4c;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #b44c4c;
#             color:  #f1f1f1;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #b85454;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #bd6060;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #be6262;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #bf6464;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #c26b6b;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #c16a6a;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #be6363;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #c26c6c;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #bb5d5d;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #c16969;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #c36f6f;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #c36d6d;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #cc8282;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #cb8181;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #ca7e7e;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #c67474;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #cc8282;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #cd8585;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #cd8585;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #ce8888;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #cc8282;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #ce8888;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #cb8181;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #d08b8b;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #d39292;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #d39292;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #d18d8d;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #cf8989;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #d39292;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #d59898;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #dba5a5;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #d69a9a;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #d79b9b;
#             color:  #000000;
#         }    #T_87f6bcf6_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #d49595;
#             color:  #0
# 'B_known'
# <style  type="text/css" >
#     #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_87ffcecc_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #d49494;
#             color:  #0
# 'pC'
# <style  type="text/css" >
#     #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #58b158;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #68ba68;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #87cb87;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #98d498;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #b5e4b5;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #c1ebc1;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #6fbd6f;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #8acc8a;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #b5e4b5;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #54ae54;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #74c074;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #7ac47a;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #92d192;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #98d498;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #a5dba5;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #afe1af;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #c1ebc1;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #3ea23e;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #55af55;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #6cbc6c;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #a1d9a1;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #40a340;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #4daa4d;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #5ab25a;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #91d091;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #9cd69c;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_880888c8_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #e3fee3;
#             color:  #0
# 'C_known'
# <style  type="text/css" >
#     #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_8811aff2_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #e5ffe5;
#             color:  #0
# 'Sum of B&C-only measured wells  @560'
# 'Note that this is not the same as A560_total = kB560*[B] + kC560*[C]'
# 'This is a just a helpful first approximation of what to expect'
# <style  type="text/css" >
#     #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #a93232;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #b44c4c;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #b85656;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #bd6161;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #c36d6d;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #c67676;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #cb8080;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #cf8a8a;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #d49595;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #d59898;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #a93333;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #ad3c3c;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #b85555;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #b95757;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #bd6060;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #c16a6a;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #c77777;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #cb7f7f;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #cf8989;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #d49494;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #d89e9e;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #daa1a1;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #b04444;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #b44d4d;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #bf6666;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #c06767;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #c47070;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #c97b7b;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #ce8888;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #d28f8f;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #d69a9a;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #dba4a4;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #e0afaf;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #e1b2b2;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #b95757;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #c47070;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #c57272;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #c87a7a;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #cd8585;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #d39292;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #d79b9b;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #dba4a4;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #e0afaf;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #e4baba;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #e6bdbd;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #b95757;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #bd6060;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #c87979;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #c97b7b;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #cc8383;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #d18e8e;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #d79b9b;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #daa3a3;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #dfadad;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #e4b8b8;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #e8c3c3;
#             color:  #000000;
#         }    #T_881c277a_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #eac6c6;
#             color:  #0
# Compare emperical measurements vs predicted fraction additions
# We note that the Beer-Lamber Law holds True. Meaning that discrepancies
# Come from the signals of one analyte being gleaned off and attributed
# to the other. This is why individual predictions look terrible, but the
# sum of the predictions are solid. The next step would be to correct of this
# signal theft
# 'Empirical @ 560'
# <style  type="text/css" >
#     #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #962896;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #9d349d;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #a645a6;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #a747a7;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #ae53ae;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #b056b0;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #b967b9;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #bc6dbc;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #c176c1;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #c781c7;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #ca86ca;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #932293;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #a442a4;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #b25bb2;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #b25bb2;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #b967b9;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #bf72bf;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #c57dc5;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #c983c9;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #d090d0;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #d091d0;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #9d349d;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #a543a5;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #ad52ad;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #b057b0;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #bb6abb;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #be70be;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #c074c0;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #c781c7;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #c983c9;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #d395d3;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #daa3da;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #dba4db;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #a441a4;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #ac4fac;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #ac50ac;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #b057b0;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #c175c1;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #bb6abb;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #ca85ca;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #cc89cc;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #d59ad5;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #dca6dc;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #e0ade0;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #e2b0e2;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #a747a7;
#             color:  #f1f1f1;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #ae54ae;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #b45eb4;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #bd6ebd;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #c277c2;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #c57cc5;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #cc8acc;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #d498d4;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #dda7dd;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #e3b2e3;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #e8bce8;
#             color:  #000000;
#         }    #T_8828d740_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #e7bae7;
#             color:  #0
# 'Predicted pB & pC @ 560 sums'
# <style  type="text/css" >
#     #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #952795;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #9c339c;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #9e369e;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #a544a5;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #a645a6;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #ae53ae;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #b057b0;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #b967b9;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #bc6cbc;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #c175c1;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #c781c7;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #c984c9;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #942494;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #a442a4;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #b25bb2;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #b25ab2;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #ba68ba;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #bf71bf;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #c57cc5;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #c882c8;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #cf8ecf;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #d091d0;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #a544a5;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #ae53ae;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #bc6cbc;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #be70be;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #c074c0;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #c780c7;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #c882c8;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #d395d3;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #daa2da;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #dba4db;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #a442a4;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #ac50ac;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #ad51ad;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #c176c1;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #bb6abb;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #c984c9;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #cb87cb;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #d599d5;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #dca6dc;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #e0ade0;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #e2b0e2;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #a848a8;
#             color:  #f1f1f1;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #af55af;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #b45eb4;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #bd6fbd;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #c176c1;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #c57dc5;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #cc89cc;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #d599d5;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #dda7dd;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #e3b2e3;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #e8bce8;
#             color:  #000000;
#         }    #T_88321616_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #e7bae7;
#             color:  #0

# %% [markdown]
# # Correcting for Signal Theft
#
#     I think this helps determine how the models glean signal from one analyted and adds it to the other (e.g. how the model takes [B] signal and adds it to pC

# %% [markdown]
# # Correct C

# %%
from sklearn.linear_model import LinearRegression

# %%
def quick_scrip():
    
    """Here we're visualizing the predicted values of C (pC) at each well in a column by
    column basis with respect to the known concetration of B. The lines should all be
    flat if the predictions were perfect, but there is a bit of signal addition given by 
    the bacteria. The addition to the signal is dependant on the concentration of B"""
    
    fig, ax = plt.subplots(figsize=(8,5))
    coefs = []
    yints = []
    c_at_cols = [i for i in C.loc['H'].values]
    for i in range(1,13):

        # create a regression object for pC v [B] (B known) and extract coefficients
        regr = LinearRegression()
        k = regr.fit(y=pC[i].values.reshape(-1,1), X=B[12].values.reshape(-1,1))
                    
        coefs.append(k.coef_[0][0])

        sns.regplot(y=pC[i], x=B[12], order=1)
        #sns.regplot(y=pC[i]-pC[i]['H'], x=B[12], order=1)
        

    ax.set_ylabel('pC')
    ax.set_xlabel('B')


    ax.set_ylim(-0.2, .6)
    ax.set_xlim(-0.4, .8)
    ax.legend(c_at_cols, 
              title='C_known @ Col')
    plt.show()
    print('coefs', coefs)
    print()
    print('c_at_cols', c_at_cols)

# %%
quick_scrip()
# Out:
# coefs [-0.18318173464707982, -0.455369115922226, 0.035345279700297536, -0.3374664943425418, -0.15007058191395656, -0.14186501366818413, -0.03315481012680046, -0.06222276423276078, 0.02690873401952689, 0.051517836243963645, 0.030340819074733672, -5.257714581259297e-07]
#
# c_at_cols [0.351, 0.3224, 0.2423, 0.2372, 0.2107, 0.1751, 0.135, 0.109, 0.0761, 0.0432, 0.0099, 0.0]

# %%
#plot_pred_vs_known(ssdf, wc)
coefs = [-0.18318173464707982, -0.455369115922226, 0.035345279700297536,
         -0.3374664943425418, -0.15007058191395656, -0.14186501366818413,
         -0.03315481012680046, -0.06222276423276078, 0.02690873401952689,
         0.051517836243963645, 0.030340819074733672, 0.0]


# correct for the outlier effect on the regression of column 3 (green line above) well=B3
coefs[2] = np.mean([coefs[1],coefs[3]])

# correct for the apparent outlier effect on the regress of column 1 (blue line aove) well=B1
coefs[0] = np.mean([coefs[1],coefs[2], coefs[3]])
c_at_cols = [0.350999989, 0.32240001100000004, 0.242300011,
             0.237199999, 0.210700013, 0.17510000599999995,
             0.13499999799999998, 0.109000005, 0.076099999,
             0.04319999400000002, 0.009899995999999994, 0.0]


# scatter these two lists and note the type of relationship
plt.scatter(y=coefs, x=c_at_cols)

print('coefs', coefs)
print()
print('c_at_cols', c_at_cols)
# Out:
# coefs [-0.3964178051323839, -0.455369115922226, -0.3964178051323839, -0.3374664943425418, -0.15007058191395656, -0.14186501366818413, -0.03315481012680046, -0.06222276423276078, 0.02690873401952689, 0.051517836243963645, 0.030340819074733672, 0.0]
#
# c_at_cols [0.350999989, 0.32240001100000004, 0.242300011, 0.237199999, 0.210700013, 0.17510000599999995, 0.13499999799999998, 0.109000005, 0.076099999, 0.04319999400000002, 0.009899995999999994, 0.0]

# %%
# the coefficients have a dependency on the concentration of chlamy which we can
# exploit to correct for the values of 
k_fit = np.polyfit(x=c_at_cols, y=coefs, deg=1)


k_ptor = np.poly1d(k_fit)

xs = np.linspace(-0.05, .4, 100)
plt.plot(c_at_cols, coefs, 'b.', xs, k_ptor(xs), 'r.')

plt.xlabel('C')
plt.ylabel('correcting_k')
# Out:
# [<matplotlib.lines.Line2D at 0x7fc47f2eecf8>,
#  <matplotlib.lines.Line2D at 0x7fc47f2eed68>]
# Text(0.5, 0, 'C')
# Text(0, 0.5, 'correcting_k')

# %%
def  corr_func_Css(pB, pC):
    
    # obtained from the empirical data itself, regression coefficients of each
    # column's pC vs. B_known @ [C]=0 (i.e B_only well) (96-well format)
    coefs = [-0.18317955932879285, -0.4553677338194911, 0.035347121040190894,
             -0.33746759907772506, -0.15007213460051003, -0.14186632583482842,
             -0.03315464322646974, -0.062221759683960196, 0.02690820807588553,
             0.05151834743363849, 0.03034145478018707, 0.0]


    # correct for the outlier effect on the regression of column 3 (green line above) well=B3
    coefs[2] = np.mean([coefs[1],coefs[3]])

    # correct for the apparent outlier effect on the regress of column 1 (blue line aove) well=B1
    coefs[0] = np.mean([coefs[1],coefs[2], coefs[3]])
    c_at_cols = [0.350999989, 0.32240001100000004, 0.242300011,
                 0.237199999, 0.210700013, 0.17510000599999995,
                 0.13499999799999998, 0.109000005, 0.076099999,
                 0.04319999400000002, 0.009899995999999994, 0.0]

    
    # this fits the coeficients from each column against C_known... this is to say that
    # every amount of chlamy adds a distinct amount of signal to the prediction of B 
    # accross of a gradient of B, thus we regress to find this coefficient and apply it
    # to correct the signal
    k_fit = np.polyfit(x=c_at_cols, y=coefs, deg=1)
    
    # we use this information to create a
    k_ptor = np.poly1d(k_fit)
    # k_ptor(pC)
    # use the predicted k for the particular value of C at hand, and use it to predict
    # the correction value that will be added/subtracted to C
   
    # probably only works for up to C < 0.25
    
    cv_ptor = np.poly1d(np.array([k_ptor(pC), 0]))
    #print(cv_ptor)
    return cv_ptor(pB)

# %%
#plot_pred_vs_known(ssdf, column=wc, ml_model=False)
#plot_pred_vs_known(ssdf, column=wc, ml_model=False)

# %% [markdown]
# # Correct B

# %%
def quick_scrip():
    
    """Here we're visualizing the predicted values of B (pB) at each well in a row by
    row basis with respect to the known concetration of C. The lines should all be
    flat if the predictions were perfect, but there is a bit of signal addition given by 
    the bacteria. The addition to the signal is dependant on the concentration of B"""
    
    fig, ax = plt.subplots(figsize=(8,5))
    coefs = []
    b_max = []
    b_at_cols = []
    for i in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']:
        
        b_at_cols.append(B.loc[i][12])
        # append max value of each column
        b_max.append(max(pB.loc[i]))
        # create a regression plot for pB v [C] (C known)
        sns.regplot(y=pB.loc[i], x=C.loc['H'], order=2, truncate=False)
        # check for any patterns --- none exist, but we do see the same
        # effecft of chalmy adding signal to B when [B] < 0.05
        
        # average these regresssion coefficient to a global one
        # and use it as a correction factor for pB
        regr = LinearRegression()
        k = regr.fit(y=pB.loc[i].values.reshape(-1,1), X=C.loc['H'].values.reshape(-1,1))
                    
        coefs.append(k.coef_[0][0])

    ax.set_ylabel('pB')
    ax.set_xlabel('C')


    ax.set_ylim(-0.2, .4)
    ax.set_xlim(-0.3, .8)
    ax.legend(b_at_cols, 
              title='B_known @ Row')
    plt.show()
    print('coefs', coefs)
    print('b_known_at_cols, b_max_at_col', [i for i in zip(b_at_cols, b_max)])

# %%
quick_scrip()
pB.loc['H']
pB.loc['F']
#pB.loc['B'][1]
# Out:
# coefs [0.00561516591896593, 0.02120591643777317, 0.07425590485923488, 0.018907692016964742, 0.08395213779805138, 0.06637152011656552, 0.02766946353780928, -2.0941589368631463e-08]
# b_known_at_cols, b_max_at_col [(0.2655, 0.284886), (0.2347, 0.281354), (0.1827, 0.216343), (0.1483, 0.165422), (0.1201, 0.146575), (0.052, 0.079198), (0.0241, 0.054413), (0.0, 0.035081)]
# 1     0.018013
# 2     0.000921
# 3     0.000520
# 4     0.007123
# 5     0.035081
# 6     0.018954
# 7     0.007721
# 8     0.014186
# 9     0.027991
# 10    0.022696
# 11    0.002912
# 12    0.000000
# Name: H, dtype: float64
# 1     0.079198
# 2     0.072143
# 3     0.064663
# 4     0.064965
# 5     0.032373
# 6     0.008575
# 7     0.032842
# 8     0.016327
# 9     0.050746
# 10    0.047446
# 11    0.068854
# 12    0.047340
# Name: F, dtype: float64

# %%
# rather than a parabolic dependency in the syncom version there is a linear one just like in the 
# pC v B graphs above, except this one is steadier than the adaptive version made for that one
coefs = np.array([0.00561516591896593, 0.02120591643777317, 0.07425590485923488, 0.018907692016964742,
         0.08395213779805138, 0.06637152011656552, 0.02766946353780928]).mean()

coefs
# Out:
# 0.04256825724076642

# %% [markdown]
#     Unfortunately there isn't any coherence to the these regression which we can exploit in an adaptive manner. However, we can correct for the effects at very low concentrations of bacteria by using the regression at [B]=0, since we know that at the very least when there is 'No' bacteria present we can remove the addition

# %%
y= pB.loc['H'] # pB at 96-well plate row where there should be no bacteria present
x= C.loc['H']  # [C] of C_only wells

# fit a 2nd degree polynomial line to these data
pBfit = np.polyfit(x,y, deg=2)

# the y-intercept should theoretically be zero
pBfit[2] = 0.0

# this is a function that takes in predicted C (pC) values and returns a corretion amount
# however we should write a clause that its only applied to pC <= 0.05
pBtor = np.poly1d(pBfit)

# %%
y.values
x.values
pBtor
# Out:
# array([0.018013, 0.000921, 0.00052 , 0.007123, 0.035081, 0.018954,
#        0.007721, 0.014186, 0.027991, 0.022696, 0.002912, 0.      ])
# array([0.351 , 0.3224, 0.2423, 0.2372, 0.2107, 0.1751, 0.135 , 0.109 ,
#        0.0761, 0.0432, 0.0099, 0.    ])
# poly1d([-0.32847909,  0.11099588,  0.        ])

# %%
y= pB.loc['F'] # pB at 96-well plate row where there should be no bacteria present
x= C.loc['H']  # [C] of C_only wells

# %%
x.values
y.values
# Out:
# array([0.351 , 0.3224, 0.2423, 0.2372, 0.2107, 0.1751, 0.135 , 0.109 ,
#        0.0761, 0.0432, 0.0099, 0.    ])
# array([0.079198, 0.072143, 0.064663, 0.064965, 0.032373, 0.008575,
#        0.032842, 0.016327, 0.050746, 0.047446, 0.068854, 0.04734 ])

# %%
def  corr_func_Bss(pB, pC):
    
    # pB at 96-well plate row where there should be no bacteria present
    y= [0.018013, 0.000921, 0.00052 , 0.007123, 0.035081, 0.018954,
       0.007721, 0.014186, 0.027991, 0.022696, 0.002912, 0.0] 
    
    # [C] of C_only wells
    x= [0.351 , 0.3224, 0.2423, 0.2372, 0.2107, 0.1751, 0.135 , 0.109 ,
       0.0761, 0.0432, 0.0099, 0.0] 
    
#
    
    # this fits a 2nd degree polynomial line to these data, ... this is to say that
    # every amount of chlamy adds a distinct amount of signal to the prediction of B 
    pBfit = np.polyfit(x,y, deg=2)

    # the y-intercept should theoretically be zero
    pBfit[2] = 0.0
    

    # this is a function that takes in predicted C (pC) values and returns a corretion amount
    # however we should write a clause that its only applied to pC <= 0.05
    pBtor = np.poly1d(pBfit)
    
    
    if pB < 0.1:
        return pBtor(pC)
    else:
        return 0.0

# %%
def  corr_func_Bss2(pB, pC):
    
    # linear regression coefficients of pB vC 
    Ks= coefs = np.array([0.02120591643777317, 0.018907692016964742, 0.02766946353780928]).mean()
    
    

    # this is a function that takes in predicted C (pC) values and returns a correction amount
    # however we should write a clause that its only applied to pC <= 0.05
    pBtor = np.poly1d(Ks)
    
    if pB > 0.15:
        return 0.0
    else:
        return pBtor(pC)

# %%
#tsdf = ssdf.copy()
tsdf = ssdf.copy()

tsdf['Btmp_'+wc] = tsdf['B_p'+wc].copy()
tsdf['Ctmp_'+wc] = tsdf['C_p'+wc].copy()

# always ensure to use the copy of the uncorrected values, because once you correct a column
# the next correction will use the corrected values (wouldn't it be better to use those though?)
tsdf['cf'] =  tsdf.apply(lambda x: corr_func_Css(x['Btmp_'+wc], x['Ctmp_'+wc]), axis=1)

# CORRECT pC
tsdf['C_p'+wc] = tsdf['Ctmp_'+wc] - tsdf['cf']
# in this case it does not make sense to reattribute gleaned signal to B
#tsdf['B_'+wc] = tsdf['Btmp_'+wc] - tsdf['cf']


# CORRECT pB
# use the uncorrected values to correct these 
#tsdf['cf2'] =  tsdf.apply(lambda x: corr_func_Bss(x['Btmp_'+wc], x['Ctmp_'+wc]), axis=1)

# uses corrected C to correct for B
tsdf['cf2'] =  tsdf.apply(lambda x: corr_func_Bss(x['Btmp_'+wc], x['Ctmp_'+wc]), axis=1)

tsdf['B_p'+wc] = tsdf['Btmp_'+wc] + tsdf['cf2']

tsdf[['Btmp_'+wc, 'cf2', 'B_p'+wc, 'Ctmp_'+wc,'C', 'cf' ,'C_p'+wc]].sample(n=10).sort_values(by='well')
# Out:
#       Btmp_560       cf2    B_p560  Ctmp_560       C        cf    C_p560
# well
# A11   0.260932  0.000000  0.260932  0.014622  0.0099  0.016741 -0.002119
# B4    0.281354  0.000000  0.281354  0.166300  0.2372 -0.046686  0.212986
# D5    0.142586  0.000000  0.142586  0.162237  0.2107 -0.022781  0.185018
# E11   0.102177  0.000000  0.102177  0.011271  0.0099  0.007075  0.004196
# G12   0.017608  0.000428  0.018035  0.003900  0.0000  0.001416  0.002484
# G3    0.013955  0.006255  0.020210  0.266433  0.2423 -0.004435  0.270868
# G4    0.003369  0.005589  0.008958  0.276337  0.2372 -0.001121  0.277459
# G7   -0.020019  0.009334 -0.010685  0.157517  0.1350  0.003055  0.154462
# H4    0.007123  0.008313  0.015436  0.225866  0.2372 -0.001826  0.227692
# H8    0.014186  0.007354  0.021540  0.090480  0.1090 -0.000722  0.091202

# %%
'original'
plot_pred_vs_known(ssdf, column=wc, ml_model=False)

'corrected'
plot_pred_vs_known(tsdf, column=wc, ml_model=False)
# Out:
# 'original'
# 'corrected'

# %% [markdown]
# # SynCom Calibration Data

# %%
path = '../data_o/calibration/community_calibration/predicted_fractions'
fname='a680_a720_pred_fractions.csv'
scdf = pd.read_csv(pjoin(path,fname), index_col=0)

scdf.head()


# Working Wavelength
wd = wc

scdf = set_B_and_C(scdf, wc)
# Out:
#      row  col  B_lbl  C_lbl    A600  A600_sdv    A680  A680_sdv    A720  \
# well
# A1     A    1    0.4   0.50  1.0938    0.0618  1.4928    0.0686  0.8732
# A2     A    2    0.4   0.46  1.0292    0.0746  1.3929    0.0742  0.8300
# A3     A    3    0.4   0.42  0.9685    0.0768  1.2995    0.0818  0.7890
# A4     A    4    0.4   0.38  0.9106    0.0732  1.2021    0.0791  0.7450
# A5     A    5    0.4   0.34  0.8852    0.0785  1.1458    0.0879  0.7252
#
#       A720_sdv  ...    B_p710    C_p710    B_p720    C_p720    B_p730  \
# well            ...
# A1      0.0660  ...  0.255450  0.656874  0.251179  0.619558  0.246193
# A2      0.0714  ...  0.270676  0.593367  0.266130  0.559659  0.260821
# A3      0.0758  ...  0.283615  0.534776  0.278836  0.504397  0.273252
# A4      0.0742  ...  0.294469  0.475272  0.289491  0.448274  0.283674
# A5      0.0804  ...  0.312694  0.433649  0.307394  0.409016  0.301199
#
#         C_p730    B_p740    C_p740    B_p750    C_p750
# well
# A1    0.596086  0.242318  0.583480  0.237911  0.571970
# A2    0.538457  0.256701  0.527069  0.252017  0.516673
# A3    0.485288  0.268921  0.475026  0.264001  0.465656
# A4    0.431291  0.279167  0.422171  0.274047  0.413844
# A5    0.393521  0.296403  0.385199  0.290956  0.377603
#
# [5 rows x 90 columns]

# %%
# set 'empirical 560_nm values at B_only or C_only wells
tcdf = scdf.copy()
tcdf = set_B_and_C(tcdf, wc)

# %%
# PREDICTED 560 fractions Fractions
pB = get_96position(tcdf, 'B_p'+wc)
pC = get_96position(tcdf, 'C_p'+wc)

# 'KNOWN Concentrations as Measured by 560 at row H and col 12'
B = get_96position(tcdf, 'B')
C = get_96position(tcdf, 'C')

# empirical measurements
e560 = get_96position(tcdf, wc)

cm = [sns.light_palette("brown", as_cmap=True),
      sns.light_palette("green", as_cmap=True), 
      sns.light_palette("purple", as_cmap=True)]

"Predicted Values @ 560 vs. Expcted 'Known' Concentration @ 560"
'pB'
pB.style.background_gradient(cmap=cm[0], axis=None)
'B_known'
B.style.background_gradient(cmap=cm[0], axis=None)


'pC'
pC.style.background_gradient(cmap=cm[1], axis=None)
'C_known'
C.style.background_gradient(cmap=cm[1], axis=None)

# How should these sums behave
'Sum of B&C-only measured wells  @560'
'Note that this is not the same as A560_total = kB560*[B] + kC560*[C]'
'This is a just a helpful first approximation of what to expect'
msm = B+C
msm.style.background_gradient(cmap=cm[0], axis=None)

print("""Compare emperical measurements vs predicted fraction additions
We note that the Beer-Lamber Law holds True. Meaning that discrepancies
Come from the signals of one analyte being gleaned off and attributed
to the other. This is why individual predictions look terrible, but the
sum of the predictions are solid. The next step would be to correct of this 
signal theft""")

'Empirical @ 560'
e560.style.background_gradient(cmap=cm[2], axis=None)

'Predicted pB & pC @ 560 sums'
sm = pB + pC
sm.style.background_gradient(cmap=cm[2], axis=None )
# Out:
# "Predicted Values @ 560 vs. Expcted 'Known' Concentration @ 560"
# 'pB'
# <style  type="text/css" >
#     #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #be6363;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #ba5a5a;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #b75454;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #b14444;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #ad3c3c;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #ac3b3b;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #aa3636;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #a62d2d;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #a52b2b;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #a62c2c;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #c77777;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #c26c6c;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #bf6464;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #bc5d5d;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #b95858;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #b65151;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #b34a4a;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #b14646;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #b04343;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #b14444;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #b24747;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #b34949;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #cd8484;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #c77777;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #bf6464;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #bc5f5f;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #bc5d5d;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #b75252;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #b34a4a;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #ae3f3f;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #b04242;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #b04242;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #b14444;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #b65050;
#             color:  #f1f1f1;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #ce8787;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #cd8484;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #c77878;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #c57373;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #c16a6a;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #be6363;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #bb5b5b;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #bd6060;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #bd6060;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #c06666;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #c26b6b;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #c77777;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #daa2a2;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #d49595;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #d18e8e;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #ce8686;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #cb8080;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #c87a7a;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #c77878;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #c67676;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #c57373;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #c77676;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #c77676;
#             color:  #000000;
#         }    #T_8d48587c_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #cd8484;
#             color:  #0
# 'B_known'
# <style  type="text/css" >
#     #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #b54e4e;
#             color:  #f1f1f1;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #c47171;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d52435a_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #ca7f7f;
#             color:  #0
# 'pC'
# <style  type="text/css" >
#     #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #168c16;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #2a972a;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #84c984;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #98d498;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #a9dea9;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #038103;
#             color:  #f1f1f1;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #188d18;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #2c982c;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #3ba13b;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #4fac4f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #85ca85;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #088408;
#             color:  #f1f1f1;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #1d901d;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #2b982b;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #4caa4c;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #74c074;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #088408;
#             color:  #f1f1f1;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #1f911f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #2f9a2f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #3da23d;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #87cb87;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #0a850a;
#             color:  #f1f1f1;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #209220;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #319b31;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #4fac4f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_8d5b916c_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #e5ffe5;
#             color:  #0
# 'C_known'
# <style  type="text/css" >
#     #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_8d645bf8_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #e5ffe5;
#             color:  #0
# 'Sum of B&C-only measured wells  @560'
# 'Note that this is not the same as A560_total = kB560*[B] + kC560*[C]'
# 'This is a just a helpful first approximation of what to expect'
# <style  type="text/css" >
#     #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #aa3535;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #ad3c3c;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #af4040;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #b34949;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #b75353;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #bb5d5d;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #c06767;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #c67474;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #ca7d7d;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #ce8787;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #d89d9d;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #ab3838;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #b04444;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #b34a4a;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #b54f4f;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #b95858;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #be6262;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #c26b6b;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #c77676;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #cc8383;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #d08b8b;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #d59696;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #deabab;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #ab3838;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #b04444;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #b34a4a;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #b54f4f;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #b95858;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #be6262;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #c26b6b;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #c77676;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #cc8383;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #d08b8b;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #d59696;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #deabab;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #b24747;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #b75252;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #ba5959;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #bc5d5d;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #c06666;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #c47070;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #c87979;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #cd8585;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #d39292;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #d69a9a;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #dba4a4;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #e4baba;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #b44c4c;
#             color:  #f1f1f1;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #b95757;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #bc5e5e;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #be6363;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #c26c6c;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #c67676;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #ca7f7f;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #cf8a8a;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #d59797;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #d99f9f;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #ddaaaa;
#             color:  #000000;
#         }    #T_8d6dfd5c_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #e7bfbf;
#             color:  #0
# Compare emperical measurements vs predicted fraction additions
# We note that the Beer-Lamber Law holds True. Meaning that discrepancies
# Come from the signals of one analyte being gleaned off and attributed
# to the other. This is why individual predictions look terrible, but the
# sum of the predictions are solid. The next step would be to correct of this
# signal theft
# 'Empirical @ 560'
# <style  type="text/css" >
#     #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #850a85;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #8c178c;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #942594;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #9a2f9a;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #a03aa0;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #a543a5;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #ab4eab;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #b057b0;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #b866b8;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #c67ec6;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #840784;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #8a128a;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #901d90;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #952695;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #9a309a;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #a03aa0;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #a544a5;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #aa4daa;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #b35cb3;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #ba68ba;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #c176c1;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #d192d1;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #8a138a;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #8e198e;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #8f1c8f;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #942494;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #992e99;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #a543a5;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #a94aa9;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #b159b1;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #b865b8;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #c073c0;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #d091d0;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #8b148b;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #942494;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #972997;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #9b319b;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #a442a4;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #ab4dab;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #b35db3;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #bb6bbb;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #c47bc4;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #cb88cb;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #dba5db;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #932293;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #992d99;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #9e379e;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #a23ea2;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #ad51ad;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #b35db3;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #ba69ba;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #c176c1;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #c882c8;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #cf8fcf;
#             color:  #000000;
#         }    #T_8d77ebaa_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #dfacdf;
#             color:  #0
# 'Predicted pB & pC @ 560 sums'
# <style  type="text/css" >
#     #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col0 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col1 {
#             background-color:  #860b86;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col2 {
#             background-color:  #8b158b;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col3 {
#             background-color:  #922092;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col4 {
#             background-color:  #942594;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col5 {
#             background-color:  #992d99;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col6 {
#             background-color:  #9f399f;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col7 {
#             background-color:  #a543a5;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col8 {
#             background-color:  #aa4caa;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col9 {
#             background-color:  #b056b0;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col10 {
#             background-color:  #b865b8;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow0_col11 {
#             background-color:  #c67fc6;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col0 {
#             background-color:  #870d87;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col1 {
#             background-color:  #8c168c;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col2 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col3 {
#             background-color:  #952695;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col4 {
#             background-color:  #9b319b;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col5 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col6 {
#             background-color:  #a441a4;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col7 {
#             background-color:  #aa4caa;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col8 {
#             background-color:  #b159b1;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col9 {
#             background-color:  #b866b8;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col10 {
#             background-color:  #c074c0;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow1_col11 {
#             background-color:  #d090d0;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col0 {
#             background-color:  #8d178d;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col1 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col2 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col3 {
#             background-color:  #942594;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col4 {
#             background-color:  #9b319b;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col5 {
#             background-color:  #9e379e;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col6 {
#             background-color:  #a543a5;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col7 {
#             background-color:  #a849a8;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col8 {
#             background-color:  #b159b1;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col9 {
#             background-color:  #b764b7;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col10 {
#             background-color:  #bf72bf;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow2_col11 {
#             background-color:  #d193d1;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col0 {
#             background-color:  #8e198e;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col1 {
#             background-color:  #962896;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col2 {
#             background-color:  #982b98;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col3 {
#             background-color:  #9c329c;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col4 {
#             background-color:  #9f399f;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col5 {
#             background-color:  #a442a4;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col6 {
#             background-color:  #a94ba9;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col7 {
#             background-color:  #b35cb3;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col8 {
#             background-color:  #ba69ba;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col9 {
#             background-color:  #c278c2;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col10 {
#             background-color:  #cb88cb;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow3_col11 {
#             background-color:  #dda7dd;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col0 {
#             background-color:  #962896;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col1 {
#             background-color:  #9b319b;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col2 {
#             background-color:  #9f389f;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col3 {
#             background-color:  #a23ea2;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col4 {
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col5 {
#             background-color:  #ab4dab;
#             color:  #f1f1f1;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col6 {
#             background-color:  #b25ab2;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col7 {
#             background-color:  #b866b8;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col8 {
#             background-color:  #c073c0;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col9 {
#             background-color:  #c780c7;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col10 {
#             background-color:  #ce8dce;
#             color:  #000000;
#         }    #T_8d813d0e_21b6_11ea_9b94_e9d76b76b75drow4_col11 {
#             background-color:  #e1afe1;
#             color:  #0

# %% [markdown]
# # Correcting for Signal Theft
#
#     I think this helps determine how the models glean signal from one analyted and adds it to the other (e.g. how the model takes [B] signal and adds it to pC

# %% [markdown]
# # Correct C

# %%
from sklearn.linear_model import LinearRegression

# %%
def quick_scrip():
    
    """Here we're visualizing the predicted values of C (pC) at each well in a column by
    column basis with respect to the known concetration of B. The lines should all be
    flat if the predictions were perfect, but there is a bit of signal addition given by 
    the bacteria. The addition to the signal is dependant on the concentration of B"""
    
    fig, ax = plt.subplots(figsize=(8,5))
    coefs = []
    yints = []
    c_at_cols = [i for i in C.loc['H'].values]
    for i in range(1,13):

        # create a regression object for pC v [B] (B known) and extract coefficients
        regr = LinearRegression()
        k = regr.fit(y=pC[i].values.reshape(-1,1), X=B[12].values.reshape(-1,1))
                    
        coefs.append(k.coef_[0][0])

        sns.regplot(y=pC[i], x=B[12], order=1)
        #sns.regplot(y=pC[i]-pC[i]['H'], x=B[12], order=1)
        

    ax.set_ylabel('pC')
    ax.set_xlabel('B')


    ax.set_ylim(-0.2, .8)
    ax.set_xlim(-0.4, .8)
    ax.legend(c_at_cols, 
              title='C_known @ Col')
    plt.show()
    print('coefs', coefs)
    print()
    print('c_at_cols', c_at_cols)

# %%
quick_scrip()
# Out:
# coefs [0.05656595866524967, 0.09692445824567747, 0.06310798510369094, 0.02004658756026922, 0.012604848631297547, 0.03507500526114857, 0.03606568342979373, 0.027922980144893382, 0.02740167591277025, 0.034829465899238896, 0.023432031060093228, 3.5934184411490945e-07]
#
# c_at_cols [0.6999, 0.6313, 0.5892, 0.563, 0.5084, 0.4475, 0.3913, 0.3235, 0.2445, 0.1935, 0.1298, 0.0]

# %%
# Given that the coefficients are very steady, there is likely only the dependency on the
# amount of bacteria added, therefore tak the average to model correction function

# %%
def quick_scrip():
    #plot_pred_vs_known(ssdf, wc)
    coefs = [0.05656595866524967, 0.06310798510369094, 0.09692445824567747,
             0.02004658756026922, 0.012604848631297547, 0.03507500526114857,
             0.03606568342979373, 0.027922980144893382, 0.02740167591277025, 
             0.034829465899238896, 0.023432031060093228, 3.5934184411490945e-07]
    # the zero is artificial as we first correct for the blank

    c_at_cols = [0.6999, 0.6313, 0.563, 0.5084, 0.5892,
                 0.4475, 0.3913, 0.3235, 0.2445, 0.1935,
                 0.1298, 0.0]

    
    print('coefs', coefs)
    print()
    print('c_at_cols', c_at_cols)
    
    fig, ax = plt.subplots(figsize=(8,5))
    
    # the coefficients have a slight dependency on the concentration of chlamy 
    # which we can exploit to correct for the values of pB
    k_fit = np.polyfit(x=c_at_cols, y=coefs, deg=1)
    k_ptor = np.poly1d(k_fit)

    xs = np.linspace(-0.05, .7, 100)
    plt.plot(c_at_cols, coefs, 'b.', xs, k_ptor(xs), 'r.', xs, np.poly1d([0, np.median(coefs)])(xs), 'k-')

    plt.xlabel('C')
    plt.ylabel('correcting_k')
    print()
    print('k_coefs_mean', np.mean(coefs[:-1]),
          'k_median', np.median(coefs[:-1]))

# %%
quick_scrip()

# It would seem that the it would probably be best to use an average or median of the ks in these
# above regressions as they seem overwhelmingly parallel, thus to make the regression above as in
# the figure below would be a stretch, use the median as it should be robust to outliers in
# Out:
# coefs [0.05656595866524967, 0.06310798510369094, 0.09692445824567747, 0.02004658756026922, 0.012604848631297547, 0.03507500526114857, 0.03606568342979373, 0.027922980144893382, 0.02740167591277025, 0.034829465899238896, 0.023432031060093228, 3.5934184411490945e-07]
#
# c_at_cols [0.6999, 0.6313, 0.563, 0.5084, 0.5892, 0.4475, 0.3913, 0.3235, 0.2445, 0.1935, 0.1298, 0.0]
#
# k_coefs_mean 0.039452425446738444 k_median 0.034829465899238896

# %%
def  corr_func_Csc(pB, pC, Ktype='median'):
    
    # obtained from the empirical data itself, regression coefficients of each
    # column's pC vs. B_known @ [C]=0 (i.e B_only well) (96-well format)
    Ks = [0.05656595866524967, 0.09692445824567747, 0.06310798510369094,
         0.02004658756026922, 0.012604848631297547, 0.03507500526114857,
         0.03606568342979373, 0.027922980144893382, 0.02740167591277025,
         0.034829465899238896, 0.023432031060093228, 3.5934184411490945e-07]
    
    
    c_at_cols = [0.6999, 0.6313, 0.563, 0.5084, 0.5892,
                 0.4475, 0.3913, 0.3235, 0.2445, 0.1935,
                 0.1298, 0.0]
    
    k_fit = np.polyfit(y=Ks, x=c_at_cols, deg=1)
    k_tor = np.poly1d(k_fit)
    
    if Ktype == 'median':
        k = np.median(Ks)
    elif Ktype== 'mean':
        k = np.mean(Ks)
    elif Ktype=='adaptive':
        k = k_tor(pC)
    
    cv_ptor = np.poly1d([k, 0])
    
    return cv_ptor(pB)

# %% [markdown]
# # CORRECT B

# %%
def quick_scrip(ylim=.8):
    
    """Here we're visualizing the predicted values of B (pB) at each well in a row by
    row basis with respect to the known concetration of C. The lines should all be
    flat if the predictions were perfect, but there is a bit of signal addition given by 
    the bacteria. The addition to the signal is dependant on the concentration of B"""
    
    fig, ax = plt.subplots(figsize=(8,5))
    b_max = []
    b_at_cols = []
    for i in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']:
        
        b_at_cols.append(B.loc[i][12])
        # append max value of each column
        b_max.append(max(pB.loc[i]))
        # create a regression plot for pB v [C] (C known)
        if ylim <= .2:
            sns.regplot(y=pB.loc[i]-pB.loc[i][12], x=C.loc['H'], order=2, truncate=False)
        else:
            sns.regplot(y=pB.loc[i], x=C.loc['H'], order=2, truncate=False)
            
        # check for any patterns --- none exist, but we do see the same


    ax.set_ylabel('pB')
    ax.set_xlabel('C')


    ax.set_ylim(-0.3, ylim)
    ax.set_xlim(-0.4, 1.4)
    ax.legend(b_at_cols, 
              title='B_known @ Row')
    plt.show()
    print('coefs', coefs)
    print('b_known_at_cols, b_max_at_col', [i for i in zip(b_at_cols, b_max)])

# %%
quick_scrip(ylim=1)
# Out:
# coefs 0.04256825724076642
# b_known_at_cols, b_max_at_col [(0.478, 0.483985), (0.3868, 0.421214), (0.3888, 0.431038), (0.3008, 0.359926), (0.2673, 0.300049), (0.2041, 0.248695), (0.1378, 0.192354), (0.0, 0.089508)]

# %%
quick_scrip(ylim=.2)
# Out:
# coefs 0.04256825724076642
# b_known_at_cols, b_max_at_col [(0.478, 0.483985), (0.3868, 0.421214), (0.3888, 0.431038), (0.3008, 0.359926), (0.2673, 0.300049), (0.2041, 0.248695), (0.1378, 0.192354), (0.0, 0.089508)]

# %%
# What I think is going is that there is definitely a a parabolic dependency on the amount of 
# signal added to pB from the actual concentration of [C]. At [C]=0 we know that that value is
# close to the actual amount of B in all those wells, but when actual concentration of B is low
# beer-lambert's model add C's signal to B, until a certain threshold at which point it begins to
# be distinguishable. Note also that the amount of B has the effect of shi shifting the parabola
# leftward causing the values... this indicates to me that the parabolas H,K

# %%
def h_k(a2a1a0):
    a, b, c = a2a1a0
    
    h = -(b / 2*a)    
    k = a*(h**2) + b*h + c
    
    #print(2*h, k)
    
    return h, k

def quick_scrip(ylim):
    x = C.loc['H'] # pB at 96-well plate row where there should be no bacteria present
    y = pB.loc['H'] # [C] of C_only wells

    fig, ax = plt.subplots(figsize=(8,8))

    a2s = [] # a2*x**2 + a1*x + a0    
    b_max = []

    rows = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
    Hs = []
    for row in rows:
        b_max.append(min(pB.loc[row]))

        y = pB.loc[row]
        pBfit = np.polyfit(x, y, deg=2)# rcond=None, full=True, w=None, cov=False)

        # We are interested in getting an average 'a2' (breadth) of the parabolas
        # alternatively we can use the 'a2' of the [B] = 0 parabola or list median
        a2s.append(pBfit[0])

        # a0 represents the y-intercept of the fitted parabola, when we truncate his
        # at 0, we essentially bring the apex of the down given that the following
        # f(x) = a2*(x-h) + k     where: h= (1/2)*(-b/a2)   and k = f(h) and h,k 
        # represents the vertex, it must be that a0 only increases the vertex's y
        # k = a2*(h)**2 + a1*x + a0
        c = pBfit[2]
        pBfit[2] = 0 
        pBtor = np.poly1d(pBfit)

        xp = np.linspace(-1, 1.5, 1000)
        plt.plot(x, y-c, '.', xp, pBtor(xp))
        
        # numerically obtain the location of x-coordinate of the vertex
        # as the analytic determinination (h_k)is not suitable
        ps=pBtor(xp).copy()
        k=max(ps)
        h=xp[np.argmax(ps)]
        Hs.append(h)
        ph,pk = h_k(pBfit)
        plt.plot(h,k, 'ro', ph, pk, 'ko')
        plt.ylim(-0.2, ylim)
        plt.xlim(-0.5, 1)
        ax.set_xlabel('C')
        ax.set_ylabel('pB')
        #plt.show()
        
    print(Hs, a2s, pBfit)
    return a2s, Hs

# %%
a2s, Hs = quick_scrip(ylim=.1)
# Out:
# [0.05855855855855863, 0.1936936936936937, 0.22622622622622623, 0.3063063063063063, 0.26626626626626626, 0.24374374374374375, 0.28128128128128127, 0.3613613613613613] [-0.35858663683087716, -0.5095722051618977, -0.745803568144804, -0.6991032754990237, -0.6124032964940198, -0.5253132108936088, -0.47844649340678086, -0.5985173374093159] [-0.59851734  0.43152119  0.        ]

# %%
def quick_scrip():

    fig, ax = plt.subplots(figsize=(9,5))

    # here were are modeling the apparent relationship that 'h' in f(h) = a(x - h)**2 + k=0 
    # pB[12] # predicted at [C] =0
    # B[12] # empirical at [C] =0
    Hs = [0.05851855851855858, 0.19423619423619432, 0.22500872500872493, 0.3058838058838058,
          0.26529126529126534, 0.24323624323624315, 0.28152128152128153, 0.36049136049136044]

    Hs = np.array(Hs)
    #Hs[0] = 0
    Hs
    b_at_c0= np.array(B[12])

    hfit = np.polyfit(b_at_c0, Hs, deg=1)
    htor = np.poly1d(hfit)
    xp = np.linspace(-0.05, .6)
    plt.plot(b_at_c0, Hs, 'ro', xp, htor(xp))
    
    ax.set_xlabel('B')
    ax.set_ylabel('H of (h,k) = C_estimated @ pBmax')
    
    plt.show()
    return htor

# %%
htor = quick_scrip()

# %%
# There are 3 options about which a2 to use, a2 refers to the breadth of the 
# correcting parabolas. These are either:
# the average, the median, or a2 @ [B]=0

a2_at_b0 = -0.5985173374093159 # this we know has  good fit independant of bacteria
a2_medn = np.median(a2s) # this should be more robust to outliers
a2_mean = np.mean(a2s) # this is the median

p_h = htor(pB)

#
b = -2*a2_medn*p_h
corr_func = np.poly1d(np.array([a2_medn, b, 0 ])) # use this to test things, but this block
# isn't necessary

# %%
def  corr_func_Bsc(pB, pC, which_a=None):
    
    # There are 3 options about which a2 to use, a2 refers to the breadth of the 
    # correcting parabolas. These are either:
    # the average, the median, or a2 @ [B]=0
    
    # a2 obtained from from the regression above from high B to B=0
    a2s = [-0.35858663683087716, -0.5095722051618977, -0.745803568144804, -0.6991032754990237,
           -0.6124032964940198, -0.5253132108936088, -0.47844649340678086, -0.5985173374093159]
    
    if which_a =='mean':
        a2 = np.mean(a2s) # this is the mean
    elif which_a =='median':
        a2 = np.median(a2s) # this should be more robust to outliers
    else:
        a2 = a2s[-1] # this we know has good fit independant of bacteria
    
    # takes in the predicted pB and spits out a likely H, one should decide whether to use
    # the predicted B values directed from the model calculations or the corrected B values
    # from the B corrections
    p_h = htor(pB)
    
    # this is from an algebraic manipulation of the parabolic function
    # in polynomial and parabolic form where h = -b/2*a2 --- since we
    # 'know' a2 and p_h is dependant on the concetration of B we 
    # estimate the likely value of b in f(x) = a2*x^2 + b*x + c
    b = -2*a2*p_h
    
    
    cv_tor = np.poly1d([a2, b, 0])
    
    return cv_tor(pC)

# %%
# LOGIC --- I use the fact that the predictions for Chlamy (pC) fit very well to CORRECT THE B
# signal first, then I HAVE to use the CORRECT B values to correct for C otherwise I will lose
# information... else I should should add what I subtracted... but I think we saw that din't work
# too well




#tcdf = ssdf.copy()
tcdf = scdf.copy()

tcdf['Btmp_'+wc] = tcdf['B_p'+wc].copy()
tcdf['Ctmp_'+wc] = tcdf['C_p'+wc].copy()


# CORRECT pB
# use the uncorrected values to correct these 
tcdf['cv'] =  tcdf.apply(lambda x: corr_func_Bsc(x['Btmp_'+wc], x['Ctmp_'+wc],
                         which_a='median'), axis=1)

tcdf['B_p'+wc] = tcdf['Btmp_'+wc] - tcdf['cv']

# since there is a big dependency on B already on the amount of chlamy, it doesn't make sense to
# use the uncorrected values to correct for C
tcdf['cv2'] =  tcdf.apply(lambda x: corr_func_Csc(x['B_p'+wc], x['Ctmp_'+wc],
                          Ktype='adaptive'), axis=1)
# CORRECT pC
tcdf['C_p'+wc] = tcdf['Ctmp_'+wc] - tcdf['cv2']

# in this case it does not make sense to reattribute gleaned signal to B
#tcdf['B_'+wc] = tcdf['Btmp_'+wc] - tcdf['cf']





# sample of corrections made
tcdf[['Btmp_'+wc,'B', 'cv', 'B_p'+wc,'Ctmp_'+wc,'C', 'C_p'+wc]].sample(n=10).sort_values(by='well')
# Out:
#       Btmp_560       B        cv    B_p560  Ctmp_560       C    C_p560
# well
# A1    0.341187  0.4780 -0.133624  0.474811  0.737230  0.6999  0.708096
# A3    0.378696  0.4780 -0.074885  0.453581  0.600190  0.5892  0.576915
# A8    0.453480  0.4780 -0.000641  0.454121  0.309022  0.3235  0.295410
# A9    0.475286  0.4780  0.005295  0.469991  0.245752  0.2445  0.233844
# B8    0.412878  0.3868  0.006441  0.406437  0.307599  0.3235  0.295459
# C5    0.354447  0.3888 -0.024616  0.379063  0.490983  0.5084  0.474566
# F10   0.245646  0.2041  0.033191  0.212455  0.180554  0.1935  0.176186
# F12   0.222836  0.2041 -0.001148  0.223984 -0.003828  0.0000 -0.005406
# G8    0.185044  0.1378  0.044926  0.140117  0.301706  0.3235  0.297581
# H9    0.076507  0.0000  0.056726  0.019780  0.226308  0.2445  0.225835

# %%
# corrected values
tcdf['sum'] = tcdf[['C_p560', 'B_p560']].apply(np.sum, axis=1)

# original values
tcdf['sum2'] = tcdf[['Ctmp_560', 'Btmp_560']].apply(np.sum, axis=1)

np.corrcoef(x=tcdf['560'], y=tcdf['sum'])
np.corrcoef(x=tcdf['560'], y=tcdf['sum2'])

'original'
plot_pred_vs_known(scdf, column=wc, ml_model=False)

'corrected'
plot_pred_vs_known(tcdf, column=wc, ml_model=False)
# Out:
# array([[1.        , 0.99711904],
#        [0.99711904, 1.        ]])
# array([[1.       , 0.9985835],
#        [0.9985835, 1.       ]])
# 'original'
# 'corrected'

# %%
tcdf['sum'] = tcdf['C_p560']+ tcdf['B_p560']
tcdf['sum2'] = tcdf['Ctmp_560']+ tcdf['Btmp_560']

#sns.scatterplot(data=tcdf, x='560', y='sum')
sns.regplot(data=tcdf, x='560', y='sum', marker='.')
np.corrcoef(x=tcdf['560'], y=tcdf['sum'])

np
# Out:
# array([[1.        , 0.99711904],
#        [0.99711904, 1.        ]])
# <module 'numpy' from '/home/rdmtinez/program_files/anaconda3/envs/fluxy/lib/python3.7/site-packages/numpy/__init__.py'>

# %%
sns.regplot(data=tcdf, x='560', y='sum2', marker='.')
np.corrcoef(x=tcdf['560'], y=tcdf['sum2'])
# Out:
# array([[1.       , 0.9985835],
#        [0.9985835, 1.       ]])

# %%
trc = tcdf[(tcdf['B']<=0.4) & (tcdf['C']<=0.4) ].copy()

# %%
trc['sum'] = trc[['C_p560', 'B_p560']].apply(np.sum, axis=1)
trc['sum2'] = trc[['Ctmp_560', 'Btmp_560']].apply(np.sum, axis=1)

# %%
np.corrcoef(x=trc['560'], y=trc['sum'])
np.corrcoef(x=trc['560'], y=trc['sum2'])
# Out:
# array([[1.        , 0.99874316],
#        [0.99874316, 1.        ]])
# array([[1.        , 0.99719497],
#        [0.99719497, 1.        ]])

# %%
def apply_correcting_functions(df, wc='560'):
    # LOGIC --- I use the fact that the predictions for Chlamy (pC) fit very well to CORRECT THE B
    # signal first, then I HAVE to use the CORRECT B values to correct for C otherwise I will lose
    # information... else I should should add what I subtracted... but I think we saw that din't work
    # too well




    cdf = df.copy()
    
    # creates a copy of the uncorrected values (pB and pC), this allows renaming using 
    # the plotting function without making to many changes to it
    cdf['Btmp_'+wc] = cdf['B_p'+wc].copy()
    cdf['Ctmp_'+wc] = cdf['C_p'+wc].copy()


    # CORRECT pB
    # pass the uncorrected values of both predictions to correct B
    cdf['cv'] =  cdf.apply(lambda x: corr_func_Bsc(x['Btmp_'+wc], x['Ctmp_'+wc],
                             which_a='median'), axis=1)

    cdf['B_p'+wc] = cdf['Btmp_'+wc] - cdf['cv']

    # CORRECT pC
    # pass the uncorrected values of C pC and the corrected values of B (cPc), since we
    # are working on the idea that the Chlamy predictions are close to ground truth we
    # first correct B with those C values, and then get the B values as close to their
    # respective ground truth to correct C
    cdf['cv2'] =  cdf.apply(lambda x: corr_func_Csc(x['B_p'+wc], x['Ctmp_'+wc],
                              Ktype='adaptive'), axis=1)
    cdf['C_p'+wc] = cdf['Ctmp_'+wc] - cdf['cv2']


    
    return cdf

# %% [markdown]
# # Validation
#
# ### Method 1

# %% [markdown]
#     # to use Calibratioin 1 data as validation----
#     # the problem with this is that the data collected was very noisy, and its not at all
#     # clear whether it was experiemental error or if the tecan itself was affected, thus
#     # there can be random variability in our measurements that cannot be corrected
#
#     # search for instrument failure in research , random error vs exp. error vs. other kinds of errso, what can be corrected for and what cannot be
#
#     # two methods:
#         1. apply SynCom correction functions to pB, pC in current dataframe even though the predictions were made using models derived from its own data (i.e. those models aren't that good at having consistent prediction)
#
#         2. apply SynCom a680_a720 ~ a560 models to Cal1 Data, then apply correction function

# %%
# Method 1 was a failure --- I already half-heartedly expected that

# %%
# single strain with predicitons
#c_ssdf = apply_correcting_functions(df=ssdf, wc='560')

# %%
#plot_pred_vs_known(c_ssdf, column='560', ml_model=False)

# the plot does not show any good results

# %% [markdown]
# ### Method 2

# %%
# apply SC models to SS data and predict 560 'concentrations' [x]
path = '../data_o/calibration/validation'

# load validation data
validata = pd.read_csv(pjoin(path,'sc_models_on_ss_data_pred_560_a680_a720.csv'),
                      index_col='well')
validata.head()
# Out:
#      row  col  B_lbl  C_lbl    F680    A680    A750     320     325     330  \
# well
# A1     A    1  0.200   0.25  4666.0  0.7210  0.4146  0.8399  0.8359  0.8349
# B1     B    1  0.175   0.25  4832.0  0.7822  0.4155  0.8916  0.8890  0.8907
# C1     C    1  0.150   0.25  4638.0  0.6925  0.3829  0.7923  0.7897  0.7912
# D1     D    1  0.125   0.25  4775.0  0.6981  0.3593  0.7690  0.7657  0.7669
# E1     E    1  0.100   0.25  4936.0  0.6788  0.3414  0.7440  0.7413  0.7438
#
#       ...     765     770     775     780     785     790     795     800  \
# well  ...
# A1    ...  0.4095  0.4067  0.4043  0.4019  0.3995  0.3977  0.3955  0.3937
# B1    ...  0.4099  0.4070  0.4041  0.4014  0.3989  0.3967  0.3943  0.3923
# C1    ...  0.3741  0.3710  0.3688  0.3665  0.3642  0.3622  0.3600  0.3582
# D1    ...  0.3418  0.3389  0.3366  0.3342  0.3319  0.3299  0.3277  0.3258
# E1    ...  0.3266  0.3236  0.3214  0.3191  0.3168  0.3146  0.3124  0.3105
#
#         B_p560    C_p560
# well
# A1    0.230315  0.322719
# B1    0.158287  0.396723
# C1    0.173351  0.334322
# D1    0.077361  0.386595
# E1    0.061885  0.382696
#
# [5 rows x 106 columns]

# %%
c_validata = apply_correcting_functions(df=validata, wc='560')

# %%
plot_pred_vs_known(c_validata, column='560', ml_model=False)

# %%
plot_pred_vs_known(ssdf, column='560', ml_model=False)

# %%
# How similar are the models themselves

#sc_model
#560	0.834127837	1.638846922	0.773945696	0.826255292	-1.472662044	3.136375574	1.353036608	-1.49506327

# ss_model
#560	0.921885444	1.863641627	0.870440283	0.839434975	-0.974654273	2.137588775	0.920606905	-0.831220282

# How similar are the predictions at [B \\ C]-only wells
pd.concat([ssdf[(ssdf['B']==0) | (ssdf['C']==0)][['B', 'C']],scdf[(scdf['B']==0) | (scdf['C']==0)][['B', 'C']]], axis=1)
# Out:
# /home/rdmtinez/program_files/anaconda3/envs/fluxy/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.
#           B       C       B       C
# A12  0.2655  0.0000  0.4780  0.0000
# B12  0.2347  0.0000  0.3868  0.0000
# C12  0.1827  0.0000  0.3888  0.0000
# D12  0.1483  0.0000  0.3008  0.0000
# E12  0.1201  0.0000  0.2673  0.0000
# F12  0.0520  0.0000  0.2041  0.0000
# G12  0.0241  0.0000  0.1378  0.0000
# H1   0.0000  0.3510  0.0000  0.6999
# H10  0.0000  0.0432  0.0000  0.1935
# H11  0.0000  0.0099  0.0000  0.1298
# H12  0.0000  0.0000  0.0000  0.0000
# H2   0.0000  0.3224  0.0000  0.6313
# H3   0.0000  0.2423  0.0000  0.5892
# H4   0.0000  0.2372  0.0000  0.5630
# H5   0.0000  0.2107  0.0000  0.5084
# H6   0.0000  0.1751  0.0000  0.4475
# H7   0.0000  0.1350  0.0000  0.3913
# H8   0.0000  0.1090  0.0000  0.3235
# H9   0.0000  0.0761  0.0000  0.2445

# %%
# conclusion about the ss_data as a validation set is that 
# you cannot use the SynComm models to model sing-strain data
# even though we think that the bacteria measurements for either
# ss or sc are fundamentaly the same, we really don't know what
# other factors can be are at play, e.g. are there elements in
# bacteria species that absorb differently.... we also cannot 
# assert that the tecan was problem-free during the time 
# that the screening data was taken, nor the first calibration

# speakin of:
    #what's absorbtion look at for ss_data,
    #the else can be inside these

# we note that sing strain models has its own correction facter
# and that we can correct these models
# thus given that we expect, we
